# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
from sklearn.preprocessing import *
assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import time

import functools

import seaborn as sns
from tqdm import tqdm_notebook as tqdm

import tensorflow as tf
import keras
from keras import Input, Model
from keras.layers import Dense, LeakyReLU, concatenate
from keras.models import Model
from keras.layers import Input, Reshape
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling1D, Conv1D
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import Adam, SGD
from keras.callbacks import TensorBoard

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Data Preprocessing

# %%
def get_dataset(samples_num=20):
  
    
    theta = np.linspace(-2*np.pi + 4*np.random.random()*np.pi, 2*np.pi + 4*np.random.random()*np.pi, samples_num)
    z = np.linspace(0, 4, samples_num)
    #r = 1 + np.random.random()
    r = 1 - np.random.random()*0.4
    x = r * np.sin(theta)
    y = r * np.cos(theta)
   
    return x,y,z

# %%
x = []
y = []
z = []

# generate 1000 spirals
for i in range(1000):
    xx, yy, zz = get_dataset()
    x.append(xx)
    y.append(yy)
    z.append(zz)
    
x = np.array(x)
y = np.array(y)
z = np.array(z)

x.shape
# Out:
# (1000, 20)

# %% [markdown]
# ### Displaying how the points(x,y) of the spirals locate in concentric circles at different times.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)
axes[0].scatter(x[:,0], y[:,0], label='At z = 0')
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")

axes[1].scatter(x[:,9], y[:,9], label='At z = 1')
axes[1].set_xlabel("x")

axes[2].scatter(x[:,19], y[:,19], label='At z = 2')

axes[2].set_xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot3D(x[0,:], y[0,:], z[0,:], 'r', label='Sample 1')
ax.plot3D(x[1,:], y[1,:], z[1,:], 'b', label='Sample 2')
ax.plot3D(x[2,:], y[2,:], z[2,:], 'y', label='Sample 3')

ax.legend()
plt.show()

# %%
samples_num = 1000
dataset = []
for i in range(samples_num):
    sample_data = np.concatenate((x[i,:].reshape(-1,1), y[i,:].reshape(-1,1)), axis=1)
    dataset.append(sample_data)

dataset = np.array(dataset)
dataset.shape
# Out:
# (1000, 20, 2)

# %%
BATCH_SIZE = 32
latent_space = 12

# %%
# Create a tensorflow dataset and split it into batches
train_dataset = dataset.reshape(dataset.shape[0], dataset.shape[1], dataset.shape[2], 1).astype('float32')
train_dataset = tf.data.Dataset.from_tensor_slices(train_dataset)
train_dataset = train_dataset.shuffle(len(dataset))
train_dataset = train_dataset.batch(BATCH_SIZE)
num=0
for data in train_dataset:
    print("every time the data shape",data.shape)
    num+=1

print("Cycles: ",num)
# Out:
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (32, 20, 2, 1)
# every time the data shape (8, 20, 2, 1)
# Cycles:  32

# %% [markdown]
# # Training

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    
    model.add(keras.layers.Dense(10*2*1, use_bias=False, input_shape=(latent_space, )))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.LeakyReLU())

    model.add(keras.layers.Reshape((10, 2, 1)))

    #model.add(Reshape((int(latent_space/2), 2, 1), input_shape=(latent_space,)))

    model.add(keras.layers.Conv2D(16, (8, 2), strides=(1, 2), padding='same'))
    model.add(keras.layers.LayerNormalization())
    model.add(keras.layers.LeakyReLU())

    model.add(keras.layers.Conv2D(32, (8, 2), strides=(2, 1), padding='same'))
    model.add(keras.layers.LayerNormalization())
    model.add(keras.layers.LeakyReLU())

    model.add(keras.layers.Conv2DTranspose(32, (8, 2), strides=(1, 2), padding='same', use_bias=False))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.LeakyReLU())
    
    model.add(keras.layers.Conv2DTranspose(16, (8, 2), strides=(2, 1), padding='same', use_bias=False))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.LeakyReLU())
    
    model.add(keras.layers.Conv2DTranspose(1, (8, 2), strides=(2, 1), padding='same', use_bias=False, activation='tanh'))

    return model

# %%
generator = make_generator_model()
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                240
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20)                80
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 20)                0
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 2, 1)          0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 10, 1, 16)         272
# _________________________________________________________________
# layer_normalization (LayerNo (None, 10, 1, 16)         32
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 10, 1, 16)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 1, 32)          8224
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 5, 1, 32)          64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 5, 1, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 5, 2, 32)          16384
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 2, 32)          128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 5, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 10, 2, 16)         8192
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10, 2, 16)         64
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 10, 2, 16)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 20, 2, 1)          256
# =================================================================
# Total params: 33,936
# Trainable params: 33,800
# Non-trainable params: 136
# _________________________________________________________________

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(keras.layers.Conv2D(32, (8, 2), strides=(2, 1), padding='same',
                                     input_shape=[20, 2, 1]))
    model.add(keras.layers.LayerNormalization())
    model.add(keras.layers.LeakyReLU())
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Conv2D(64, (8, 2), strides=(2, 1), padding='same'))
    model.add(keras.layers.LayerNormalization())
    model.add(keras.layers.LeakyReLU())
    model.add(keras.layers.Dropout(0.2))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(1))

    return model

# %%
discriminator = make_discriminator_model()
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 10, 2, 32)         544
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 10, 2, 32)         64
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 10, 2, 32)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 2, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 2, 64)          32832
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 5, 2, 64)          128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 5, 2, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 641
# =================================================================
# Total params: 34,209
# Trainable params: 34,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
gan = keras.models.Sequential([generator, discriminator])
gan.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 20, 2, 1)          33936
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 34209
# =================================================================
# Total params: 68,145
# Trainable params: 68,009
# Non-trainable params: 136
# _________________________________________________________________

# %%
def generator_loss(fake_output):
    return -tf.reduce_mean(fake_output)

def discriminator_loss(real_output,fake_output):
    return tf.reduce_mean(fake_output)-tf.reduce_mean(real_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5, beta_2=0.9)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5, beta_2=0.9)

# %%
def gradient_penalty(f, real, fake):
    
    def _interpolate(a, b):
        shape = [tf.shape(a)[0]] + [1] * (a.shape.ndims - 1)
        alpha = tf.random.uniform(shape=shape, minval=0., maxval=1.)
        inter = a + alpha * (b - a)
        inter.set_shape(a.shape)
        return inter

    x = _interpolate(real, fake)
    with tf.GradientTape() as t:
        t.watch(x)
        pred = f(x)
    grad = t.gradient(pred, x)
    norm = tf.norm(tf.reshape(grad, [tf.shape(grad)[0], -1]), axis=1)
    gp = tf.reduce_mean((norm - 1.)**2)

    return gp

# %%
@tf.function
def train_G(batch):
    with tf.GradientTape() as gen_tape:
        if batch.shape[0]==BATCH_SIZE:
            noise = tf.random.normal([BATCH_SIZE, latent_space])
        else:
            noise = tf.random.normal([batch.shape[0]%BATCH_SIZE, latent_space])
        generated_images = generator(noise, training=True)
        fake_output = discriminator(generated_images, training=True)
        gen_loss = generator_loss(fake_output)
        
    
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))


    return gen_loss

# %%
@tf.function
def train_D(batch):
    with tf.GradientTape() as disc_tape:
        if batch.shape[0]==BATCH_SIZE:
            noise = tf.random.normal([BATCH_SIZE, latent_space])
        else:
            noise = tf.random.normal([batch.shape[0]%BATCH_SIZE, latent_space])

        generated_images = generator(noise, training=True)

        real_output = discriminator(batch, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss_without = discriminator_loss(real_output, fake_output)
        gp = gradient_penalty(functools.partial(discriminator, training=True), batch, generated_images)
        disc_loss = discriminator_loss(real_output, fake_output) + gp*10.0

    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return disc_loss_without

# %%
generator_log_dir = './content/generator'
discriminator_log_dir = './content/discriminator'

generator_summary_writer = tf.summary.create_file_writer(generator_log_dir)
discriminator_summary_writer = tf.summary.create_file_writer(discriminator_log_dir)

# %%
generator_mean_loss = tf.keras.metrics.Mean(dtype=tf.float32)
discriminator_mean_loss = tf.keras.metrics.Mean(dtype=tf.float32)

# %%
n_critic = 5
num_examples_to_generate = 5
seed = tf.random.normal([num_examples_to_generate, latent_space])

# %%
def train(dataset, epochs):
    hist = []
    for epoch in range(epochs):
        start = time.time()
        print("Epoch {}/{}".format(epoch + 1, epochs))   

        for batch in dataset:

            for _ in range(n_critic):
                disc_loss_without = train_D(batch)

            gen_loss = train_G(batch)
            

            generator_mean_loss(gen_loss)
            discriminator_mean_loss(disc_loss_without)
        
        with generator_summary_writer.as_default():
            tf.summary.scalar('generator_loss', generator_mean_loss.result(), step=epoch)

        with discriminator_summary_writer.as_default():
            tf.summary.scalar('discriminator_loss', discriminator_mean_loss.result(), step=epoch)
        
        hist.append([generator_mean_loss.result().numpy(), discriminator_mean_loss.result().numpy()])

        generator_mean_loss.reset_states()
        discriminator_mean_loss.reset_states()
        
        print("discriminator: {:.6f}".format(hist[-1][1]), end=' - ')
        print("generator: {:.6f}".format(hist[-1][0]), end=' - ')    
        print('{:.0f}s'.format( time.time()-start))

        # Global variables are used below
        if epoch%100 == 0:
            #save the model
            gan.save('./content/'+'wgan'+str(epoch)+'.h5')    

            # plot loss
            print('Loss: ')
            fig, ax = plt.subplots(1,1, figsize=[10,5])
            ax.plot(hist)
            ax.legend(['loss_gen', 'loss_disc'])
            #ax.set_yscale('log')
            ax.grid()
            plt.show()
            
    return hist

# %%
# %matplotlib inline
hist = train(train_dataset, epochs=501)
# Out:
# Epoch 1/501
# discriminator: -0.413133 - generator: 0.238168 - 14s
# Loss:
# Epoch 2/501
# discriminator: -0.859103 - generator: 0.209299 - 1s
# Epoch 3/501
# discriminator: -0.864158 - generator: 0.354751 - 1s
# Epoch 4/501
# discriminator: -0.909183 - generator: 0.693103 - 1s
# Epoch 5/501
# discriminator: -0.828348 - generator: 0.942093 - 1s
# Epoch 6/501
# discriminator: -0.722742 - generator: 1.214793 - 1s
# Epoch 7/501
# discriminator: -0.711567 - generator: 1.385554 - 1s
# Epoch 8/501
# discriminator: -0.732231 - generator: 1.477418 - 1s
# Epoch 9/501
# discriminator: -0.752872 - generator: 1.596236 - 1s
# Epoch 10/501
# discriminator: -0.798326 - generator: 1.750497 - 1s
# Epoch 11/501
# discriminator: -0.785554 - generator: 1.760891 - 1s
# Epoch 12/501
# discriminator: -0.814551 - generator: 1.796945 - 1s
# Epoch 13/501
# discriminator: -0.793677 - generator: 1.902462 - 1s
# Epoch 14/501
# discriminator: -0.765957 - generator: 2.065219 - 1s
# Epoch 15/501
# discriminator: -0.819681 - generator: 2.165789 - 1s
# Epoch 16/501
# discriminator: -0.775817 - generator: 2.254784 - 1s
# Epoch 17/501
# discriminator: -0.716968 - generator: 2.406814 - 1s
# Epoch 18/501
# discriminator: -0.739696 - generator: 2.444991 - 1s
# Epoch 19/501
# discriminator: -0.769700 - generator: 2.527151 - 1s
# Epoch 20/501
# discriminator: -0.788503 - generator: 2.621137 - 1s
# Epoch 21/501
# discriminator: -0.812348 - generator: 2.787347 - 1s
# Epoch 22/501
# discriminator: -0.827264 - generator: 2.999688 - 1s
# Epoch 23/501
# discriminator: -0.848585 - generator: 3.052148 - 1s
# Epoch 24/501
# discriminator: -0.887016 - generator: 3.227089 - 1s
# Epoch 25/501
# discriminator: -0.835850 - generator: 3.369318 - 1s
# Epoch 26/501
# discriminator: -0.880905 - generator: 3.510748 - 1s
# Epoch 27/501
# discriminator: -0.911704 - generator: 3.567006 - 1s
# Epoch 28/501
# discriminator: -0.892146 - generator: 3.725568 - 1s
# Epoch 29/501
# discriminator: -0.936670 - generator: 3.839187 - 1s
# Epoch 30/501
# discriminator: -0.935723 - generator: 3.895846 - 1s
# Epoch 31/501
# discriminator: -0.992384 - generator: 3.960546 - 1s
# Epoch 32/501
# discriminator: -0.936288 - generator: 4.100278 - 1s
# Epoch 33/501
# discriminator: -0.990644 - generator: 4.187586 - 1s
# Epoch 34/501
# discriminator: -0.934865 - generator: 4.267618 - 1s
# Epoch 35/501
# discriminator: -0.958390 - generator: 4.374849 - 1s
# Epoch 36/501
# discriminator: -0.932692 - generator: 4.454612 - 1s
# Epoch 37/501
# discriminator: -0.930741 - generator: 4.412714 - 1s
# Epoch 38/501
# discriminator: -0.922115 - generator: 4.542807 - 1s
# Epoch 39/501
# discriminator: -0.909145 - generator: 4.445308 - 1s
# Epoch 40/501
# discriminator: -0.878440 - generator: 4.546239 - 1s
# Epoch 41/501
# discriminator: -0.926156 - generator: 4.533979 - 1s
# Epoch 42/501
# discriminator: -0.900726 - generator: 4.499969 - 1s
# Epoch 43/501
# discriminator: -0.878055 - generator: 4.539291 - 1s
# Epoch 44/501
# discriminator: -0.874861 - generator: 4.424446 - 1s
# Epoch 45/501
# discriminator: -0.916947 - generator: 4.419556 - 1s
# Epoch 46/501
# discriminator: -0.863711 - generator: 4.415779 - 1s
# Epoch 47/501
# discriminator: -0.877606 - generator: 4.235419 - 1s
# Epoch 48/501
# discriminator: -0.856756 - generator: 4.321648 - 1s
# Epoch 49/501
# discriminator: -0.841903 - generator: 4.306283 - 1s
# Epoch 50/501
# discriminator: -0.819424 - generator: 4.386512 - 1s
# Epoch 51/501
# discriminator: -0.837023 - generator: 4.465114 - 1s
# Epoch 52/501
# discriminator: -0.789328 - generator: 4.356732 - 1s
# Epoch 53/501
# discriminator: -0.821966 - generator: 4.344272 - 1s
# Epoch 54/501
# discriminator: -0.781265 - generator: 4.252421 - 1s
# Epoch 55/501
# discriminator: -0.774846 - generator: 4.282236 - 1s
# Epoch 56/501
# discriminator: -0.730162 - generator: 4.292427 - 1s
# Epoch 57/501
# discriminator: -0.758438 - generator: 4.099793 - 1s
# Epoch 58/501
# discriminator: -0.715950 - generator: 4.042451 - 1s
# Epoch 59/501
# discriminator: -0.725212 - generator: 4.182222 - 1s
# Epoch 60/501
# discriminator: -0.750980 - generator: 4.191198 - 1s
# Epoch 61/501
# discriminator: -0.657496 - generator: 4.216323 - 1s
# Epoch 62/501
# discriminator: -0.747011 - generator: 4.196968 - 1s
# Epoch 63/501
# discriminator: -0.701799 - generator: 4.226189 - 1s
# Epoch 64/501
# discriminator: -0.719981 - generator: 4.206129 - 1s
# Epoch 65/501
# discriminator: -0.665005 - generator: 4.166935 - 1s
# Epoch 66/501
# discriminator: -0.651619 - generator: 4.112305 - 1s
# Epoch 67/501
# discriminator: -0.644187 - generator: 4.117056 - 1s
# Epoch 68/501
# discriminator: -0.640085 - generator: 4.133038 - 1s
# Epoch 69/501
# discriminator: -0.636977 - generator: 4.152658 - 1s
# Epoch 70/501
# discriminator: -0.614374 - generator: 4.229077 - 1s
# Epoch 71/501
# discriminator: -0.700930 - generator: 4.261784 - 1s
# Epoch 72/501
# discriminator: -0.648445 - generator: 4.276376 - 1s
# Epoch 73/501
# discriminator: -0.618897 - generator: 4.214413 - 1s
# Epoch 74/501
# discriminator: -0.633541 - generator: 4.141945 - 1s
# Epoch 75/501
# discriminator: -0.627853 - generator: 4.074251 - 1s
# Epoch 76/501
# discriminator: -0.573239 - generator: 4.046416 - 1s
# Epoch 77/501
# discriminator: -0.572598 - generator: 4.002877 - 1s
# Epoch 78/501
# discriminator: -0.552683 - generator: 4.042438 - 1s
# Epoch 79/501
# discriminator: -0.597228 - generator: 4.152720 - 1s
# Epoch 80/501
# discriminator: -0.549026 - generator: 4.026498 - 1s
# Epoch 81/501
# discriminator: -0.573464 - generator: 4.132030 - 1s
# Epoch 82/501
# discriminator: -0.549230 - generator: 4.013396 - 1s
# Epoch 83/501
# discriminator: -0.574075 - generator: 4.091646 - 1s
# Epoch 84/501
# discriminator: -0.536619 - generator: 4.074266 - 1s
# Epoch 85/501
# discriminator: -0.556177 - generator: 3.965558 - 1s
# Epoch 86/501
# discriminator: -0.572548 - generator: 4.026375 - 1s
# Epoch 87/501
# discriminator: -0.561727 - generator: 4.010247 - 1s
# Epoch 88/501
# discriminator: -0.534613 - generator: 4.038332 - 1s
# Epoch 89/501
# discriminator: -0.545648 - generator: 3.989260 - 1s
# Epoch 90/501
# discriminator: -0.551421 - generator: 4.035716 - 1s
# Epoch 91/501
# discriminator: -0.541285 - generator: 3.860476 - 1s
# Epoch 92/501
# discriminator: -0.525114 - generator: 3.958334 - 1s
# Epoch 93/501
# discriminator: -0.542448 - generator: 4.044482 - 1s
# Epoch 94/501
# discriminator: -0.547694 - generator: 4.069313 - 1s
# Epoch 95/501
# discriminator: -0.539596 - generator: 3.947529 - 1s
# Epoch 96/501
# discriminator: -0.529747 - generator: 4.121740 - 1s
# Epoch 97/501
# discriminator: -0.536100 - generator: 4.036240 - 1s
# Epoch 98/501
# discriminator: -0.573617 - generator: 4.069969 - 1s
# Epoch 99/501
# discriminator: -0.550695 - generator: 4.053726 - 1s
# Epoch 100/501
# discriminator: -0.551701 - generator: 4.012167 - 1s
# Epoch 101/501
# discriminator: -0.532244 - generator: 4.058795 - 1s
# Loss:
# Epoch 102/501
# discriminator: -0.509973 - generator: 4.060935 - 1s
# Epoch 103/501
# discriminator: -0.501433 - generator: 3.982689 - 1s
# Epoch 104/501
# discriminator: -0.564164 - generator: 3.938602 - 1s
# Epoch 105/501
# discriminator: -0.517884 - generator: 3.917367 - 1s
# Epoch 106/501
# discriminator: -0.511165 - generator: 3.833917 - 1s
# Epoch 107/501
# discriminator: -0.492736 - generator: 3.894279 - 1s
# Epoch 108/501
# discriminator: -0.525406 - generator: 3.889263 - 1s
# Epoch 109/501
# discriminator: -0.481401 - generator: 3.873826 - 1s
# Epoch 110/501
# discriminator: -0.465137 - generator: 3.876718 - 1s
# Epoch 111/501
# discriminator: -0.495047 - generator: 3.806140 - 1s
# Epoch 112/501
# discriminator: -0.501836 - generator: 3.763299 - 1s
# Epoch 113/501
# discriminator: -0.543930 - generator: 3.831529 - 1s
# Epoch 114/501
# discriminator: -0.482017 - generator: 3.802506 - 1s
# Epoch 115/501
# discriminator: -0.458583 - generator: 3.847258 - 1s
# Epoch 116/501
# discriminator: -0.479276 - generator: 3.814016 - 1s
# Epoch 117/501
# discriminator: -0.510775 - generator: 3.841263 - 1s
# Epoch 118/501
# discriminator: -0.445464 - generator: 3.925075 - 1s
# Epoch 119/501
# discriminator: -0.467860 - generator: 3.956010 - 1s
# Epoch 120/501
# discriminator: -0.464708 - generator: 3.899664 - 1s
# Epoch 121/501
# discriminator: -0.467512 - generator: 3.889480 - 1s
# Epoch 122/501
# discriminator: -0.443212 - generator: 3.821792 - 1s
# Epoch 123/501
# discriminator: -0.497306 - generator: 3.766874 - 1s
# Epoch 124/501
# discriminator: -0.454532 - generator: 3.830954 - 1s
# Epoch 125/501
# discriminator: -0.490241 - generator: 3.926622 - 1s
# Epoch 126/501
# discriminator: -0.477816 - generator: 3.987868 - 1s
# Epoch 127/501
# discriminator: -0.464483 - generator: 4.034861 - 1s
# Epoch 128/501
# discriminator: -0.448543 - generator: 3.924256 - 1s
# Epoch 129/501
# discriminator: -0.478718 - generator: 3.900649 - 1s
# Epoch 130/501
# discriminator: -0.452099 - generator: 3.883187 - 1s
# Epoch 131/501
# discriminator: -0.474965 - generator: 3.902784 - 1s
# Epoch 132/501
# discriminator: -0.444031 - generator: 3.831909 - 1s
# Epoch 133/501
# discriminator: -0.492615 - generator: 3.833811 - 1s
# Epoch 134/501
# discriminator: -0.449242 - generator: 3.824344 - 1s
# Epoch 135/501
# discriminator: -0.448333 - generator: 3.825986 - 1s
# Epoch 136/501
# discriminator: -0.461122 - generator: 3.897648 - 1s
# Epoch 137/501
# discriminator: -0.476914 - generator: 3.948948 - 1s
# Epoch 138/501
# discriminator: -0.462020 - generator: 3.904066 - 1s
# Epoch 139/501
# discriminator: -0.481202 - generator: 3.874984 - 1s
# Epoch 140/501
# discriminator: -0.437101 - generator: 4.013838 - 1s
# Epoch 141/501
# discriminator: -0.438576 - generator: 3.951573 - 1s
# Epoch 142/501
# discriminator: -0.436602 - generator: 3.929352 - 1s
# Epoch 143/501
# discriminator: -0.449968 - generator: 3.882707 - 1s
# Epoch 144/501
# discriminator: -0.425962 - generator: 3.914607 - 1s
# Epoch 145/501
# discriminator: -0.470512 - generator: 3.848971 - 1s
# Epoch 146/501
# discriminator: -0.442430 - generator: 3.934564 - 1s
# Epoch 147/501
# discriminator: -0.426289 - generator: 3.932720 - 1s
# Epoch 148/501
# discriminator: -0.450066 - generator: 3.955948 - 1s
# Epoch 149/501
# discriminator: -0.400768 - generator: 3.890141 - 1s
# Epoch 150/501
# discriminator: -0.434732 - generator: 3.982133 - 1s
# Epoch 151/501
# discriminator: -0.422951 - generator: 3.970740 - 1s
# Epoch 152/501
# discriminator: -0.407424 - generator: 4.007274 - 1s
# Epoch 153/501
# discriminator: -0.451934 - generator: 4.011422 - 1s
# Epoch 154/501
# discriminator: -0.421887 - generator: 4.043956 - 1s
# Epoch 155/501
# discriminator: -0.415865 - generator: 4.048878 - 1s
# Epoch 156/501
# discriminator: -0.423476 - generator: 3.997132 - 1s
# Epoch 157/501
# discriminator: -0.444591 - generator: 4.052756 - 1s
# Epoch 158/501
# discriminator: -0.384288 - generator: 4.071108 - 1s
# Epoch 159/501
# discriminator: -0.378842 - generator: 3.950002 - 1s
# Epoch 160/501
# discriminator: -0.390472 - generator: 4.044152 - 1s
# Epoch 161/501
# discriminator: -0.419314 - generator: 3.919271 - 1s
# Epoch 162/501
# discriminator: -0.414805 - generator: 4.008616 - 1s
# Epoch 163/501
# discriminator: -0.386801 - generator: 4.109042 - 1s
# Epoch 164/501
# discriminator: -0.375838 - generator: 4.107375 - 1s
# Epoch 165/501
# discriminator: -0.380273 - generator: 4.034116 - 1s
# Epoch 166/501
# discriminator: -0.397082 - generator: 4.014080 - 1s
# Epoch 167/501
# discriminator: -0.420151 - generator: 4.021920 - 1s
# Epoch 168/501
# discriminator: -0.394935 - generator: 4.098482 - 1s
# Epoch 169/501
# discriminator: -0.404950 - generator: 4.007024 - 1s
# Epoch 170/501
# discriminator: -0.376089 - generator: 4.082498 - 1s
# Epoch 171/501
# discriminator: -0.411491 - generator: 4.082133 - 1s
# Epoch 172/501
# discriminator: -0.342937 - generator: 4.178724 - 1s
# Epoch 173/501
# discriminator: -0.347819 - generator: 4.076937 - 1s
# Epoch 174/501
# discriminator: -0.368376 - generator: 4.077929 - 1s
# Epoch 175/501
# discriminator: -0.405210 - generator: 4.145279 - 1s
# Epoch 176/501
# discriminator: -0.381399 - generator: 4.085433 - 1s
# Epoch 177/501
# discriminator: -0.365559 - generator: 4.031812 - 1s
# Epoch 178/501
# discriminator: -0.408994 - generator: 4.047696 - 1s
# Epoch 179/501
# discriminator: -0.418062 - generator: 4.078949 - 1s
# Epoch 180/501
# discriminator: -0.406214 - generator: 4.078793 - 1s
# Epoch 181/501
# discriminator: -0.370483 - generator: 4.173811 - 1s
# Epoch 182/501
# discriminator: -0.381588 - generator: 4.137649 - 1s
# Epoch 183/501
# discriminator: -0.392464 - generator: 4.216117 - 1s
# Epoch 184/501
# discriminator: -0.423903 - generator: 4.186330 - 1s
# Epoch 185/501
# discriminator: -0.401405 - generator: 4.108212 - 1s
# Epoch 186/501
# discriminator: -0.377766 - generator: 4.201080 - 1s
# Epoch 187/501
# discriminator: -0.377071 - generator: 4.183770 - 1s
# Epoch 188/501
# discriminator: -0.378543 - generator: 4.092156 - 1s
# Epoch 189/501
# discriminator: -0.377629 - generator: 4.156407 - 1s
# Epoch 190/501
# discriminator: -0.455270 - generator: 4.245496 - 1s
# Epoch 191/501
# discriminator: -0.372431 - generator: 4.163471 - 1s
# Epoch 192/501
# discriminator: -0.395974 - generator: 4.131224 - 1s
# Epoch 193/501
# discriminator: -0.356889 - generator: 4.147268 - 1s
# Epoch 194/501
# discriminator: -0.331857 - generator: 4.094627 - 1s
# Epoch 195/501
# discriminator: -0.367435 - generator: 4.099446 - 1s
# Epoch 196/501
# discriminator: -0.390432 - generator: 4.163061 - 1s
# Epoch 197/501
# discriminator: -0.391962 - generator: 4.269943 - 1s
# Epoch 198/501
# discriminator: -0.356596 - generator: 4.342077 - 1s
# Epoch 199/501
# discriminator: -0.388672 - generator: 4.361444 - 1s
# Epoch 200/501
# discriminator: -0.337001 - generator: 4.409490 - 1s
# Epoch 201/501
# discriminator: -0.381216 - generator: 4.411582 - 1s
# Loss:
# Epoch 202/501
# discriminator: -0.343404 - generator: 4.307749 - 1s
# Epoch 203/501
# discriminator: -0.360315 - generator: 4.352236 - 1s
# Epoch 204/501
# discriminator: -0.369008 - generator: 4.410439 - 1s
# Epoch 205/501
# discriminator: -0.386214 - generator: 4.412870 - 1s
# Epoch 206/501
# discriminator: -0.373085 - generator: 4.391543 - 1s
# Epoch 207/501
# discriminator: -0.329807 - generator: 4.379506 - 1s
# Epoch 208/501
# discriminator: -0.332169 - generator: 4.356668 - 1s
# Epoch 209/501
# discriminator: -0.352664 - generator: 4.358788 - 1s
# Epoch 210/501
# discriminator: -0.361409 - generator: 4.365376 - 1s
# Epoch 211/501
# discriminator: -0.354860 - generator: 4.412438 - 1s
# Epoch 212/501
# discriminator: -0.375651 - generator: 4.330991 - 1s
# Epoch 213/501
# discriminator: -0.346503 - generator: 4.419190 - 1s
# Epoch 214/501
# discriminator: -0.375074 - generator: 4.448745 - 1s
# Epoch 215/501
# discriminator: -0.321998 - generator: 4.463293 - 1s
# Epoch 216/501
# discriminator: -0.342722 - generator: 4.439540 - 1s
# Epoch 217/501
# discriminator: -0.355614 - generator: 4.414068 - 1s
# Epoch 218/501
# discriminator: -0.344751 - generator: 4.401519 - 1s
# Epoch 219/501
# discriminator: -0.316274 - generator: 4.426242 - 1s
# Epoch 220/501
# discriminator: -0.333473 - generator: 4.428957 - 1s
# Epoch 221/501
# discriminator: -0.337643 - generator: 4.395153 - 1s
# Epoch 222/501
# discriminator: -0.356848 - generator: 4.417078 - 1s
# Epoch 223/501
# discriminator: -0.300683 - generator: 4.392268 - 1s
# Epoch 224/501
# discriminator: -0.325077 - generator: 4.379262 - 1s
# Epoch 225/501
# discriminator: -0.286897 - generator: 4.369184 - 1s
# Epoch 226/501
# discriminator: -0.326886 - generator: 4.343499 - 1s
# Epoch 227/501
# discriminator: -0.312368 - generator: 4.353597 - 1s
# Epoch 228/501
# discriminator: -0.377702 - generator: 4.300316 - 1s
# Epoch 229/501
# discriminator: -0.322439 - generator: 4.352977 - 1s
# Epoch 230/501
# discriminator: -0.305321 - generator: 4.281488 - 1s
# Epoch 231/501
# discriminator: -0.371685 - generator: 4.153393 - 1s
# Epoch 232/501
# discriminator: -0.302287 - generator: 4.216379 - 1s
# Epoch 233/501
# discriminator: -0.338013 - generator: 4.228775 - 1s
# Epoch 234/501
# discriminator: -0.317188 - generator: 4.304754 - 1s
# Epoch 235/501
# discriminator: -0.318381 - generator: 4.255475 - 1s
# Epoch 236/501
# discriminator: -0.322819 - generator: 4.245371 - 1s
# Epoch 237/501
# discriminator: -0.335048 - generator: 4.308868 - 1s
# Epoch 238/501
# discriminator: -0.326982 - generator: 4.349727 - 1s
# Epoch 239/501
# discriminator: -0.320788 - generator: 4.345634 - 1s
# Epoch 240/501
# discriminator: -0.313741 - generator: 4.424696 - 1s
# Epoch 241/501
# discriminator: -0.312239 - generator: 4.370423 - 1s
# Epoch 242/501
# discriminator: -0.326051 - generator: 4.389426 - 1s
# Epoch 243/501
# discriminator: -0.325824 - generator: 4.302917 - 1s
# Epoch 244/501
# discriminator: -0.344888 - generator: 4.292836 - 1s
# Epoch 245/501
# discriminator: -0.323651 - generator: 4.279548 - 1s
# Epoch 246/501
# discriminator: -0.303094 - generator: 4.292405 - 1s
# Epoch 247/501
# discriminator: -0.280357 - generator: 4.385714 - 1s
# Epoch 248/501
# discriminator: -0.360848 - generator: 4.280829 - 1s
# Epoch 249/501
# discriminator: -0.296926 - generator: 4.315003 - 1s
# Epoch 250/501
# discriminator: -0.299211 - generator: 4.367349 - 1s
# Epoch 251/501
# discriminator: -0.244770 - generator: 4.365447 - 1s
# Epoch 252/501
# discriminator: -0.286976 - generator: 4.423808 - 1s
# Epoch 253/501
# discriminator: -0.283119 - generator: 4.450877 - 1s
# Epoch 254/501
# discriminator: -0.345709 - generator: 4.428916 - 1s
# Epoch 255/501
# discriminator: -0.321132 - generator: 4.486510 - 1s
# Epoch 256/501
# discriminator: -0.308770 - generator: 4.414908 - 1s
# Epoch 257/501
# discriminator: -0.307798 - generator: 4.447114 - 1s
# Epoch 258/501
# discriminator: -0.301664 - generator: 4.441006 - 1s
# Epoch 259/501
# discriminator: -0.311799 - generator: 4.469775 - 1s
# Epoch 260/501
# discriminator: -0.279819 - generator: 4.398825 - 1s
# Epoch 261/501
# discriminator: -0.318973 - generator: 4.448353 - 1s
# Epoch 262/501
# discriminator: -0.283870 - generator: 4.470982 - 1s
# Epoch 263/501
# discriminator: -0.254068 - generator: 4.518128 - 1s
# Epoch 264/501
# discriminator: -0.273678 - generator: 4.471829 - 1s
# Epoch 265/501
# discriminator: -0.303215 - generator: 4.454988 - 1s
# Epoch 266/501
# discriminator: -0.304962 - generator: 4.470096 - 1s
# Epoch 267/501
# discriminator: -0.284636 - generator: 4.509148 - 1s
# Epoch 268/501
# discriminator: -0.288182 - generator: 4.488485 - 1s
# Epoch 269/501
# discriminator: -0.245910 - generator: 4.504638 - 1s
# Epoch 270/501
# discriminator: -0.276604 - generator: 4.486505 - 1s
# Epoch 271/501
# discriminator: -0.307155 - generator: 4.478390 - 1s
# Epoch 272/501
# discriminator: -0.268086 - generator: 4.462600 - 1s
# Epoch 273/501
# discriminator: -0.315106 - generator: 4.413949 - 1s
# Epoch 274/501
# discriminator: -0.280150 - generator: 4.420362 - 1s
# Epoch 275/501
# discriminator: -0.287935 - generator: 4.436711 - 1s
# Epoch 276/501
# discriminator: -0.309605 - generator: 4.428513 - 1s
# Epoch 277/501
# discriminator: -0.282632 - generator: 4.440562 - 1s
# Epoch 278/501
# discriminator: -0.279223 - generator: 4.479995 - 1s
# Epoch 279/501
# discriminator: -0.283161 - generator: 4.525904 - 1s
# Epoch 280/501
# discriminator: -0.243495 - generator: 4.492143 - 1s
# Epoch 281/501
# discriminator: -0.274529 - generator: 4.566407 - 1s
# Epoch 282/501
# discriminator: -0.267591 - generator: 4.514937 - 1s
# Epoch 283/501
# discriminator: -0.267118 - generator: 4.467673 - 1s
# Epoch 284/501
# discriminator: -0.277534 - generator: 4.483118 - 1s
# Epoch 285/501
# discriminator: -0.308586 - generator: 4.463632 - 1s
# Epoch 286/501
# discriminator: -0.241545 - generator: 4.438996 - 1s
# Epoch 287/501
# discriminator: -0.291398 - generator: 4.440493 - 1s
# Epoch 288/501
# discriminator: -0.278341 - generator: 4.471968 - 1s
# Epoch 289/501
# discriminator: -0.286952 - generator: 4.490910 - 1s
# Epoch 290/501
# discriminator: -0.315418 - generator: 4.597993 - 1s
# Epoch 291/501
# discriminator: -0.266667 - generator: 4.565305 - 1s
# Epoch 292/501
# discriminator: -0.254561 - generator: 4.611066 - 1s
# Epoch 293/501
# discriminator: -0.262731 - generator: 4.669912 - 1s
# Epoch 294/501
# discriminator: -0.219820 - generator: 4.644760 - 1s
# Epoch 295/501
# discriminator: -0.258595 - generator: 4.623161 - 1s
# Epoch 296/501
# discriminator: -0.293811 - generator: 4.674428 - 1s
# Epoch 297/501
# discriminator: -0.230681 - generator: 4.629749 - 1s
# Epoch 298/501
# discriminator: -0.289349 - generator: 4.536026 - 1s
# Epoch 299/501
# discriminator: -0.250276 - generator: 4.581616 - 1s
# Epoch 300/501
# discriminator: -0.228305 - generator: 4.562273 - 1s
# Epoch 301/501
# discriminator: -0.304020 - generator: 4.602296 - 1s
# Loss:
# Epoch 302/501
# discriminator: -0.295150 - generator: 4.618282 - 1s
# Epoch 303/501
# discriminator: -0.205509 - generator: 4.554904 - 1s
# Epoch 304/501
# discriminator: -0.287917 - generator: 4.601878 - 1s
# Epoch 305/501
# discriminator: -0.287181 - generator: 4.596894 - 1s
# Epoch 306/501
# discriminator: -0.255692 - generator: 4.659319 - 1s
# Epoch 307/501
# discriminator: -0.294052 - generator: 4.639187 - 1s
# Epoch 308/501
# discriminator: -0.284396 - generator: 4.604842 - 1s
# Epoch 309/501
# discriminator: -0.283071 - generator: 4.601017 - 1s
# Epoch 310/501
# discriminator: -0.288811 - generator: 4.558394 - 1s
# Epoch 311/501
# discriminator: -0.232588 - generator: 4.680040 - 1s
# Epoch 312/501
# discriminator: -0.211332 - generator: 4.649847 - 1s
# Epoch 313/501
# discriminator: -0.276993 - generator: 4.626652 - 1s
# Epoch 314/501
# discriminator: -0.251175 - generator: 4.617827 - 1s
# Epoch 315/501
# discriminator: -0.251033 - generator: 4.629295 - 1s
# Epoch 316/501
# discriminator: -0.258157 - generator: 4.575247 - 1s
# Epoch 317/501
# discriminator: -0.263766 - generator: 4.565620 - 1s
# Epoch 318/501
# discriminator: -0.258758 - generator: 4.557206 - 1s
# Epoch 319/501
# discriminator: -0.243008 - generator: 4.541473 - 1s
# Epoch 320/501
# discriminator: -0.238569 - generator: 4.556303 - 1s
# Epoch 321/501
# discriminator: -0.230095 - generator: 4.586061 - 1s
# Epoch 322/501
# discriminator: -0.195547 - generator: 4.584532 - 1s
# Epoch 323/501
# discriminator: -0.281046 - generator: 4.592943 - 1s
# Epoch 324/501
# discriminator: -0.257193 - generator: 4.648706 - 1s
# Epoch 325/501
# discriminator: -0.245713 - generator: 4.651764 - 1s
# Epoch 326/501
# discriminator: -0.218724 - generator: 4.614500 - 1s
# Epoch 327/501
# discriminator: -0.238706 - generator: 4.522116 - 1s
# Epoch 328/501
# discriminator: -0.264726 - generator: 4.564441 - 1s
# Epoch 329/501
# discriminator: -0.254193 - generator: 4.557290 - 1s
# Epoch 330/501
# discriminator: -0.232441 - generator: 4.606591 - 1s
# Epoch 331/501
# discriminator: -0.242077 - generator: 4.614301 - 1s
# Epoch 332/501
# discriminator: -0.216705 - generator: 4.644973 - 1s
# Epoch 333/501
# discriminator: -0.224930 - generator: 4.651387 - 1s
# Epoch 334/501
# discriminator: -0.253547 - generator: 4.709205 - 1s
# Epoch 335/501
# discriminator: -0.273631 - generator: 4.689238 - 1s
# Epoch 336/501
# discriminator: -0.228203 - generator: 4.718888 - 1s
# Epoch 337/501
# discriminator: -0.277346 - generator: 4.707090 - 1s
# Epoch 338/501
# discriminator: -0.270115 - generator: 4.721233 - 1s
# Epoch 339/501
# discriminator: -0.277207 - generator: 4.707870 - 1s
# Epoch 340/501
# discriminator: -0.233765 - generator: 4.693908 - 1s
# Epoch 341/501
# discriminator: -0.221567 - generator: 4.740254 - 1s
# Epoch 342/501
# discriminator: -0.256949 - generator: 4.678902 - 1s
# Epoch 343/501
# discriminator: -0.253939 - generator: 4.813818 - 1s
# Epoch 344/501
# discriminator: -0.223638 - generator: 4.788454 - 1s
# Epoch 345/501
# discriminator: -0.220450 - generator: 4.758396 - 1s
# Epoch 346/501
# discriminator: -0.210105 - generator: 4.798887 - 1s
# Epoch 347/501
# discriminator: -0.197647 - generator: 4.768467 - 1s
# Epoch 348/501
# discriminator: -0.235826 - generator: 4.901584 - 1s
# Epoch 349/501
# discriminator: -0.247715 - generator: 4.910473 - 1s
# Epoch 350/501
# discriminator: -0.232371 - generator: 4.975537 - 1s
# Epoch 351/501
# discriminator: -0.211347 - generator: 4.965234 - 1s
# Epoch 352/501
# discriminator: -0.245393 - generator: 4.903042 - 1s
# Epoch 353/501
# discriminator: -0.210127 - generator: 4.822755 - 1s
# Epoch 354/501
# discriminator: -0.221438 - generator: 4.887359 - 1s
# Epoch 355/501
# discriminator: -0.199775 - generator: 4.817333 - 1s
# Epoch 356/501
# discriminator: -0.230981 - generator: 4.805202 - 1s
# Epoch 357/501
# discriminator: -0.235441 - generator: 4.788379 - 1s
# Epoch 358/501
# discriminator: -0.211095 - generator: 4.794507 - 1s
# Epoch 359/501
# discriminator: -0.213949 - generator: 4.730914 - 1s
# Epoch 360/501
# discriminator: -0.248718 - generator: 4.799918 - 1s
# Epoch 361/501
# discriminator: -0.187405 - generator: 4.815718 - 1s
# Epoch 362/501
# discriminator: -0.227875 - generator: 4.853716 - 1s
# Epoch 363/501
# discriminator: -0.247241 - generator: 4.879247 - 1s
# Epoch 364/501
# discriminator: -0.212777 - generator: 4.932358 - 1s
# Epoch 365/501
# discriminator: -0.238288 - generator: 4.900784 - 1s
# Epoch 366/501
# discriminator: -0.233731 - generator: 4.948548 - 1s
# Epoch 367/501
# discriminator: -0.229248 - generator: 4.999999 - 1s
# Epoch 368/501
# discriminator: -0.262870 - generator: 4.982681 - 1s
# Epoch 369/501
# discriminator: -0.165656 - generator: 5.004124 - 1s
# Epoch 370/501
# discriminator: -0.224127 - generator: 4.998364 - 1s
# Epoch 371/501
# discriminator: -0.205980 - generator: 4.957588 - 1s
# Epoch 372/501
# discriminator: -0.234421 - generator: 4.956894 - 1s
# Epoch 373/501
# discriminator: -0.216165 - generator: 4.969925 - 1s
# Epoch 374/501
# discriminator: -0.229988 - generator: 4.985790 - 1s
# Epoch 375/501
# discriminator: -0.228833 - generator: 4.987920 - 1s
# Epoch 376/501
# discriminator: -0.211038 - generator: 4.952499 - 1s
# Epoch 377/501
# discriminator: -0.237748 - generator: 4.935791 - 1s
# Epoch 378/501
# discriminator: -0.263861 - generator: 4.970191 - 1s
# Epoch 379/501
# discriminator: -0.171405 - generator: 4.917559 - 1s
# Epoch 380/501
# discriminator: -0.198199 - generator: 4.890358 - 1s
# Epoch 381/501
# discriminator: -0.193196 - generator: 4.854096 - 1s
# Epoch 382/501
# discriminator: -0.224688 - generator: 4.840710 - 1s
# Epoch 383/501
# discriminator: -0.242203 - generator: 4.900274 - 1s
# Epoch 384/501
# discriminator: -0.212442 - generator: 4.969594 - 1s
# Epoch 385/501
# discriminator: -0.197565 - generator: 4.994237 - 1s
# Epoch 386/501
# discriminator: -0.231980 - generator: 4.911857 - 1s
# Epoch 387/501
# discriminator: -0.196076 - generator: 4.941453 - 1s
# Epoch 388/501
# discriminator: -0.226015 - generator: 5.013350 - 1s
# Epoch 389/501
# discriminator: -0.247705 - generator: 5.008227 - 1s
# Epoch 390/501
# discriminator: -0.212812 - generator: 5.016198 - 1s
# Epoch 391/501
# discriminator: -0.236328 - generator: 5.010137 - 1s
# Epoch 392/501
# discriminator: -0.236682 - generator: 5.021107 - 1s
# Epoch 393/501
# discriminator: -0.193111 - generator: 5.013939 - 1s
# Epoch 394/501
# discriminator: -0.257592 - generator: 5.050055 - 1s
# Epoch 395/501
# discriminator: -0.234863 - generator: 5.075534 - 1s
# Epoch 396/501
# discriminator: -0.229687 - generator: 5.094070 - 1s
# Epoch 397/501
# discriminator: -0.266943 - generator: 5.172349 - 1s
# Epoch 398/501
# discriminator: -0.227597 - generator: 5.144236 - 1s
# Epoch 399/501
# discriminator: -0.225294 - generator: 5.142599 - 1s
# Epoch 400/501
# discriminator: -0.237075 - generator: 5.187362 - 1s
# Epoch 401/501
# discriminator: -0.196826 - generator: 5.178932 - 1s
# Loss:
# Epoch 402/501
# discriminator: -0.217245 - generator: 5.155207 - 1s
# Epoch 403/501
# discriminator: -0.199838 - generator: 5.044986 - 1s
# Epoch 404/501
# discriminator: -0.212360 - generator: 5.105858 - 1s
# Epoch 405/501
# discriminator: -0.210822 - generator: 5.118563 - 1s
# Epoch 406/501
# discriminator: -0.214805 - generator: 5.094791 - 1s
# Epoch 407/501
# discriminator: -0.202070 - generator: 5.083467 - 1s
# Epoch 408/501
# discriminator: -0.232544 - generator: 5.062707 - 1s
# Epoch 409/501
# discriminator: -0.249523 - generator: 5.109531 - 1s
# Epoch 410/501
# discriminator: -0.222224 - generator: 5.086576 - 1s
# Epoch 411/501
# discriminator: -0.211478 - generator: 5.063677 - 1s
# Epoch 412/501
# discriminator: -0.233879 - generator: 5.083593 - 1s
# Epoch 413/501
# discriminator: -0.224688 - generator: 5.086459 - 1s
# Epoch 414/501
# discriminator: -0.217919 - generator: 5.120136 - 1s
# Epoch 415/501
# discriminator: -0.230035 - generator: 5.158056 - 1s
# Epoch 416/501
# discriminator: -0.184053 - generator: 5.192276 - 1s
# Epoch 417/501
# discriminator: -0.253318 - generator: 5.183114 - 1s
# Epoch 418/501
# discriminator: -0.209136 - generator: 5.187783 - 1s
# Epoch 419/501
# discriminator: -0.211949 - generator: 5.173379 - 1s
# Epoch 420/501
# discriminator: -0.206023 - generator: 5.139137 - 1s
# Epoch 421/501
# discriminator: -0.220571 - generator: 5.172458 - 1s
# Epoch 422/501
# discriminator: -0.220574 - generator: 5.214251 - 1s
# Epoch 423/501
# discriminator: -0.189589 - generator: 5.212563 - 1s
# Epoch 424/501
# discriminator: -0.210778 - generator: 5.148705 - 1s
# Epoch 425/501
# discriminator: -0.227475 - generator: 5.171848 - 1s
# Epoch 426/501
# discriminator: -0.242603 - generator: 5.192421 - 1s
# Epoch 427/501
# discriminator: -0.219345 - generator: 5.174132 - 1s
# Epoch 428/501
# discriminator: -0.172622 - generator: 5.191310 - 1s
# Epoch 429/501
# discriminator: -0.175397 - generator: 5.207048 - 1s
# Epoch 430/501
# discriminator: -0.200794 - generator: 5.219084 - 1s
# Epoch 431/501
# discriminator: -0.227415 - generator: 5.223241 - 1s
# Epoch 432/501
# discriminator: -0.176508 - generator: 5.153791 - 1s
# Epoch 433/501
# discriminator: -0.187501 - generator: 5.134382 - 1s
# Epoch 434/501
# discriminator: -0.204117 - generator: 5.177763 - 1s
# Epoch 435/501
# discriminator: -0.206752 - generator: 5.179495 - 1s
# Epoch 436/501
# discriminator: -0.247439 - generator: 5.216146 - 1s
# Epoch 437/501
# discriminator: -0.195474 - generator: 5.172681 - 1s
# Epoch 438/501
# discriminator: -0.188477 - generator: 5.168976 - 1s
# Epoch 439/501
# discriminator: -0.202176 - generator: 5.290277 - 1s
# Epoch 440/501
# discriminator: -0.176399 - generator: 5.251957 - 1s
# Epoch 441/501
# discriminator: -0.196733 - generator: 5.222692 - 1s
# Epoch 442/501
# discriminator: -0.194169 - generator: 5.258604 - 1s
# Epoch 443/501
# discriminator: -0.227589 - generator: 5.214841 - 1s
# Epoch 444/501
# discriminator: -0.186686 - generator: 5.197312 - 1s
# Epoch 445/501
# discriminator: -0.191820 - generator: 5.218246 - 1s
# Epoch 446/501
# discriminator: -0.192213 - generator: 5.170489 - 1s
# Epoch 447/501
# discriminator: -0.219288 - generator: 5.136506 - 1s
# Epoch 448/501
# discriminator: -0.177968 - generator: 5.073372 - 1s
# Epoch 449/501
# discriminator: -0.205883 - generator: 5.113285 - 1s
# Epoch 450/501
# discriminator: -0.208414 - generator: 5.082403 - 1s
# Epoch 451/501
# discriminator: -0.199474 - generator: 5.096189 - 1s
# Epoch 452/501
# discriminator: -0.192713 - generator: 5.128023 - 1s
# Epoch 453/501
# discriminator: -0.204692 - generator: 5.127722 - 1s
# Epoch 454/501
# discriminator: -0.212388 - generator: 5.153609 - 1s
# Epoch 455/501
# discriminator: -0.203846 - generator: 5.185213 - 1s
# Epoch 456/501
# discriminator: -0.157227 - generator: 5.112153 - 1s
# Epoch 457/501
# discriminator: -0.187805 - generator: 5.161738 - 1s
# Epoch 458/501
# discriminator: -0.202678 - generator: 5.154898 - 1s
# Epoch 459/501
# discriminator: -0.226285 - generator: 5.107237 - 1s
# Epoch 460/501
# discriminator: -0.195307 - generator: 5.128160 - 1s
# Epoch 461/501
# discriminator: -0.196774 - generator: 5.078639 - 1s
# Epoch 462/501
# discriminator: -0.217462 - generator: 5.081177 - 1s
# Epoch 463/501
# discriminator: -0.196322 - generator: 5.083719 - 1s
# Epoch 464/501
# discriminator: -0.214909 - generator: 5.102062 - 1s
# Epoch 465/501
# discriminator: -0.172093 - generator: 5.083333 - 1s
# Epoch 466/501
# discriminator: -0.216228 - generator: 5.138969 - 1s
# Epoch 467/501
# discriminator: -0.196262 - generator: 5.141839 - 1s
# Epoch 468/501
# discriminator: -0.236797 - generator: 5.171629 - 1s
# Epoch 469/501
# discriminator: -0.196933 - generator: 5.173451 - 1s
# Epoch 470/501
# discriminator: -0.238503 - generator: 5.221159 - 1s
# Epoch 471/501
# discriminator: -0.174936 - generator: 5.295028 - 1s
# Epoch 472/501
# discriminator: -0.167596 - generator: 5.239600 - 1s
# Epoch 473/501
# discriminator: -0.220117 - generator: 5.219431 - 1s
# Epoch 474/501
# discriminator: -0.194361 - generator: 5.142297 - 1s
# Epoch 475/501
# discriminator: -0.192115 - generator: 5.087053 - 1s
# Epoch 476/501
# discriminator: -0.194011 - generator: 5.143173 - 1s
# Epoch 477/501
# discriminator: -0.166542 - generator: 5.190531 - 1s
# Epoch 478/501
# discriminator: -0.194954 - generator: 5.151359 - 1s
# Epoch 479/501
# discriminator: -0.185501 - generator: 5.131908 - 1s
# Epoch 480/501
# discriminator: -0.205254 - generator: 5.111634 - 1s
# Epoch 481/501
# discriminator: -0.217546 - generator: 5.100263 - 1s
# Epoch 482/501
# discriminator: -0.208981 - generator: 5.099840 - 1s
# Epoch 483/501
# discriminator: -0.235884 - generator: 5.127440 - 1s
# Epoch 484/501
# discriminator: -0.194866 - generator: 5.104423 - 1s
# Epoch 485/501
# discriminator: -0.190379 - generator: 5.138981 - 1s
# Epoch 486/501
# discriminator: -0.193894 - generator: 5.122227 - 1s
# Epoch 487/501
# discriminator: -0.211081 - generator: 5.113809 - 1s
# Epoch 488/501
# discriminator: -0.222125 - generator: 5.111921 - 1s
# Epoch 489/501
# discriminator: -0.162709 - generator: 5.046843 - 1s
# Epoch 490/501
# discriminator: -0.207480 - generator: 5.060102 - 1s
# Epoch 491/501
# discriminator: -0.212788 - generator: 5.006099 - 1s
# Epoch 492/501
# discriminator: -0.187009 - generator: 5.033974 - 1s
# Epoch 493/501
# discriminator: -0.178557 - generator: 5.014119 - 1s
# Epoch 494/501
# discriminator: -0.196412 - generator: 5.052326 - 1s
# Epoch 495/501
# discriminator: -0.180984 - generator: 5.097728 - 1s
# Epoch 496/501
# discriminator: -0.185168 - generator: 5.104111 - 1s
# Epoch 497/501
# discriminator: -0.163606 - generator: 5.121365 - 1s
# Epoch 498/501
# discriminator: -0.183059 - generator: 5.063936 - 1s
# Epoch 499/501
# discriminator: -0.237537 - generator: 5.007441 - 1s
# Epoch 500/501
# discriminator: -0.178630 - generator: 4.953484 - 1s
# Epoch 501/501
# discriminator: -0.189174 - generator: 4.841326 - 1s
# Loss:

# %% [markdown]
# # Analysis and Prediction
#
# ### Sampling from the latent space without prediction

# %%
latent_values = tf.random.normal([1,latent_space])
aa = generator.predict(tf.convert_to_tensor(latent_values)).reshape(20, 2)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot3D(aa[:,0], aa[:,1], z[0,:], 'r', label='Generated Sample 1')
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.legend()
plt.show()

# %%
latent_values = tf.random.normal([1,latent_space])
aa = generator.predict(tf.convert_to_tensor(latent_values)).reshape(20, 2)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot3D(aa[:,0], aa[:,1], z[0,:], 'g', label='Generated Sample 2')
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.legend()
plt.show()

# %% [markdown]
# ### Applying the prediction function

# %%
codings_size = 2
mse = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(1e-2)

def mse_loss(inp, outp):
    inp = tf.reshape(inp, [-1, codings_size])
    outp = tf.reshape(outp, [-1, codings_size])
    return mse(inp, outp)

# %%
#@tf.function
def opt_step(latent_values, real_coding, num_predefined):
    with tf.GradientTape() as tape:
        tape.watch(latent_values)
        gen_output = generator(latent_values, training=False)  #results from generator
        loss = mse_loss(real_coding, gen_output[:,:num_predefined,:,:])   #codings_size is size of each output, ntimes is number of time levels. 
        #If training for 9 time levels, it finds the loss between the first 8 outputs from the generator and 8 real outputs

    gradient = tape.gradient(loss, latent_values)   #gradient of the loss ws to the input
    optimizer.apply_gradients(zip([gradient], [latent_values]))   #applies gradients to the input
    
    return loss

# %%
def optimize_coding(real_coding, num_predefined):
    latent_values = tf.random.normal([len(real_coding), latent_space], mean=0.0, stddev=0.1)
    latent_values = tf.Variable(latent_values)     #make input a tensorflow variable so it can be trained
    
    loss = []
    for epoch in range(10000):
        loss.append(opt_step(latent_values, real_coding, num_predefined).numpy())
                            
    plt.plot(loss)
    plt.grid()
    plt.show
        
    return latent_values  #returns the optimized input that generates the desired output

# %% [markdown]
# ### Test Prediction on Test Set

# %%
x_test = []
y_test = []

# generate 10 spirals
for i in range(10):
    xx, yy, zz = get_dataset()
    x_test.append(xx)
    y_test.append(yy)
    
x_test = np.array(x_test)
y_test = np.array(y_test)

x_test.shape
# Out:
# (10, 20)

# %%
samples_num = 10
testset = []
for i in range(samples_num):
    sample_data = np.concatenate((x[i,:].reshape(-1,1), y[i,:].reshape(-1,1)), axis=1)
    #X_train_scaled = scaler.fit_transform(sample_data)*2 - 1
    testset.append(sample_data)
    #dataset.append(sample_data)

testset = np.array(testset)
testset.shape
# Out:
# (10, 20, 2)

# %%
n = 0
num_predefined = 10
real_coding = testset[n].reshape(1,-1)
real_coding = real_coding[:,:codings_size*num_predefined]
real_coding = tf.constant(real_coding)
real_coding = tf.cast(real_coding, dtype=tf.float32)

latent_values = optimize_coding(real_coding, num_predefined)
print('Loss: ', mse_loss(generator(latent_values)[:,:num_predefined,:,:], real_coding).numpy())
print(latent_values)
# Out:
# Loss:  0.0018127207
# <tf.Variable 'Variable:0' shape=(1, 12) dtype=float32, numpy=
# array([[-0.5988122 , -0.19386807, -0.02923575, -0.01020977,  0.31746086,
#          0.23514542,  0.36406434, -0.08890693,  0.41892013, -0.41454053,
#         -0.370428  , -0.5058632 ]], dtype=float32)>

# %%
X_generated = generator.predict(tf.convert_to_tensor(latent_values)).reshape(20,codings_size)
X_generated = X_generated.reshape(20, 2)

X_real = testset[n].reshape(20, codings_size)
X_real = X_real.reshape(20, 2)

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.gca(projection='3d')


ax.plot3D(X_generated[:,0], X_generated[:,1], z[0,:], 'r', label='Generated Sample')
ax.plot3D(X_real[:,0], X_real[:,1], z[0,:], 'b', label='Test Sample')
ax.scatter3D(X_real[:num_predefined, 0], X_real[:num_predefined, 1], z[0,:num_predefined], c='b', s=30, depthshade=False, label='Test Data Points')
ax.set_xlabel("x")
ax.set_ylabel("\n y")
ax.set_zlabel("z")
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(0,4)
ax.legend(prop={'size': 13})

plt.tight_layout(pad=-7)

# %% [markdown]
# ### Exploring if the generated samples still form a concentric circle.

# %%
generated = []
seed = 10
for i in range(1000):
    tf.random.set_seed(seed)
    latent_values = tf.random.normal([1, latent_space])
    generated.append(generator.predict(tf.convert_to_tensor(latent_values)).reshape(20, 2))
    seed = seed + 1

generated = np.array(generated)
generated.shape
# Out:
# (1000, 20, 2)

# %%
generated[:,0,0].shape
# Out:
# (1000,)

# %%
new_x = np.concatenate((generated[:,0,0].reshape(1,-1), x[:,0].reshape(1,-1)),axis=1).reshape(2000,)
new_y = np.concatenate((generated[:,0,1].reshape(1,-1), y[:,0].reshape(1,-1)),axis=1).reshape(2000,)
labels = np.array([1]*1000 + [2]*1000)

# Combine data into DataFrame
df = pd.DataFrame({'X': new_x, 'Y': new_y, 'col': labels})

# Define colormap and create corresponding color palette
cmap = sns.diverging_palette(10, 260, as_cmap=True)
colors = sns.diverging_palette(10, 260, n=2)

# Plot data onto seaborn JointGrid
g = sns.JointGrid('X', 'Y', data=df, ratio=3,xlim=(-1.2, 1.2),ylim=(-1.2, 1.2))
g = g.plot_joint(plt.scatter, c=df['col'], cmap=cmap, label="At z=0")

# Loop through unique categories and plot individual kdes
for c in df['col'].unique():
    sns.kdeplot(df['Y'][df['col']==c], ax=g.ax_marg_y, vertical=True,
                color=colors[c-1], shade=True)
    sns.kdeplot(df['X'][df['col']==c], ax=g.ax_marg_x, vertical=False,
                color=colors[c-1], shade=True)
    g.ax_marg_x.legend_.remove()
    g.ax_marg_y.legend_.remove()

plt.legend()

# %%
[15:36] Tao, Ran
    the code part is here. how to understand np.exp(line_fit_fe[1]) * dt_array**(line_fit_fe[0])?
​[15:36] Tao, Ran
    line_fit_fe = np.polyfit(np.log(dt_array[start_fit:]), np.log(error_fe[start_fit:]), 1)
line_fit_ie = np.polyfit(np.log(dt_array[start_fit:]), np.log(error_ie[start_fit:]), 1)
ax1.loglog(dt_array, np.exp(line_fit_fe[1]) * dt_array**(line_fit_fe[0]), 'k-', label = 'slope: {​​​​​​​:.2f}​​​​​​​'.format(line_fit_fe[0]))
ax1.loglog(dt_array, np.exp(line_fit_ie[1]) * dt_array**(line_fit_ie[0]), 'b-', label = 'slope: {​​​​​​​:.2f}​​​​​​​'.format(line_fit_ie[0]))
 
<https://teams.microsoft.com/l/message/19:82b1156c87a1493dbd83a9efa79dcb91@thread.tacv2/1606837012978?tenantId=2b
