# %%
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
#style.use('fivethirtyeight')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras

import sys
sys.path.append("..")

import dataset, network, GPR_Model, prob_dist
import WGAN_Model

# please ensure the WGAN_Model.py is edited to use prediction on a
# non-fixed input, as by default the active function is for fixed input.

# %% [markdown]
# # Load data

# %%
# n_features = 4 

# data = pd.read_csv("../data/mtsdata.csv")
# print(data.head())

# x1, x2, x3 = np.array(data["Surface Area"]*1e13).reshape(-1,1), np.array(data["Concentration"]).reshape(-1,1), np.array(data["Time"]).reshape(-1,1)

# X_train = np.concatenate((x1, x2), axis=1)
# X_train = np.concatenate((X_train, x3), axis=1)
# y_train = np.array(data["Response"]).reshape(-1,1)

# X_test = np.concatenate((x1, x2), axis=1)
# X_test = np.concatenate((X_test, x3), axis=1)
# y_test = np.array(data["Response"]).reshape(-1,1)

# %%
# 2 n_features sets "sinus", "circle", "multi", "moons", "heter"
# 3 n_features sets "helix", "3d"

scenario = "sinus"
n_instance = 200 # number of generated points
n_features = 2

# %%
if scenario in ("3d", "helix") :
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.tight_layout()
    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='grey')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Preprocessing

# %%
wgan = WGAN_Model.WGAN(n_features)

# %%
train_dataset, scaler, X_train_scaled = wgan.preproc(X_train, y_train)
test_dataset, scaler1, X_test_scaled = wgan.preproc(X_test, y_test)
# Out:
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)

# %% [markdown]
# ### Training

# %%
hist = wgan.train(train_dataset, epochs=1000)
# Out:
# Epoch 0/1000
# discriminator: -0.033958 - generator: 0.641438 - 3s
# Epoch 1/1000
# discriminator: -0.113491 - generator: 0.627997 - 0s
# Epoch 2/1000
# discriminator: -0.057517 - generator: 0.636088 - 1s
# Epoch 3/1000
# discriminator: -0.003461 - generator: 0.598041 - 1s
# Epoch 4/1000
# discriminator: -0.016329 - generator: 0.586421 - 0s
# Epoch 5/1000
# discriminator: -0.059070 - generator: 0.616910 - 0s
# Epoch 6/1000
# discriminator: -0.005178 - generator: 0.541126 - 0s
# Epoch 7/1000
# discriminator: -0.002314 - generator: 0.576437 - 0s
# Epoch 8/1000
# discriminator: -0.014170 - generator: 0.593904 - 0s
# Epoch 9/1000
# discriminator: -0.068248 - generator: 0.581028 - 0s
# Epoch 10/1000
# discriminator: -0.031520 - generator: 0.541470 - 1s
# Epoch 11/1000
# discriminator: -0.034031 - generator: 0.508866 - 0s
# Epoch 12/1000
# discriminator: -0.015740 - generator: 0.500046 - 0s
# Epoch 13/1000
# discriminator: -0.005816 - generator: 0.521906 - 0s
# Epoch 14/1000
# discriminator: -0.023018 - generator: 0.485697 - 0s
# Epoch 15/1000
# discriminator: 0.013038 - generator: 0.475224 - 0s
# Epoch 16/1000
# discriminator: 0.009562 - generator: 0.465604 - 0s
# Epoch 17/1000
# discriminator: 0.025946 - generator: 0.476863 - 0s
# Epoch 18/1000
# discriminator: 0.002329 - generator: 0.462287 - 0s
# Epoch 19/1000
# discriminator: -0.028356 - generator: 0.475664 - 0s
# Epoch 20/1000
# discriminator: -0.010002 - generator: 0.436786 - 0s
# Epoch 21/1000
# discriminator: -0.019251 - generator: 0.448299 - 0s
# Epoch 22/1000
# discriminator: -0.004929 - generator: 0.448276 - 0s
# Epoch 23/1000
# discriminator: -0.015847 - generator: 0.452612 - 0s
# Epoch 24/1000
# discriminator: -0.027623 - generator: 0.484107 - 0s
# Epoch 25/1000
# discriminator: -0.038704 - generator: 0.514587 - 0s
# Epoch 26/1000
# discriminator: -0.055265 - generator: 0.518372 - 0s
# Epoch 27/1000
# discriminator: -0.074893 - generator: 0.543400 - 0s
# Epoch 28/1000
# discriminator: -0.104133 - generator: 0.571557 - 0s
# Epoch 29/1000
# discriminator: -0.105882 - generator: 0.588732 - 0s
# Epoch 30/1000
# discriminator: -0.123779 - generator: 0.623972 - 0s
# Epoch 31/1000
# discriminator: -0.153680 - generator: 0.665180 - 0s
# Epoch 32/1000
# discriminator: -0.148858 - generator: 0.653765 - 0s
# Epoch 33/1000
# discriminator: -0.148479 - generator: 0.641671 - 0s
# Epoch 34/1000
# discriminator: -0.145013 - generator: 0.623521 - 0s
# Epoch 35/1000
# discriminator: -0.153482 - generator: 0.628837 - 0s
# Epoch 36/1000
# discriminator: -0.141378 - generator: 0.613967 - 0s
# Epoch 37/1000
# discriminator: -0.148557 - generator: 0.588468 - 0s
# Epoch 38/1000
# discriminator: -0.140982 - generator: 0.608769 - 0s
# Epoch 39/1000
# discriminator: -0.149682 - generator: 0.596167 - 0s
# Epoch 40/1000
# discriminator: -0.119252 - generator: 0.563786 - 0s
# Epoch 41/1000
# discriminator: -0.121082 - generator: 0.549952 - 0s
# Epoch 42/1000
# discriminator: -0.135476 - generator: 0.564932 - 0s
# Epoch 43/1000
# discriminator: -0.110146 - generator: 0.558829 - 0s
# Epoch 44/1000
# discriminator: -0.093985 - generator: 0.549501 - 0s
# Epoch 45/1000
# discriminator: -0.128189 - generator: 0.516043 - 0s
# Epoch 46/1000
# discriminator: -0.126507 - generator: 0.569751 - 0s
# Epoch 47/1000
# discriminator: -0.111190 - generator: 0.517023 - 0s
# Epoch 48/1000
# discriminator: -0.126355 - generator: 0.489204 - 0s
# Epoch 49/1000
# discriminator: -0.094890 - generator: 0.478204 - 0s
# Epoch 50/1000
# discriminator: -0.083522 - generator: 0.478196 - 0s
# Epoch 51/1000
# discriminator: -0.078477 - generator: 0.484039 - 0s
# Epoch 52/1000
# discriminator: -0.055377 - generator: 0.475157 - 0s
# Epoch 53/1000
# discriminator: -0.035263 - generator: 0.459647 - 1s
# Epoch 54/1000
# discriminator: -0.077018 - generator: 0.498112 - 1s
# Epoch 55/1000
# discriminator: -0.010790 - generator: 0.448942 - 1s
# Epoch 56/1000
# discriminator: -0.089382 - generator: 0.488046 - 1s
# Epoch 57/1000
# discriminator: -0.030057 - generator: 0.450600 - 1s
# Epoch 58/1000
# discriminator: 0.012741 - generator: 0.455355 - 1s
# Epoch 59/1000
# discriminator: -0.022814 - generator: 0.484065 - 1s
# Epoch 60/1000
# discriminator: 0.051994 - generator: 0.428735 - 1s
# Epoch 61/1000
# discriminator: -0.003295 - generator: 0.420981 - 1s
# Epoch 62/1000
# discriminator: 0.047211 - generator: 0.420064 - 0s
# Epoch 63/1000
# discriminator: 0.014732 - generator: 0.451553 - 1s
# Epoch 64/1000
# discriminator: 0.058308 - generator: 0.400789 - 1s
# Epoch 65/1000
# discriminator: 0.055524 - generator: 0.415054 - 1s
# Epoch 66/1000
# discriminator: 0.102738 - generator: 0.444941 - 1s
# Epoch 67/1000
# discriminator: 0.103323 - generator: 0.411189 - 1s
# Epoch 68/1000
# discriminator: 0.104723 - generator: 0.406199 - 0s
# Epoch 69/1000
# discriminator: 0.096501 - generator: 0.419443 - 0s
# Epoch 70/1000
# discriminator: 0.089826 - generator: 0.391887 - 0s
# Epoch 71/1000
# discriminator: 0.129197 - generator: 0.397928 - 0s
# Epoch 72/1000
# discriminator: 0.114728 - generator: 0.402949 - 1s
# Epoch 73/1000
# discriminator: 0.156064 - generator: 0.339618 - 0s
# Epoch 74/1000
# discriminator: 0.133576 - generator: 0.363639 - 1s
# Epoch 75/1000
# discriminator: 0.150765 - generator: 0.350829 - 0s
# Epoch 76/1000
# discriminator: 0.137581 - generator: 0.400717 - 0s
# Epoch 77/1000
# discriminator: 0.152483 - generator: 0.361246 - 0s
# Epoch 78/1000
# discriminator: 0.246457 - generator: 0.373818 - 0s
# Epoch 79/1000
# discriminator: 0.167931 - generator: 0.423103 - 0s
# Epoch 80/1000
# discriminator: 0.199377 - generator: 0.416713 - 0s
# Epoch 81/1000
# discriminator: 0.160804 - generator: 0.427634 - 0s
# Epoch 82/1000
# discriminator: 0.216326 - generator: 0.410064 - 0s
# Epoch 83/1000
# discriminator: 0.252047 - generator: 0.486344 - 0s
# Epoch 84/1000
# discriminator: 0.235867 - generator: 0.476590 - 0s
# Epoch 85/1000
# discriminator: 0.260047 - generator: 0.519750 - 0s
# Epoch 86/1000
# discriminator: 0.274363 - generator: 0.492060 - 0s
# Epoch 87/1000
# discriminator: 0.246337 - generator: 0.503304 - 0s
# Epoch 88/1000
# discriminator: 0.209608 - generator: 0.473587 - 0s
# Epoch 89/1000
# discriminator: 0.230831 - generator: 0.540674 - 0s
# Epoch 90/1000
# discriminator: 0.278090 - generator: 0.509319 - 0s
# Epoch 91/1000
# discriminator: 0.262697 - generator: 0.490619 - 0s
# Epoch 92/1000
# discriminator: 0.283882 - generator: 0.490548 - 0s
# Epoch 93/1000
# discriminator: 0.235044 - generator: 0.428052 - 0s
# Epoch 94/1000
# discriminator: 0.311204 - generator: 0.435501 - 0s
# Epoch 95/1000
# discriminator: 0.302773 - generator: 0.379707 - 0s
# Epoch 96/1000
# discriminator: 0.333205 - generator: 0.426221 - 0s
# Epoch 97/1000
# discriminator: 0.362976 - generator: 0.390077 - 0s
# Epoch 98/1000
# discriminator: 0.321316 - generator: 0.388025 - 0s
# Epoch 99/1000
# discriminator: 0.299928 - generator: 0.381379 - 1s
# Epoch 100/1000
# discriminator: 0.339406 - generator: 0.365525 - 1s
# Epoch 101/1000
# discriminator: 0.317207 - generator: 0.403636 - 1s
# Epoch 102/1000
# discriminator: 0.328042 - generator: 0.349860 - 0s
# Epoch 103/1000
# discriminator: 0.378974 - generator: 0.348324 - 1s
# Epoch 104/1000
# discriminator: 0.358008 - generator: 0.309966 - 0s
# Epoch 105/1000
# discriminator: 0.411495 - generator: 0.332995 - 0s
# Epoch 106/1000
# discriminator: 0.355229 - generator: 0.336957 - 0s
# Epoch 107/1000
# discriminator: 0.330179 - generator: 0.270455 - 0s
# Epoch 108/1000
# discriminator: 0.410623 - generator: 0.257831 - 0s
# Epoch 109/1000
# discriminator: 0.385519 - generator: 0.182082 - 0s
# Epoch 110/1000
# discriminator: 0.342744 - generator: 0.235271 - 0s
# Epoch 111/1000
# discriminator: 0.314040 - generator: 0.207599 - 0s
# Epoch 112/1000
# discriminator: 0.321221 - generator: 0.210705 - 0s
# Epoch 113/1000
# discriminator: 0.336678 - generator: 0.270311 - 0s
# Epoch 114/1000
# discriminator: 0.342396 - generator: 0.265952 - 0s
# Epoch 115/1000
# discriminator: 0.212856 - generator: 0.253659 - 0s
# Epoch 116/1000
# discriminator: 0.134621 - generator: 0.241258 - 0s
# Epoch 117/1000
# discriminator: 0.078892 - generator: 0.326592 - 0s
# Epoch 118/1000
# discriminator: -0.004143 - generator: 0.380430 - 0s
# Epoch 119/1000
# discriminator: -0.052499 - generator: 0.441102 - 0s
# Epoch 120/1000
# discriminator: -0.117518 - generator: 0.470374 - 0s
# Epoch 121/1000
# discriminator: -0.104084 - generator: 0.488626 - 0s
# Epoch 122/1000
# discriminator: -0.109571 - generator: 0.517993 - 0s
# Epoch 123/1000
# discriminator: -0.152615 - generator: 0.552947 - 0s
# Epoch 124/1000
# discriminator: -0.233558 - generator: 0.590678 - 0s
# Epoch 125/1000
# discriminator: -0.296898 - generator: 0.656995 - 0s
# Epoch 126/1000
# discriminator: -0.279916 - generator: 0.691531 - 0s
# Epoch 127/1000
# discriminator: -0.291579 - generator: 0.738177 - 0s
# Epoch 128/1000
# discriminator: -0.352394 - generator: 0.671280 - 0s
# Epoch 129/1000
# discriminator: -0.340859 - generator: 0.759625 - 0s
# Epoch 130/1000
# discriminator: -0.316108 - generator: 0.763074 - 0s
# Epoch 131/1000
# discriminator: -0.356859 - generator: 0.805591 - 0s
# Epoch 132/1000
# discriminator: -0.298078 - generator: 0.892241 - 0s
# Epoch 133/1000
# discriminator: -0.427714 - generator: 0.910710 - 0s
# Epoch 134/1000
# discriminator: -0.391576 - generator: 0.947345 - 0s
# Epoch 135/1000
# discriminator: -0.403740 - generator: 0.934259 - 0s
# Epoch 136/1000
# discriminator: -0.425587 - generator: 0.971102 - 0s
# Epoch 137/1000
# discriminator: -0.381546 - generator: 0.967314 - 0s
# Epoch 138/1000
# discriminator: -0.471726 - generator: 0.979482 - 0s
# Epoch 139/1000
# discriminator: -0.384050 - generator: 0.967938 - 0s
# Epoch 140/1000
# discriminator: -0.435392 - generator: 0.987395 - 0s
# Epoch 141/1000
# discriminator: -0.426776 - generator: 0.979567 - 0s
# Epoch 142/1000
# discriminator: -0.424533 - generator: 1.020053 - 0s
# Epoch 143/1000
# discriminator: -0.528483 - generator: 1.073583 - 0s
# Epoch 144/1000
# discriminator: -0.497161 - generator: 1.052284 - 0s
# Epoch 145/1000
# discriminator: -0.377818 - generator: 1.017283 - 0s
# Epoch 146/1000
# discriminator: -0.333876 - generator: 1.020268 - 0s
# Epoch 147/1000
# discriminator: -0.476363 - generator: 1.005446 - 0s
# Epoch 148/1000
# discriminator: -0.374481 - generator: 0.981986 - 0s
# Epoch 149/1000
# discriminator: -0.398360 - generator: 0.947486 - 0s
# Epoch 150/1000
# discriminator: -0.352110 - generator: 0.989252 - 0s
# Epoch 151/1000
# discriminator: -0.391894 - generator: 1.033208 - 0s
# Epoch 152/1000
# discriminator: -0.280498 - generator: 0.963390 - 0s
# Epoch 153/1000
# discriminator: -0.338685 - generator: 0.904116 - 0s
# Epoch 154/1000
# discriminator: -0.374603 - generator: 0.897088 - 0s
# Epoch 155/1000
# discriminator: -0.364041 - generator: 0.900524 - 1s
# Epoch 156/1000
# discriminator: -0.379447 - generator: 0.821994 - 1s
# Epoch 157/1000
# discriminator: -0.333275 - generator: 0.833565 - 1s
# Epoch 158/1000
# discriminator: -0.328194 - generator: 0.885954 - 1s
# Epoch 159/1000
# discriminator: -0.270122 - generator: 0.877599 - 1s
# Epoch 160/1000
# discriminator: -0.222567 - generator: 0.831157 - 1s
# Epoch 161/1000
# discriminator: -0.377620 - generator: 0.804810 - 1s
# Epoch 162/1000
# discriminator: -0.281824 - generator: 0.788685 - 0s
# Epoch 163/1000
# discriminator: -0.270652 - generator: 0.801870 - 0s
# Epoch 164/1000
# discriminator: -0.235596 - generator: 0.850287 - 1s
# Epoch 165/1000
# discriminator: -0.292177 - generator: 0.788275 - 0s
# Epoch 166/1000
# discriminator: -0.215649 - generator: 0.819883 - 0s
# Epoch 167/1000
# discriminator: -0.189611 - generator: 0.835716 - 0s
# Epoch 168/1000
# discriminator: -0.127963 - generator: 0.777030 - 0s
# Epoch 169/1000
# discriminator: -0.167850 - generator: 0.786450 - 0s
# Epoch 170/1000
# discriminator: -0.220171 - generator: 0.803344 - 0s
# Epoch 171/1000
# discriminator: -0.206382 - generator: 0.740228 - 1s
# Epoch 172/1000
# discriminator: -0.197527 - generator: 0.765469 - 1s
# Epoch 173/1000
# discriminator: -0.195037 - generator: 0.805180 - 0s
# Epoch 174/1000
# discriminator: -0.078298 - generator: 0.830038 - 0s
# Epoch 175/1000
# discriminator: -0.121210 - generator: 0.793473 - 0s
# Epoch 176/1000
# discriminator: -0.188182 - generator: 0.779301 - 0s
# Epoch 177/1000
# discriminator: -0.225285 - generator: 0.782788 - 0s
# Epoch 178/1000
# discriminator: -0.163441 - generator: 0.754309 - 0s
# Epoch 179/1000
# discriminator: -0.188872 - generator: 0.860972 - 0s
# Epoch 180/1000
# discriminator: -0.045776 - generator: 0.801134 - 0s
# Epoch 181/1000
# discriminator: -0.117052 - generator: 0.820728 - 0s
# Epoch 182/1000
# discriminator: -0.093429 - generator: 0.808389 - 0s
# Epoch 183/1000
# discriminator: -0.116252 - generator: 0.756606 - 0s
# Epoch 184/1000
# discriminator: -0.052254 - generator: 0.839833 - 0s
# Epoch 185/1000
# discriminator: -0.136979 - generator: 0.780167 - 0s
# Epoch 186/1000
# discriminator: -0.128930 - generator: 0.781087 - 0s
# Epoch 187/1000
# discriminator: -0.148552 - generator: 0.880038 - 0s
# Epoch 188/1000
# discriminator: -0.055026 - generator: 0.838225 - 0s
# Epoch 189/1000
# discriminator: -0.011641 - generator: 0.756995 - 0s
# Epoch 190/1000
# discriminator: -0.048999 - generator: 0.761354 - 0s
# Epoch 191/1000
# discriminator: -0.017859 - generator: 0.797846 - 0s
# Epoch 192/1000
# discriminator: -0.022537 - generator: 0.854621 - 0s
# Epoch 193/1000
# discriminator: -0.013126 - generator: 0.795072 - 0s
# Epoch 194/1000
# discriminator: 0.002035 - generator: 0.819314 - 0s
# Epoch 195/1000
# discriminator: -0.015106 - generator: 0.767172 - 0s
# Epoch 196/1000
# discriminator: -0.041345 - generator: 0.793009 - 0s
# Epoch 197/1000
# discriminator: -0.059166 - generator: 0.778484 - 0s
# Epoch 198/1000
# discriminator: -0.018152 - generator: 0.758564 - 0s
# Epoch 199/1000
# discriminator: 0.009346 - generator: 0.774783 - 0s
# Epoch 200/1000
# discriminator: -0.026344 - generator: 0.762477 - 0s
# Epoch 201/1000
# discriminator: 0.063295 - generator: 0.707043 - 0s
# Epoch 202/1000
# discriminator: -0.006286 - generator: 0.752713 - 0s
# Epoch 203/1000
# discriminator: -0.004977 - generator: 0.662502 - 0s
# Epoch 204/1000
# discriminator: 0.094980 - generator: 0.690896 - 1s
# Epoch 205/1000
# discriminator: -0.004296 - generator: 0.694415 - 0s
# Epoch 206/1000
# discriminator: 0.028660 - generator: 0.708986 - 0s
# Epoch 207/1000
# discriminator: 0.058099 - generator: 0.730864 - 0s
# Epoch 208/1000
# discriminator: 0.088287 - generator: 0.706467 - 0s
# Epoch 209/1000
# discriminator: 0.082884 - generator: 0.752741 - 0s
# Epoch 210/1000
# discriminator: 0.009885 - generator: 0.638118 - 0s
# Epoch 211/1000
# discriminator: 0.082321 - generator: 0.659032 - 0s
# Epoch 212/1000
# discriminator: 0.115190 - generator: 0.634823 - 0s
# Epoch 213/1000
# discriminator: 0.038264 - generator: 0.671289 - 0s
# Epoch 214/1000
# discriminator: 0.124522 - generator: 0.595449 - 0s
# Epoch 215/1000
# discriminator: 0.054971 - generator: 0.608534 - 1s
# Epoch 216/1000
# discriminator: 0.144337 - generator: 0.640010 - 0s
# Epoch 217/1000
# discriminator: 0.134258 - generator: 0.550770 - 0s
# Epoch 218/1000
# discriminator: 0.153582 - generator: 0.588760 - 0s
# Epoch 219/1000
# discriminator: 0.240385 - generator: 0.572902 - 0s
# Epoch 220/1000
# discriminator: 0.201752 - generator: 0.545163 - 0s
# Epoch 221/1000
# discriminator: 0.098095 - generator: 0.513553 - 0s
# Epoch 222/1000
# discriminator: 0.168817 - generator: 0.486830 - 0s
# Epoch 223/1000
# discriminator: 0.271681 - generator: 0.484292 - 0s
# Epoch 224/1000
# discriminator: 0.261596 - generator: 0.385098 - 0s
# Epoch 225/1000
# discriminator: 0.192129 - generator: 0.445328 - 0s
# Epoch 226/1000
# discriminator: 0.226360 - generator: 0.391590 - 0s
# Epoch 227/1000
# discriminator: 0.248498 - generator: 0.348643 - 0s
# Epoch 228/1000
# discriminator: 0.195067 - generator: 0.345084 - 0s
# Epoch 229/1000
# discriminator: 0.204911 - generator: 0.303056 - 0s
# Epoch 230/1000
# discriminator: 0.243840 - generator: 0.204809 - 0s
# Epoch 231/1000
# discriminator: 0.273311 - generator: 0.213016 - 0s
# Epoch 232/1000
# discriminator: 0.251530 - generator: 0.218649 - 0s
# Epoch 233/1000
# discriminator: 0.217358 - generator: 0.173616 - 0s
# Epoch 234/1000
# discriminator: 0.256643 - generator: 0.228691 - 0s
# Epoch 235/1000
# discriminator: 0.207758 - generator: 0.137525 - 0s
# Epoch 236/1000
# discriminator: 0.315454 - generator: 0.114890 - 0s
# Epoch 237/1000
# discriminator: 0.228207 - generator: 0.117569 - 1s
# Epoch 238/1000
# discriminator: 0.250596 - generator: 0.117863 - 1s
# Epoch 239/1000
# discriminator: 0.273083 - generator: 0.148856 - 0s
# Epoch 240/1000
# discriminator: 0.246297 - generator: 0.057571 - 0s
# Epoch 241/1000
# discriminator: 0.241755 - generator: 0.022020 - 0s
# Epoch 242/1000
# discriminator: 0.229949 - generator: 0.008296 - 0s
# Epoch 243/1000
# discriminator: 0.213235 - generator: 0.027437 - 0s
# Epoch 244/1000
# discriminator: 0.215143 - generator: -0.005827 - 0s
# Epoch 245/1000
# discriminator: 0.204845 - generator: -0.067663 - 0s
# Epoch 246/1000
# discriminator: 0.290459 - generator: -0.058490 - 0s
# Epoch 247/1000
# discriminator: 0.172126 - generator: -0.035110 - 0s
# Epoch 248/1000
# discriminator: 0.116547 - generator: -0.088008 - 0s
# Epoch 249/1000
# discriminator: 0.115099 - generator: -0.153447 - 0s
# Epoch 250/1000
# discriminator: 0.076255 - generator: -0.163485 - 0s
# Epoch 251/1000
# discriminator: 0.121622 - generator: -0.141567 - 0s
# Epoch 252/1000
# discriminator: 0.140804 - generator: -0.171983 - 0s
# Epoch 253/1000
# discriminator: 0.100025 - generator: -0.158317 - 0s
# Epoch 254/1000
# discriminator: 0.107355 - generator: -0.130153 - 0s
# Epoch 255/1000
# discriminator: 0.058390 - generator: -0.206959 - 0s
# Epoch 256/1000
# discriminator: 0.145161 - generator: -0.153998 - 0s
# Epoch 257/1000
# discriminator: 0.095813 - generator: -0.237639 - 0s
# Epoch 258/1000
# discriminator: 0.148104 - generator: -0.222770 - 0s
# Epoch 259/1000
# discriminator: 0.099513 - generator: -0.172338 - 0s
# Epoch 260/1000
# discriminator: 0.061602 - generator: -0.109724 - 0s
# Epoch 261/1000
# discriminator: 0.152491 - generator: -0.120742 - 0s
# Epoch 262/1000
# discriminator: 0.030623 - generator: -0.181161 - 0s
# Epoch 263/1000
# discriminator: 0.069430 - generator: -0.153216 - 0s
# Epoch 264/1000
# discriminator: 0.056601 - generator: -0.046349 - 0s
# Epoch 265/1000
# discriminator: 0.091768 - generator: -0.030781 - 0s
# Epoch 266/1000
# discriminator: 0.257133 - generator: 0.001395 - 0s
# Epoch 267/1000
# discriminator: -0.012030 - generator: -0.041677 - 0s
# Epoch 268/1000
# discriminator: 0.098395 - generator: -0.024375 - 0s
# Epoch 269/1000
# discriminator: 0.030571 - generator: 0.121625 - 0s
# Epoch 270/1000
# discriminator: 0.069191 - generator: 0.111738 - 0s
# Epoch 271/1000
# discriminator: 0.075260 - generator: 0.017321 - 0s
# Epoch 272/1000
# discriminator: -0.003664 - generator: 0.089028 - 0s
# Epoch 273/1000
# discriminator: 0.012439 - generator: 0.129502 - 0s
# Epoch 274/1000
# discriminator: 0.071491 - generator: 0.245333 - 0s
# Epoch 275/1000
# discriminator: 0.104771 - generator: 0.280705 - 0s
# Epoch 276/1000
# discriminator: 0.025289 - generator: 0.316157 - 0s
# Epoch 277/1000
# discriminator: 0.013247 - generator: 0.387824 - 0s
# Epoch 278/1000
# discriminator: -0.051101 - generator: 0.355000 - 0s
# Epoch 279/1000
# discriminator: -0.053451 - generator: 0.487045 - 0s
# Epoch 280/1000
# discriminator: 0.110018 - generator: 0.421702 - 0s
# Epoch 281/1000
# discriminator: -0.002672 - generator: 0.444581 - 1s
# Epoch 282/1000
# discriminator: -0.084500 - generator: 0.503002 - 1s
# Epoch 283/1000
# discriminator: 0.021050 - generator: 0.602519 - 1s
# Epoch 284/1000
# discriminator: -0.087719 - generator: 0.593602 - 0s
# Epoch 285/1000
# discriminator: -0.068550 - generator: 0.728357 - 1s
# Epoch 286/1000
# discriminator: -0.093388 - generator: 0.667674 - 0s
# Epoch 287/1000
# discriminator: -0.124701 - generator: 0.693126 - 0s
# Epoch 288/1000
# discriminator: -0.006489 - generator: 0.761515 - 0s
# Epoch 289/1000
# discriminator: -0.159870 - generator: 0.686856 - 0s
# Epoch 290/1000
# discriminator: -0.060615 - generator: 0.733540 - 0s
# Epoch 291/1000
# discriminator: -0.018089 - generator: 0.700835 - 0s
# Epoch 292/1000
# discriminator: -0.115862 - generator: 0.812078 - 0s
# Epoch 293/1000
# discriminator: -0.077578 - generator: 0.664287 - 0s
# Epoch 294/1000
# discriminator: -0.089614 - generator: 0.618984 - 0s
# Epoch 295/1000
# discriminator: -0.126145 - generator: 0.554141 - 0s
# Epoch 296/1000
# discriminator: -0.009007 - generator: 0.646952 - 0s
# Epoch 297/1000
# discriminator: -0.044752 - generator: 0.502501 - 0s
# Epoch 298/1000
# discriminator: -0.139945 - generator: 0.536992 - 0s
# Epoch 299/1000
# discriminator: -0.132001 - generator: 0.334374 - 1s
# Epoch 300/1000
# discriminator: -0.130470 - generator: 0.171419 - 0s
# Epoch 301/1000
# discriminator: -0.317958 - generator: 0.232825 - 1s
# Epoch 302/1000
# discriminator: -0.314321 - generator: 0.112704 - 0s
# Epoch 303/1000
# discriminator: -0.274861 - generator: -0.075085 - 1s
# Epoch 304/1000
# discriminator: -0.303209 - generator: -0.244183 - 0s
# Epoch 305/1000
# discriminator: -0.245995 - generator: -0.423793 - 0s
# Epoch 306/1000
# discriminator: -0.281184 - generator: -0.497580 - 1s
# Epoch 307/1000
# discriminator: -0.308637 - generator: -0.476428 - 0s
# Epoch 308/1000
# discriminator: -0.209868 - generator: -0.727881 - 0s
# Epoch 309/1000
# discriminator: -0.212903 - generator: -0.881758 - 0s
# Epoch 310/1000
# discriminator: -0.412045 - generator: -0.947476 - 0s
# Epoch 311/1000
# discriminator: -0.319638 - generator: -0.889148 - 0s
# Epoch 312/1000
# discriminator: -0.412465 - generator: -0.975082 - 0s
# Epoch 313/1000
# discriminator: -0.248769 - generator: -1.128767 - 0s
# Epoch 314/1000
# discriminator: -0.443208 - generator: -1.169177 - 0s
# Epoch 315/1000
# discriminator: -0.323005 - generator: -1.233427 - 0s
# Epoch 316/1000
# discriminator: -0.362311 - generator: -1.120861 - 0s
# Epoch 317/1000
# discriminator: -0.348881 - generator: -1.258585 - 0s
# Epoch 318/1000
# discriminator: -0.269376 - generator: -1.395515 - 0s
# Epoch 319/1000
# discriminator: -0.361044 - generator: -1.289800 - 0s
# Epoch 320/1000
# discriminator: -0.271746 - generator: -1.366181 - 0s
# Epoch 321/1000
# discriminator: -0.272958 - generator: -1.430200 - 0s
# Epoch 322/1000
# discriminator: -0.318285 - generator: -1.635936 - 0s
# Epoch 323/1000
# discriminator: -0.368992 - generator: -1.721287 - 0s
# Epoch 324/1000
# discriminator: -0.328456 - generator: -1.693006 - 0s
# Epoch 325/1000
# discriminator: -0.295766 - generator: -1.688929 - 0s
# Epoch 326/1000
# discriminator: -0.217678 - generator: -1.700045 - 0s
# Epoch 327/1000
# discriminator: -0.264408 - generator: -1.772155 - 0s
# Epoch 328/1000
# discriminator: -0.358048 - generator: -1.806815 - 0s
# Epoch 329/1000
# discriminator: -0.205057 - generator: -1.852169 - 0s
# Epoch 330/1000
# discriminator: -0.254811 - generator: -1.932245 - 0s
# Epoch 331/1000
# discriminator: -0.205234 - generator: -1.921381 - 0s
# Epoch 332/1000
# discriminator: -0.197023 - generator: -1.948573 - 0s
# Epoch 333/1000
# discriminator: -0.163963 - generator: -1.968827 - 0s
# Epoch 334/1000
# discriminator: -0.180434 - generator: -2.145539 - 0s
# Epoch 335/1000
# discriminator: -0.195606 - generator: -2.215811 - 0s
# Epoch 336/1000
# discriminator: -0.129872 - generator: -2.181317 - 0s
# Epoch 337/1000
# discriminator: -0.161689 - generator: -2.269072 - 0s
# Epoch 338/1000
# discriminator: -0.090226 - generator: -2.288245 - 0s
# Epoch 339/1000
# discriminator: -0.190370 - generator: -2.225609 - 0s
# Epoch 340/1000
# discriminator: -0.145806 - generator: -2.277354 - 0s
# Epoch 341/1000
# discriminator: -0.101797 - generator: -2.339841 - 0s
# Epoch 342/1000
# discriminator: -0.158148 - generator: -2.267186 - 0s
# Epoch 343/1000
# discriminator: 0.033361 - generator: -2.424788 - 0s
# Epoch 344/1000
# discriminator: 0.000751 - generator: -2.383393 - 0s
# Epoch 345/1000
# discriminator: -0.044358 - generator: -2.495133 - 0s
# Epoch 346/1000
# discriminator: -0.031200 - generator: -2.483554 - 0s
# Epoch 347/1000
# discriminator: 0.056959 - generator: -2.416895 - 0s
# Epoch 348/1000
# discriminator: 0.000520 - generator: -2.461363 - 0s
# Epoch 349/1000
# discriminator: 0.023576 - generator: -2.476182 - 0s
# Epoch 350/1000
# discriminator: 0.073455 - generator: -2.460288 - 0s
# Epoch 351/1000
# discriminator: -0.049543 - generator: -2.438052 - 0s
# Epoch 352/1000
# discriminator: 0.072695 - generator: -2.443526 - 0s
# Epoch 353/1000
# discriminator: 0.063602 - generator: -2.430918 - 0s
# Epoch 354/1000
# discriminator: 0.133355 - generator: -2.517177 - 0s
# Epoch 355/1000
# discriminator: 0.037986 - generator: -2.564874 - 0s
# Epoch 356/1000
# discriminator: 0.077433 - generator: -2.564555 - 0s
# Epoch 357/1000
# discriminator: 0.105044 - generator: -2.559122 - 0s
# Epoch 358/1000
# discriminator: 0.090419 - generator: -2.550346 - 0s
# Epoch 359/1000
# discriminator: 0.107347 - generator: -2.658284 - 0s
# Epoch 360/1000
# discriminator: 0.047505 - generator: -2.555038 - 0s
# Epoch 361/1000
# discriminator: 0.139741 - generator: -2.522945 - 0s
# Epoch 362/1000
# discriminator: 0.125614 - generator: -2.393935 - 0s
# Epoch 363/1000
# discriminator: 0.058799 - generator: -2.415145 - 0s
# Epoch 364/1000
# discriminator: 0.051033 - generator: -2.452409 - 0s
# Epoch 365/1000
# discriminator: 0.136409 - generator: -2.423230 - 0s
# Epoch 366/1000
# discriminator: 0.124747 - generator: -2.391342 - 0s
# Epoch 367/1000
# discriminator: 0.119721 - generator: -2.323206 - 0s
# Epoch 368/1000
# discriminator: 0.155945 - generator: -2.245627 - 0s
# Epoch 369/1000
# discriminator: 0.117840 - generator: -2.170776 - 0s
# Epoch 370/1000
# discriminator: 0.143414 - generator: -2.185319 - 0s
# Epoch 371/1000
# discriminator: 0.240788 - generator: -2.308494 - 0s
# Epoch 372/1000
# discriminator: 0.268985 - generator: -2.274553 - 0s
# Epoch 373/1000
# discriminator: 0.035650 - generator: -2.186750 - 0s
# Epoch 374/1000
# discriminator: 0.140939 - generator: -2.137782 - 0s
# Epoch 375/1000
# discriminator: 0.165114 - generator: -2.174084 - 0s
# Epoch 376/1000
# discriminator: 0.287347 - generator: -2.146274 - 0s
# Epoch 377/1000
# discriminator: 0.063261 - generator: -2.127252 - 0s
# Epoch 378/1000
# discriminator: 0.174834 - generator: -2.165208 - 0s
# Epoch 379/1000
# discriminator: 0.277148 - generator: -2.054253 - 0s
# Epoch 380/1000
# discriminator: 0.227732 - generator: -2.088654 - 0s
# Epoch 381/1000
# discriminator: 0.235660 - generator: -2.065778 - 0s
# Epoch 382/1000
# discriminator: 0.289323 - generator: -2.076835 - 0s
# Epoch 383/1000
# discriminator: 0.308882 - generator: -2.048265 - 0s
# Epoch 384/1000
# discriminator: 0.189988 - generator: -2.022681 - 0s
# Epoch 385/1000
# discriminator: 0.190821 - generator: -1.944498 - 0s
# Epoch 386/1000
# discriminator: 0.204382 - generator: -1.988645 - 0s
# Epoch 387/1000
# discriminator: 0.253396 - generator: -1.831680 - 0s
# Epoch 388/1000
# discriminator: 0.275328 - generator: -1.855565 - 0s
# Epoch 389/1000
# discriminator: 0.334178 - generator: -1.990923 - 0s
# Epoch 390/1000
# discriminator: 0.362384 - generator: -1.976108 - 0s
# Epoch 391/1000
# discriminator: 0.271175 - generator: -1.841726 - 0s
# Epoch 392/1000
# discriminator: 0.273639 - generator: -1.729538 - 0s
# Epoch 393/1000
# discriminator: 0.375392 - generator: -1.727601 - 0s
# Epoch 394/1000
# discriminator: 0.272310 - generator: -1.686849 - 0s
# Epoch 395/1000
# discriminator: 0.260840 - generator: -1.584793 - 0s
# Epoch 396/1000
# discriminator: 0.398992 - generator: -1.663871 - 0s
# Epoch 397/1000
# discriminator: 0.290542 - generator: -1.564745 - 0s
# Epoch 398/1000
# discriminator: 0.290761 - generator: -1.522436 - 0s
# Epoch 399/1000
# discriminator: 0.295647 - generator: -1.489738 - 0s
# Epoch 400/1000
# discriminator: 0.465191 - generator: -1.602794 - 0s
# Epoch 401/1000
# discriminator: 0.374391 - generator: -1.465927 - 0s
# Epoch 402/1000
# discriminator: 0.404684 - generator: -1.562761 - 0s
# Epoch 403/1000
# discriminator: 0.487608 - generator: -1.590917 - 0s
# Epoch 404/1000
# discriminator: 0.418399 - generator: -1.542027 - 1s
# Epoch 405/1000
# discriminator: 0.344723 - generator: -1.545739 - 0s
# Epoch 406/1000
# discriminator: 0.447442 - generator: -1.497349 - 0s
# Epoch 407/1000
# discriminator: 0.343427 - generator: -1.463518 - 0s
# Epoch 408/1000
# discriminator: 0.470839 - generator: -1.351660 - 0s
# Epoch 409/1000
# discriminator: 0.455585 - generator: -1.188783 - 0s
# Epoch 410/1000
# discriminator: 0.482848 - generator: -1.019068 - 0s
# Epoch 411/1000
# discriminator: 0.514900 - generator: -0.911756 - 0s
# Epoch 412/1000
# discriminator: 0.419324 - generator: -0.804205 - 0s
# Epoch 413/1000
# discriminator: 0.430686 - generator: -0.592039 - 0s
# Epoch 414/1000
# discriminator: 0.232865 - generator: -0.274663 - 0s
# Epoch 415/1000
# discriminator: -0.002775 - generator: -0.134834 - 0s
# Epoch 416/1000
# discriminator: 0.110655 - generator: 0.151217 - 0s
# Epoch 417/1000
# discriminator: 0.151883 - generator: 0.190355 - 0s
# Epoch 418/1000
# discriminator: -0.054603 - generator: 0.407112 - 0s
# Epoch 419/1000
# discriminator: 0.066158 - generator: 0.512993 - 0s
# Epoch 420/1000
# discriminator: -0.277373 - generator: 0.582146 - 0s
# Epoch 421/1000
# discriminator: -0.254205 - generator: 0.755593 - 0s
# Epoch 422/1000
# discriminator: -0.405054 - generator: 0.909524 - 0s
# Epoch 423/1000
# discriminator: -0.161446 - generator: 1.031957 - 0s
# Epoch 424/1000
# discriminator: -0.514792 - generator: 1.057695 - 0s
# Epoch 425/1000
# discriminator: -0.397569 - generator: 1.189068 - 0s
# Epoch 426/1000
# discriminator: -0.516232 - generator: 1.220602 - 0s
# Epoch 427/1000
# discriminator: -0.495072 - generator: 1.161827 - 0s
# Epoch 428/1000
# discriminator: -0.626315 - generator: 1.093611 - 0s
# Epoch 429/1000
# discriminator: -0.414791 - generator: 1.128181 - 0s
# Epoch 430/1000
# discriminator: -0.568980 - generator: 0.923519 - 0s
# Epoch 431/1000
# discriminator: -0.505624 - generator: 0.784548 - 0s
# Epoch 432/1000
# discriminator: -0.479078 - generator: 0.758372 - 0s
# Epoch 433/1000
# discriminator: -0.472645 - generator: 0.589192 - 0s
# Epoch 434/1000
# discriminator: -0.591089 - generator: 0.657382 - 0s
# Epoch 435/1000
# discriminator: -0.520955 - generator: 0.564574 - 0s
# Epoch 436/1000
# discriminator: -0.381242 - generator: 0.459179 - 0s
# Epoch 437/1000
# discriminator: -0.404532 - generator: 0.333257 - 0s
# Epoch 438/1000
# discriminator: -0.289057 - generator: 0.304954 - 0s
# Epoch 439/1000
# discriminator: -0.393075 - generator: 0.361799 - 0s
# Epoch 440/1000
# discriminator: -0.539499 - generator: 0.427750 - 0s
# Epoch 441/1000
# discriminator: -0.384611 - generator: 0.439967 - 0s
# Epoch 442/1000
# discriminator: -0.396268 - generator: 0.490903 - 0s
# Epoch 443/1000
# discriminator: -0.397205 - generator: 0.537592 - 0s
# Epoch 444/1000
# discriminator: -0.346832 - generator: 0.455129 - 0s
# Epoch 445/1000
# discriminator: -0.280405 - generator: 0.387911 - 0s
# Epoch 446/1000
# discriminator: -0.253491 - generator: 0.380642 - 0s
# Epoch 447/1000
# discriminator: -0.267229 - generator: 0.327929 - 0s
# Epoch 448/1000
# discriminator: -0.300673 - generator: 0.360076 - 0s
# Epoch 449/1000
# discriminator: -0.322070 - generator: 0.362686 - 0s
# Epoch 450/1000
# discriminator: -0.232178 - generator: 0.359013 - 0s
# Epoch 451/1000
# discriminator: -0.223642 - generator: 0.349801 - 0s
# Epoch 452/1000
# discriminator: -0.230861 - generator: 0.433565 - 0s
# Epoch 453/1000
# discriminator: -0.232833 - generator: 0.245314 - 0s
# Epoch 454/1000
# discriminator: -0.236377 - generator: 0.425205 - 0s
# Epoch 455/1000
# discriminator: -0.252493 - generator: 0.341332 - 0s
# Epoch 456/1000
# discriminator: -0.201209 - generator: 0.490775 - 0s
# Epoch 457/1000
# discriminator: -0.266793 - generator: 0.375895 - 0s
# Epoch 458/1000
# discriminator: -0.289303 - generator: 0.495989 - 0s
# Epoch 459/1000
# discriminator: -0.175653 - generator: 0.573197 - 0s
# Epoch 460/1000
# discriminator: -0.123416 - generator: 0.472615 - 0s
# Epoch 461/1000
# discriminator: -0.156258 - generator: 0.413284 - 0s
# Epoch 462/1000
# discriminator: -0.204515 - generator: 0.427994 - 0s
# Epoch 463/1000
# discriminator: -0.165705 - generator: 0.315034 - 0s
# Epoch 464/1000
# discriminator: -0.291135 - generator: 0.406184 - 0s
# Epoch 465/1000
# discriminator: -0.266113 - generator: 0.445709 - 0s
# Epoch 466/1000
# discriminator: -0.129735 - generator: 0.444550 - 0s
# Epoch 467/1000
# discriminator: -0.157017 - generator: 0.441754 - 0s
# Epoch 468/1000
# discriminator: -0.237761 - generator: 0.198808 - 0s
# Epoch 469/1000
# discriminator: -0.149393 - generator: 0.266734 - 0s
# Epoch 470/1000
# discriminator: -0.220262 - generator: 0.225763 - 0s
# Epoch 471/1000
# discriminator: -0.183076 - generator: 0.376106 - 0s
# Epoch 472/1000
# discriminator: -0.171291 - generator: 0.351111 - 0s
# Epoch 473/1000
# discriminator: -0.166342 - generator: 0.352039 - 0s
# Epoch 474/1000
# discriminator: -0.137742 - generator: 0.406017 - 0s
# Epoch 475/1000
# discriminator: -0.137747 - generator: 0.210577 - 0s
# Epoch 476/1000
# discriminator: -0.146903 - generator: 0.285382 - 0s
# Epoch 477/1000
# discriminator: -0.082880 - generator: 0.120305 - 0s
# Epoch 478/1000
# discriminator: -0.065284 - generator: 0.253580 - 0s
# Epoch 479/1000
# discriminator: -0.187474 - generator: 0.353966 - 0s
# Epoch 480/1000
# discriminator: -0.004662 - generator: 0.342317 - 0s
# Epoch 481/1000
# discriminator: 0.027146 - generator: 0.300006 - 0s
# Epoch 482/1000
# discriminator: 0.028330 - generator: 0.364126 - 0s
# Epoch 483/1000
# discriminator: -0.035101 - generator: 0.334356 - 0s
# Epoch 484/1000
# discriminator: -0.082773 - generator: 0.388818 - 0s
# Epoch 485/1000
# discriminator: -0.039491 - generator: 0.379395 - 0s
# Epoch 486/1000
# discriminator: 0.052067 - generator: 0.389062 - 0s
# Epoch 487/1000
# discriminator: -0.064580 - generator: 0.420983 - 0s
# Epoch 488/1000
# discriminator: 0.026940 - generator: 0.428892 - 0s
# Epoch 489/1000
# discriminator: 0.071925 - generator: 0.525028 - 0s
# Epoch 490/1000
# discriminator: 0.047122 - generator: 0.429648 - 0s
# Epoch 491/1000
# discriminator: 0.002484 - generator: 0.513081 - 0s
# Epoch 492/1000
# discriminator: 0.052703 - generator: 0.445929 - 0s
# Epoch 493/1000
# discriminator: 0.036828 - generator: 0.432157 - 0s
# Epoch 494/1000
# discriminator: 0.078895 - generator: 0.477833 - 0s
# Epoch 495/1000
# discriminator: -0.075351 - generator: 0.529593 - 0s
# Epoch 496/1000
# discriminator: 0.023811 - generator: 0.489864 - 0s
# Epoch 497/1000
# discriminator: -0.021842 - generator: 0.564397 - 0s
# Epoch 498/1000
# discriminator: 0.100578 - generator: 0.688659 - 0s
# Epoch 499/1000
# discriminator: 0.061440 - generator: 0.737588 - 0s
# Epoch 500/1000
# discriminator: 0.067975 - generator: 0.647687 - 0s
# Epoch 501/1000
# discriminator: 0.074265 - generator: 0.635384 - 0s
# Epoch 502/1000
# discriminator: 0.139474 - generator: 0.863654 - 0s
# Epoch 503/1000
# discriminator: 0.114268 - generator: 0.805499 - 0s
# Epoch 504/1000
# discriminator: 0.097481 - generator: 1.005383 - 1s
# Epoch 505/1000
# discriminator: 0.124807 - generator: 0.986461 - 1s
# Epoch 506/1000
# discriminator: 0.245192 - generator: 1.129340 - 0s
# Epoch 507/1000
# discriminator: -0.006704 - generator: 1.243939 - 0s
# Epoch 508/1000
# discriminator: 0.187209 - generator: 1.250050 - 0s
# Epoch 509/1000
# discriminator: 0.151022 - generator: 1.375014 - 0s
# Epoch 510/1000
# discriminator: 0.178173 - generator: 1.318423 - 0s
# Epoch 511/1000
# discriminator: 0.081078 - generator: 1.337941 - 0s
# Epoch 512/1000
# discriminator: 0.239953 - generator: 1.428577 - 0s
# Epoch 513/1000
# discriminator: 0.264941 - generator: 1.692794 - 0s
# Epoch 514/1000
# discriminator: 0.039443 - generator: 1.597855 - 0s
# Epoch 515/1000
# discriminator: 0.161208 - generator: 1.797573 - 0s
# Epoch 516/1000
# discriminator: -0.044156 - generator: 1.967470 - 0s
# Epoch 517/1000
# discriminator: -0.008586 - generator: 1.954537 - 0s
# Epoch 518/1000
# discriminator: 0.024671 - generator: 2.185068 - 0s
# Epoch 519/1000
# discriminator: 0.043110 - generator: 2.250669 - 0s
# Epoch 520/1000
# discriminator: 0.048936 - generator: 2.371573 - 0s
# Epoch 521/1000
# discriminator: -0.169443 - generator: 2.210769 - 0s
# Epoch 522/1000
# discriminator: -0.162749 - generator: 2.129969 - 0s
# Epoch 523/1000
# discriminator: -0.247811 - generator: 2.206718 - 0s
# Epoch 524/1000
# discriminator: -0.276766 - generator: 2.255136 - 0s
# Epoch 525/1000
# discriminator: -0.211510 - generator: 2.288746 - 1s
# Epoch 526/1000
# discriminator: -0.033127 - generator: 2.346281 - 0s
# Epoch 527/1000
# discriminator: -0.076129 - generator: 2.383868 - 0s
# Epoch 528/1000
# discriminator: -0.094233 - generator: 2.245959 - 0s
# Epoch 529/1000
# discriminator: -0.119175 - generator: 2.477389 - 0s
# Epoch 530/1000
# discriminator: -0.050497 - generator: 2.391387 - 0s
# Epoch 531/1000
# discriminator: 0.049828 - generator: 2.529568 - 0s
# Epoch 532/1000
# discriminator: -0.151388 - generator: 2.290822 - 0s
# Epoch 533/1000
# discriminator: -0.162372 - generator: 2.293692 - 0s
# Epoch 534/1000
# discriminator: -0.183183 - generator: 2.435386 - 0s
# Epoch 535/1000
# discriminator: -0.097932 - generator: 2.338586 - 0s
# Epoch 536/1000
# discriminator: -0.113990 - generator: 2.389426 - 0s
# Epoch 537/1000
# discriminator: -0.086965 - generator: 2.571137 - 1s
# Epoch 538/1000
# discriminator: -0.147712 - generator: 2.608786 - 0s
# Epoch 539/1000
# discriminator: -0.234368 - generator: 2.559314 - 0s
# Epoch 540/1000
# discriminator: -0.085994 - generator: 2.589729 - 0s
# Epoch 541/1000
# discriminator: -0.190123 - generator: 2.562999 - 0s
# Epoch 542/1000
# discriminator: 0.166432 - generator: 2.687064 - 0s
# Epoch 543/1000
# discriminator: -0.165641 - generator: 2.597972 - 0s
# Epoch 544/1000
# discriminator: -0.195834 - generator: 2.633671 - 0s
# Epoch 545/1000
# discriminator: 0.028870 - generator: 2.646796 - 0s
# Epoch 546/1000
# discriminator: -0.067600 - generator: 2.973598 - 0s
# Epoch 547/1000
# discriminator: 0.116323 - generator: 2.738738 - 0s
# Epoch 548/1000
# discriminator: 0.198020 - generator: 2.598410 - 0s
# Epoch 549/1000
# discriminator: 0.066326 - generator: 2.648722 - 0s
# Epoch 550/1000
# discriminator: 0.007814 - generator: 2.744511 - 0s
# Epoch 551/1000
# discriminator: -0.002910 - generator: 2.686581 - 0s
# Epoch 552/1000
# discriminator: -0.109763 - generator: 2.818313 - 0s
# Epoch 553/1000
# discriminator: 0.116878 - generator: 2.975949 - 0s
# Epoch 554/1000
# discriminator: -0.075901 - generator: 2.966182 - 0s
# Epoch 555/1000
# discriminator: 0.290697 - generator: 2.785557 - 0s
# Epoch 556/1000

# %%
# plot loss
print('Loss: ')
fig, ax = plt.subplots(1,1, figsize=[10,5])
ax.plot(hist)
ax.legend(['loss_gen', 'loss_disc'])
#ax.set_yscale('log')
ax.grid()
plt.show()

# %%
X_generated = wgan.predict(X_test_scaled, scaler)

# %% [markdown]
# # Gaussian Process Regression

# %%
ypred_GPR = GPR_Model.train(X_train, y_train, X_test, n_features)

# %% [markdown]
# # Comparison
#
# ### Prediction Plots

# %%
# generates the plots
if scenario in ("3d", "helix"):
    fig = plt.figure(figsize=(13, 4))

    #---- First subplot
    ax = fig.add_subplot(1, 3, 1, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], y_test, color='orange')
    ax.set_title("Sample Data")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-4,4)
    ax.set_ylim(-4,4)
    ax.set_zlim(0,7)

    ax = fig.add_subplot(1, 3, 2, projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], color='green', label='Generated Data')
    ax.set_title("WGAN-GP Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-4,4)
    ax.set_ylim(-4,4)
    ax.set_zlim(0,7)

    ax = fig.add_subplot(1, 3, 3, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], ypred_GPR, c='b', label='Generated Data')
    ax.set_title("GPR Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-4,4)
    ax.set_ylim(-4,4)
    ax.set_zlim(0,7)
    
    plt.tight_layout(pad=-1, w_pad=0.8, h_pad=0)
    

else:
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)
    axes[0].scatter(X_test, y_test, label='Real Data', color='orange')
    axes[0].set_title("Sample Data")
    axes[0].set_xlabel("x")
    axes[0].set_ylabel("y")

    axes[1].scatter(X_generated[:,0], X_generated[:,1], label="Generated Data by WGAN-GP", color='green')
    axes[1].set_title("WGAN-GP Predictions")
    axes[1].set_xlabel("x")

    axes[2].scatter(X_test, ypred_GPR, label='Generated Data by GPR')
    axes[2].set_title("GPR Predictions")
    axes[2].set_xlabel("x")

# %% [markdown]
# ### Probability Density Plots

# %%
sns.distplot(y_train, hist=False, label='True')
sns.distplot(ypred_GPR, hist=False, label='GPR')
sns.distplot(X_generated[:,1], hist=False, label='GAN Generated')
plt.xlabel("Y")
plt.ylabel("Probability Density")
plt.legend(loc='best');

# %%
# user inputs
values = [-1,0,1] # input values
bounds = 0.75 # determine interval size

# for graph axis
x_min = 0
x_max = 20

# %%
# generating the plots
if scenario in ("3d", "helix"):
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[0], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[0], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[0], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x & y = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Z")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[1], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[1], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[1], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x & y = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Z")
    ax2.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[2], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[2], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[2], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x & y = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Z")
    ax3.set_xlim(x_min, x_max)

else:
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[0], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[0], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[0], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Y")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[1], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[1], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[1], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Y")
    ax2.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[2], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[2], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[2], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Y")
    ax3.set_xlim(x_min, x_max)
