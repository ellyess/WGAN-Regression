# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import random

import sys
sys.path.append("..")

import dataset, network, GPR_Model, prob_dist
import WGAN_Model

# %% [markdown]
# # Load data

# %%
scenario = "moons"
n_instance = 1000 # number of generated points
n_features = 2

if scenario in ("3d", "helix") :
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)

os.system('mkdir Dataset')
os.system('mkdir GANS')
os.system('mkdir GANS/Models')
os.system('mkdir GANS/Losses')
os.system('mkdir GANS/Random_test')
export_excel(X_train, 'Dataset/X_train')
export_excel(y_train, 'Dataset/y_train')
# print(X_train.shape,y_train.shape)
X_train = import_excel('Dataset/X_train')
y_train = import_excel('Dataset/y_train')
print('made dataset')
# Preprocessing
vars = np.zeros((6,864))
j = 0
for i in range(6):
    for i2 in range(4):
        for i3 in range(3):
            for i4 in range(2):
                for i5 in range(3):
                    for i6 in range(2):
                        vars[0,j]=i+2
                        vars[1,j]=i2
                        vars[2,j]=i3
                        vars[3,j]=i4
                        vars[4,j]=i5
                        vars[5,j]=i6
                        j = j +1
j = 0#int(sys.argv[1])-1
print(vars[:,j])
n_features = 2
n_var =int(vars[0,j])
latent_spaces = [3,10,50,100]
latent_space = 3#int(latent_spaces[int(vars[1,j])])
batchs = [10,100,1000]
BATCH_SIZE = 100#int(batchs[int(vars[2,j])])
scales = ['-1-1','0-1']
scaled = '-1-1'#scales[int(vars[3,j])]
epochs = 1001   #[1000,10000,10000]
# epoch = int(epochs[int(vars[4,j])])
bias = [True,False]
use_bias = True#(bias[int(vars[5,j])])
# Out:
# made dataset
# [2. 0. 0. 0. 0. 0.]

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Preprocessing

# %%
wgan = WGAN_Model.WGAN(n_features,latent_space,BATCH_SIZE,n_var,use_bias)
train_dataset, scaler, X_train_scaled = wgan.preproc(X_train, y_train, scaled)
hist = wgan.train(train_dataset, epochs, scaler, scaled, X_train, y_train)
wgan.generator.save('GANS/Models/GAN_'+str(j))
# plot loss
print('Loss: ')
fig, ax = plt.subplots(1,1, figsize=[10,5])
ax.plot(hist)
ax.legend(['loss_gen', 'loss_disc'])
#ax.set_yscale('log')
ax.grid()
plt.tight_layout()
plt.savefig('GANS/Losses/GANS_loss'+str(j)+'.png')
generator = keras.models.load_model('GANS/Models/GAN_'+str(j))
plt.close()
# Out:
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# every time the data shape (100, 2)
# Epoch 0/1001
# critic: 25.568979 - generator: 0.070247 - 3s
# Epoch 1/1001
# critic: 2.688954 - generator: 0.000613 - 0s
# Epoch 2/1001
# critic: 0.176120 - generator: -0.001025 - 1s
# Epoch 3/1001
# critic: 0.034078 - generator: -0.007843 - 0s
# Epoch 4/1001
# critic: 0.023872 - generator: -0.019241 - 0s
# Epoch 5/1001
# critic: 0.030154 - generator: -0.024663 - 0s
# Epoch 6/1001
# critic: 0.019505 - generator: -0.033050 - 1s
# Epoch 7/1001
# critic: 0.025594 - generator: -0.040037 - 0s
# Epoch 8/1001
# critic: 0.018164 - generator: -0.052804 - 0s
# Epoch 9/1001
# critic: 0.022046 - generator: -0.061853 - 0s
# Epoch 10/1001
# critic: 0.023408 - generator: -0.069584 - 0s
# Epoch 11/1001
# critic: 0.019457 - generator: -0.076791 - 0s
# Epoch 12/1001
# critic: 0.015165 - generator: -0.082658 - 0s
# Epoch 13/1001
# critic: 0.027290 - generator: -0.095384 - 0s
# Epoch 14/1001
# critic: 0.037055 - generator: -0.102816 - 0s
# Epoch 15/1001
# critic: 0.022575 - generator: -0.108251 - 0s
# Epoch 16/1001
# critic: 0.020684 - generator: -0.115601 - 0s
# Epoch 17/1001
# critic: 0.017669 - generator: -0.118765 - 0s
# Epoch 18/1001
# critic: 0.017717 - generator: -0.123137 - 0s
# Epoch 19/1001
# critic: 0.024663 - generator: -0.123612 - 0s
# Epoch 20/1001
# critic: 0.034461 - generator: -0.124099 - 0s
# Epoch 21/1001
# critic: 0.027552 - generator: -0.127057 - 0s
# Epoch 22/1001
# critic: 0.032897 - generator: -0.127540 - 0s
# Epoch 23/1001
# critic: 0.021437 - generator: -0.128156 - 0s
# Epoch 24/1001
# critic: 0.022266 - generator: -0.123292 - 0s
# Epoch 25/1001
# critic: 0.022047 - generator: -0.127166 - 0s
# Epoch 26/1001
# critic: 0.029026 - generator: -0.130562 - 0s
# Epoch 27/1001
# critic: 0.026986 - generator: -0.124924 - 0s
# Epoch 28/1001
# critic: 0.019485 - generator: -0.130389 - 0s
# Epoch 29/1001
# critic: 0.025529 - generator: -0.129109 - 0s
# Epoch 30/1001
# critic: 0.030013 - generator: -0.127556 - 0s
# Epoch 31/1001
# critic: 0.029520 - generator: -0.129072 - 0s
# Epoch 32/1001
# critic: 0.025325 - generator: -0.128980 - 0s
# Epoch 33/1001
# critic: 0.029414 - generator: -0.122372 - 0s
# Epoch 34/1001
# critic: 0.029364 - generator: -0.122721 - 0s
# Epoch 35/1001
# critic: 0.025976 - generator: -0.118179 - 0s
# Epoch 36/1001
# critic: 0.030323 - generator: -0.112393 - 0s
# Epoch 37/1001
# critic: 0.027385 - generator: -0.116549 - 0s
# Epoch 38/1001
# critic: 0.027154 - generator: -0.123225 - 0s
# Epoch 39/1001
# critic: 0.029747 - generator: -0.123592 - 0s
# Epoch 40/1001
# critic: 0.031739 - generator: -0.122516 - 0s
# Epoch 41/1001
# critic: 0.025656 - generator: -0.116855 - 0s
# Epoch 42/1001
# critic: 0.024843 - generator: -0.115419 - 0s
# Epoch 43/1001
# critic: 0.028486 - generator: -0.104431 - 0s
# Epoch 44/1001
# critic: 0.024818 - generator: -0.113454 - 0s
# Epoch 45/1001
# critic: 0.026805 - generator: -0.111395 - 0s
# Epoch 46/1001
# critic: 0.022583 - generator: -0.106167 - 0s
# Epoch 47/1001
# critic: 0.027529 - generator: -0.106675 - 0s
# Epoch 48/1001
# critic: 0.033895 - generator: -0.109275 - 0s
# Epoch 49/1001
# critic: 0.033593 - generator: -0.112387 - 0s
# Epoch 50/1001
# critic: 0.025051 - generator: -0.115361 - 0s
# Epoch 51/1001
# critic: 0.027259 - generator: -0.114793 - 0s
# Epoch 52/1001
# critic: 0.025210 - generator: -0.119652 - 0s
# Epoch 53/1001
# critic: 0.027581 - generator: -0.112108 - 0s
# Epoch 54/1001
# critic: 0.026654 - generator: -0.115012 - 0s
# Epoch 55/1001
# critic: 0.022277 - generator: -0.113917 - 1s
# Epoch 56/1001
# critic: 0.037606 - generator: -0.118175 - 0s
# Epoch 57/1001
# critic: 0.031411 - generator: -0.117958 - 0s
# Epoch 58/1001
# critic: 0.026676 - generator: -0.123886 - 0s
# Epoch 59/1001
# critic: 0.026181 - generator: -0.130423 - 0s
# Epoch 60/1001
# critic: 0.028910 - generator: -0.135358 - 0s
# Epoch 61/1001
# critic: 0.032483 - generator: -0.126818 - 0s
# Epoch 62/1001
# critic: 0.022315 - generator: -0.132630 - 0s
# Epoch 63/1001
# critic: 0.027036 - generator: -0.132911 - 0s
# Epoch 64/1001
# critic: 0.030786 - generator: -0.125757 - 0s
# Epoch 65/1001
# critic: 0.028733 - generator: -0.125349 - 0s
# Epoch 66/1001
# critic: 0.029621 - generator: -0.122990 - 0s
# Epoch 67/1001
# critic: 0.031012 - generator: -0.121220 - 1s
# Epoch 68/1001
# critic: 0.028020 - generator: -0.132084 - 0s
# Epoch 69/1001
# critic: 0.024225 - generator: -0.115723 - 0s
# Epoch 70/1001
# critic: 0.030966 - generator: -0.129223 - 0s
# Epoch 71/1001
# critic: 0.023838 - generator: -0.126994 - 0s
# Epoch 72/1001
# critic: 0.027896 - generator: -0.130682 - 0s
# Epoch 73/1001
# critic: 0.027139 - generator: -0.129798 - 0s
# Epoch 74/1001
# critic: 0.029060 - generator: -0.131594 - 0s
# Epoch 75/1001
# critic: 0.034973 - generator: -0.131477 - 0s
# Epoch 76/1001
# critic: 0.023300 - generator: -0.135917 - 0s
# Epoch 77/1001
# critic: 0.026047 - generator: -0.134290 - 0s
# Epoch 78/1001
# critic: 0.029338 - generator: -0.125773 - 0s
# Epoch 79/1001
# critic: 0.028433 - generator: -0.131305 - 0s
# Epoch 80/1001
# critic: 0.019193 - generator: -0.124576 - 0s
# Epoch 81/1001
# critic: 0.018784 - generator: -0.119864 - 0s
# Epoch 82/1001
# critic: 0.023357 - generator: -0.119690 - 0s
# Epoch 83/1001
# critic: 0.027060 - generator: -0.124522 - 0s
# Epoch 84/1001
# critic: 0.035080 - generator: -0.122195 - 0s
# Epoch 85/1001
# critic: 0.016614 - generator: -0.127656 - 0s
# Epoch 86/1001
# critic: 0.021245 - generator: -0.125087 - 0s
# Epoch 87/1001
# critic: 0.028238 - generator: -0.134848 - 0s
# Epoch 88/1001
# critic: 0.027495 - generator: -0.140637 - 0s
# Epoch 89/1001
# critic: 0.036221 - generator: -0.139536 - 0s
# Epoch 90/1001
# critic: 0.035780 - generator: -0.142084 - 1s
# Epoch 91/1001
# critic: 0.024387 - generator: -0.137261 - 0s
# Epoch 92/1001
# critic: 0.033898 - generator: -0.139775 - 0s
# Epoch 93/1001
# critic: 0.024793 - generator: -0.141957 - 0s
# Epoch 94/1001
# critic: 0.031182 - generator: -0.140327 - 0s
# Epoch 95/1001
# critic: 0.021342 - generator: -0.145852 - 0s
# Epoch 96/1001
# critic: 0.019208 - generator: -0.151455 - 0s
# Epoch 97/1001
# critic: 0.031263 - generator: -0.157938 - 1s
# Epoch 98/1001
# critic: 0.031839 - generator: -0.163076 - 0s
# Epoch 99/1001
# critic: 0.020708 - generator: -0.149761 - 0s
# Epoch 100/1001
# critic: 0.029246 - generator: -0.157890 - 0s
# Epoch 101/1001
# critic: 0.033402 - generator: -0.152588 - 0s
# Epoch 102/1001
# critic: 0.024386 - generator: -0.147543 - 0s
# Epoch 103/1001
# critic: 0.032790 - generator: -0.146951 - 0s
# Epoch 104/1001
# critic: 0.027668 - generator: -0.141939 - 0s
# Epoch 105/1001
# critic: 0.023909 - generator: -0.140643 - 0s
# Epoch 106/1001
# critic: 0.029838 - generator: -0.143357 - 0s
# Epoch 107/1001
# critic: 0.026188 - generator: -0.141938 - 0s
# Epoch 108/1001
# critic: 0.037015 - generator: -0.149648 - 0s
# Epoch 109/1001
# critic: 0.039801 - generator: -0.142260 - 0s
# Epoch 110/1001
# critic: 0.030545 - generator: -0.140615 - 0s
# Epoch 111/1001
# critic: 0.029042 - generator: -0.131273 - 0s
# Epoch 112/1001
# critic: 0.024143 - generator: -0.136179 - 0s
# Epoch 113/1001
# critic: 0.042132 - generator: -0.137109 - 0s
# Epoch 114/1001
# critic: 0.028055 - generator: -0.132523 - 0s
# Epoch 115/1001
# critic: 0.025088 - generator: -0.131276 - 0s
# Epoch 116/1001
# critic: 0.024487 - generator: -0.127451 - 0s
# Epoch 117/1001
# critic: 0.025621 - generator: -0.122053 - 0s
# Epoch 118/1001
# critic: 0.031852 - generator: -0.125088 - 0s
# Epoch 119/1001
# critic: 0.031111 - generator: -0.133959 - 0s
# Epoch 120/1001
# critic: 0.024644 - generator: -0.133664 - 0s
# Epoch 121/1001
# critic: 0.028217 - generator: -0.126505 - 0s
# Epoch 122/1001
# critic: 0.026509 - generator: -0.124533 - 0s
# Epoch 123/1001
# critic: 0.021606 - generator: -0.113439 - 0s
# Epoch 124/1001
# critic: 0.022321 - generator: -0.112446 - 0s
# Epoch 125/1001
# critic: 0.026713 - generator: -0.106153 - 0s
# Epoch 126/1001
# critic: 0.030266 - generator: -0.109716 - 0s
# Epoch 127/1001
# critic: 0.029438 - generator: -0.107248 - 0s
# Epoch 128/1001
# critic: 0.031368 - generator: -0.109164 - 1s
# Epoch 129/1001
# critic: 0.022176 - generator: -0.109392 - 1s
# Epoch 130/1001
# critic: 0.030306 - generator: -0.107703 - 1s
# Epoch 131/1001
# critic: 0.030922 - generator: -0.112434 - 0s
# Epoch 132/1001
# critic: 0.029925 - generator: -0.112389 - 1s
# Epoch 133/1001
# critic: 0.028700 - generator: -0.110202 - 0s
# Epoch 134/1001
# critic: 0.017319 - generator: -0.109931 - 0s
# Epoch 135/1001
# critic: 0.028686 - generator: -0.107767 - 0s
# Epoch 136/1001
# critic: 0.029966 - generator: -0.107580 - 1s
# Epoch 137/1001
# critic: 0.016829 - generator: -0.107399 - 1s
# Epoch 138/1001
# critic: 0.020160 - generator: -0.108393 - 1s
# Epoch 139/1001
# critic: 0.031876 - generator: -0.107319 - 0s
# Epoch 140/1001
# critic: 0.027244 - generator: -0.118049 - 1s
# Epoch 141/1001
# critic: 0.024614 - generator: -0.117202 - 0s
# Epoch 142/1001
# critic: 0.026510 - generator: -0.112457 - 0s
# Epoch 143/1001
# critic: 0.021969 - generator: -0.111223 - 0s
# Epoch 144/1001
# critic: 0.030914 - generator: -0.109044 - 0s
# Epoch 145/1001
# critic: 0.021679 - generator: -0.108447 - 0s
# Epoch 146/1001
# critic: 0.027273 - generator: -0.110019 - 0s
# Epoch 147/1001
# critic: 0.024759 - generator: -0.109656 - 0s
# Epoch 148/1001
# critic: 0.017976 - generator: -0.107778 - 0s
# Epoch 149/1001
# critic: 0.025305 - generator: -0.107996 - 0s
# Epoch 150/1001
# critic: 0.027444 - generator: -0.111139 - 0s
# Epoch 151/1001
# critic: 0.019496 - generator: -0.115176 - 1s
# Epoch 152/1001
# critic: 0.031274 - generator: -0.117117 - 1s
# Epoch 153/1001
# critic: 0.021385 - generator: -0.111520 - 0s
# Epoch 154/1001
# critic: 0.025861 - generator: -0.108832 - 0s
# Epoch 155/1001
# critic: 0.021637 - generator: -0.119899 - 0s
# Epoch 156/1001
# critic: 0.026514 - generator: -0.130861 - 0s
# Epoch 157/1001
# critic: 0.025348 - generator: -0.130476 - 0s
# Epoch 158/1001
# critic: 0.023151 - generator: -0.130760 - 0s
# Epoch 159/1001
# critic: 0.027114 - generator: -0.119629 - 0s
# Epoch 160/1001
# critic: 0.033967 - generator: -0.110903 - 1s
# Epoch 161/1001
# critic: 0.023605 - generator: -0.112101 - 0s
# Epoch 162/1001
# critic: 0.023253 - generator: -0.108549 - 0s
# Epoch 163/1001
# critic: 0.027003 - generator: -0.102125 - 0s
# Epoch 164/1001
# critic: 0.020767 - generator: -0.107849 - 0s
# Epoch 165/1001
# critic: 0.026613 - generator: -0.101548 - 0s
# Epoch 166/1001
# critic: 0.022766 - generator: -0.110628 - 0s
# Epoch 167/1001
# critic: 0.019664 - generator: -0.114751 - 0s
# Epoch 168/1001
# critic: 0.027597 - generator: -0.113567 - 0s
# Epoch 169/1001
# critic: 0.026942 - generator: -0.113389 - 0s
# Epoch 170/1001
# critic: 0.024359 - generator: -0.113815 - 0s
# Epoch 171/1001
# critic: 0.027797 - generator: -0.104637 - 0s
# Epoch 172/1001
# critic: 0.021512 - generator: -0.106514 - 1s
# Epoch 173/1001
# critic: 0.026763 - generator: -0.100979 - 1s
# Epoch 174/1001
# critic: 0.025204 - generator: -0.101403 - 1s
# Epoch 175/1001
# critic: 0.025529 - generator: -0.109351 - 1s
# Epoch 176/1001
# critic: 0.029057 - generator: -0.104748 - 0s
# Epoch 177/1001
# critic: 0.025334 - generator: -0.107476 - 0s
# Epoch 178/1001
# critic: 0.024189 - generator: -0.108681 - 0s
# Epoch 179/1001
# critic: 0.021263 - generator: -0.110630 - 0s
# Epoch 180/1001
# critic: 0.023883 - generator: -0.108194 - 0s
# Epoch 181/1001
# critic: 0.027943 - generator: -0.101988 - 0s
# Epoch 182/1001
# critic: 0.021029 - generator: -0.098698 - 0s
# Epoch 183/1001
# critic: 0.023060 - generator: -0.100709 - 0s
# Epoch 184/1001
# critic: 0.023622 - generator: -0.099702 - 0s
# Epoch 185/1001
# critic: 0.018890 - generator: -0.109590 - 1s
# Epoch 186/1001
# critic: 0.026077 - generator: -0.104380 - 1s
# Epoch 187/1001
# critic: 0.027018 - generator: -0.111996 - 1s
# Epoch 188/1001
# critic: 0.021956 - generator: -0.111153 - 0s
# Epoch 189/1001
# critic: 0.024792 - generator: -0.110819 - 0s
# Epoch 190/1001
# critic: 0.029741 - generator: -0.108783 - 0s
# Epoch 191/1001
# critic: 0.018075 - generator: -0.101309 - 0s
# Epoch 192/1001
# critic: 0.028321 - generator: -0.102840 - 0s
# Epoch 193/1001
# critic: 0.026529 - generator: -0.101268 - 0s
# Epoch 194/1001
# critic: 0.022136 - generator: -0.111389 - 0s
# Epoch 195/1001
# critic: 0.021607 - generator: -0.106953 - 0s
# Epoch 196/1001
# critic: 0.031426 - generator: -0.104138 - 0s
# Epoch 197/1001
# critic: 0.025254 - generator: -0.105194 - 1s
# Epoch 198/1001
# critic: 0.024452 - generator: -0.104426 - 1s
# Epoch 199/1001
# critic: 0.028197 - generator: -0.091609 - 0s
# Epoch 200/1001
# critic: 0.020904 - generator: -0.095070 - 0s
# Epoch 201/1001
# critic: 0.018830 - generator: -0.085596 - 1s
# Epoch 202/1001
# critic: 0.024973 - generator: -0.088422 - 1s
# Epoch 203/1001
# critic: 0.019689 - generator: -0.087100 - 1s
# Epoch 204/1001
# critic: 0.030911 - generator: -0.083558 - 1s
# Epoch 205/1001
# critic: 0.019644 - generator: -0.091667 - 1s
# Epoch 206/1001
# critic: 0.033285 - generator: -0.086905 - 1s
# Epoch 207/1001
# critic: 0.026448 - generator: -0.092785 - 0s
# Epoch 208/1001
# critic: 0.022481 - generator: -0.088703 - 0s
# Epoch 209/1001
# critic: 0.019629 - generator: -0.083564 - 0s
# Epoch 210/1001
# critic: 0.028769 - generator: -0.083190 - 1s
# Epoch 211/1001
# critic: 0.017080 - generator: -0.079642 - 1s
# Epoch 212/1001
# critic: 0.017111 - generator: -0.076999 - 1s
# Epoch 213/1001
# critic: 0.014787 - generator: -0.077097 - 0s
# Epoch 214/1001
# critic: 0.023755 - generator: -0.077336 - 1s
# Epoch 215/1001
# critic: 0.026578 - generator: -0.074974 - 0s
# Epoch 216/1001
# critic: 0.024115 - generator: -0.082977 - 0s
# Epoch 217/1001
# critic: 0.024010 - generator: -0.073038 - 0s
# Epoch 218/1001
# critic: 0.019755 - generator: -0.072907 - 0s
# Epoch 219/1001
# critic: 0.023322 - generator: -0.072466 - 0s
# Epoch 220/1001
# critic: 0.025118 - generator: -0.078744 - 0s
# Epoch 221/1001
# critic: 0.023706 - generator: -0.077205 - 0s
# Epoch 222/1001
# critic: 0.029692 - generator: -0.078945 - 1s
# Epoch 223/1001
# critic: 0.020690 - generator: -0.079112 - 0s
# Epoch 224/1001
# critic: 0.024181 - generator: -0.074602 - 0s
# Epoch 225/1001
# critic: 0.018261 - generator: -0.078158 - 0s
# Epoch 226/1001
# critic: 0.029231 - generator: -0.083756 - 0s
# Epoch 227/1001
# critic: 0.021820 - generator: -0.086860 - 0s
# Epoch 228/1001
# critic: 0.018510 - generator: -0.094798 - 0s
# Epoch 229/1001
# critic: 0.020600 - generator: -0.090184 - 0s
# Epoch 230/1001
# critic: 0.027893 - generator: -0.093999 - 0s
# Epoch 231/1001
# critic: 0.029077 - generator: -0.089644 - 0s
# Epoch 232/1001
# critic: 0.023821 - generator: -0.090503 - 0s
# Epoch 233/1001
# critic: 0.012294 - generator: -0.089523 - 0s
# Epoch 234/1001
# critic: 0.027144 - generator: -0.093507 - 1s
# Epoch 235/1001
# critic: 0.019825 - generator: -0.087005 - 1s
# Epoch 236/1001
# critic: 0.023749 - generator: -0.084742 - 0s
# Epoch 237/1001
# critic: 0.027215 - generator: -0.090280 - 0s
# Epoch 238/1001
# critic: 0.024872 - generator: -0.088864 - 1s
# Epoch 239/1001
# critic: 0.020602 - generator: -0.080124 - 0s
# Epoch 240/1001
# critic: 0.016655 - generator: -0.078871 - 1s
# Epoch 241/1001
# critic: 0.027875 - generator: -0.078681 - 1s
# Epoch 242/1001
# critic: 0.025438 - generator: -0.076579 - 1s
# Epoch 243/1001
# critic: 0.032975 - generator: -0.069227 - 1s
# Epoch 244/1001
# critic: 0.025952 - generator: -0.073226 - 1s
# Epoch 245/1001
# critic: 0.022051 - generator: -0.074188 - 1s
# Epoch 246/1001
# critic: 0.021624 - generator: -0.078228 - 1s
# Epoch 247/1001
# critic: 0.027967 - generator: -0.083110 - 1s
# Epoch 248/1001
# critic: 0.023937 - generator: -0.079586 - 0s
# Epoch 249/1001
# critic: 0.024877 - generator: -0.073986 - 0s
# Epoch 250/1001
# critic: 0.027070 - generator: -0.082807 - 0s
# Epoch 251/1001
# critic: 0.026619 - generator: -0.073363 - 0s
# Epoch 252/1001
# critic: 0.019585 - generator: -0.069456 - 0s
# Epoch 253/1001
# critic: 0.028080 - generator: -0.072030 - 0s
# Epoch 254/1001
# critic: 0.030726 - generator: -0.068967 - 0s
# Epoch 255/1001
# critic: 0.032746 - generator: -0.066757 - 0s
# Epoch 256/1001
# critic: 0.019704 - generator: -0.059785 - 0s
# Epoch 257/1001
# critic: 0.027583 - generator: -0.058389 - 0s
# Epoch 258/1001
# critic: 0.027068 - generator: -0.068825 - 0s
# Epoch 259/1001
# critic: 0.026381 - generator: -0.069736 - 0s
# Epoch 260/1001
# critic: 0.019359 - generator: -0.066307 - 0s
# Epoch 261/1001
# critic: 0.033042 - generator: -0.059607 - 1s
# Epoch 262/1001
# critic: 0.031216 - generator: -0.055495 - 0s
# Epoch 263/1001
# critic: 0.028369 - generator: -0.061788 - 0s
# Epoch 264/1001
# critic: 0.028459 - generator: -0.055042 - 0s
# Epoch 265/1001
# critic: 0.024716 - generator: -0.053223 - 0s
# Epoch 266/1001
# critic: 0.019956 - generator: -0.054662 - 0s
# Epoch 267/1001
# critic: 0.020079 - generator: -0.056392 - 0s
# Epoch 268/1001
# critic: 0.025182 - generator: -0.063407 - 0s
# Epoch 269/1001
# critic: 0.025773 - generator: -0.056206 - 0s
# Epoch 270/1001
# critic: 0.034528 - generator: -0.053144 - 0s
# Epoch 271/1001
# critic: 0.017152 - generator: -0.058213 - 0s
# Epoch 272/1001
# critic: 0.019279 - generator: -0.060445 - 0s
# Epoch 273/1001
# critic: 0.022278 - generator: -0.060602 - 0s
# Epoch 274/1001
# critic: 0.017258 - generator: -0.056158 - 0s
# Epoch 275/1001
# critic: 0.031646 - generator: -0.062814 - 0s
# Epoch 276/1001
# critic: 0.020097 - generator: -0.049286 - 0s
# Epoch 277/1001
# critic: 0.018406 - generator: -0.046692 - 0s
# Epoch 278/1001
# critic: 0.023951 - generator: -0.054140 - 0s
# Epoch 279/1001
# critic: 0.030433 - generator: -0.046333 - 0s
# Epoch 280/1001
# critic: 0.016685 - generator: -0.053919 - 0s
# Epoch 281/1001
# critic: 0.020613 - generator: -0.038851 - 0s
# Epoch 282/1001
# critic: 0.022051 - generator: -0.042982 - 0s
# Epoch 283/1001
# critic: 0.025628 - generator: -0.050579 - 0s
# Epoch 284/1001
# critic: 0.022710 - generator: -0.055121 - 0s
# Epoch 285/1001
# critic: 0.023416 - generator: -0.045809 - 0s
# Epoch 286/1001
# critic: 0.021049 - generator: -0.042901 - 0s
# Epoch 287/1001
# critic: 0.021939 - generator: -0.048530 - 0s
# Epoch 288/1001
# critic: 0.027320 - generator: -0.039575 - 1s
# Epoch 289/1001
# critic: 0.022248 - generator: -0.034060 - 1s
# Epoch 290/1001
# critic: 0.032477 - generator: -0.039935 - 1s
# Epoch 291/1001
# critic: 0.026540 - generator: -0.036212 - 1s
# Epoch 292/1001
# critic: 0.019092 - generator: -0.033867 - 1s
# Epoch 293/1001
# critic: 0.023638 - generator: -0.040164 - 1s
# Epoch 294/1001
# critic: 0.023064 - generator: -0.029689 - 0s
# Epoch 295/1001
# critic: 0.019147 - generator: -0.034933 - 0s
# Epoch 296/1001
# critic: 0.017593 - generator: -0.035355 - 0s
# Epoch 297/1001
# critic: 0.020366 - generator: -0.034111 - 0s
# Epoch 298/1001
# critic: 0.020503 - generator: -0.027673 - 0s
# Epoch 299/1001
# critic: 0.024981 - generator: -0.027849 - 0s
# Epoch 300/1001
# critic: 0.028924 - generator: -0.023683 - 0s
# Epoch 301/1001
# critic: 0.022518 - generator: -0.026423 - 0s
# Epoch 302/1001
# critic: 0.025785 - generator: -0.029740 - 0s
# Epoch 303/1001
# critic: 0.031697 - generator: -0.030120 - 0s
# Epoch 304/1001
# critic: 0.022755 - generator: -0.025367 - 0s
# Epoch 305/1001
# critic: 0.029835 - generator: -0.026903 - 0s
# Epoch 306/1001
# critic: 0.018063 - generator: -0.026734 - 0s
# Epoch 307/1001
# critic: 0.020330 - generator: -0.017850 - 0s
# Epoch 308/1001
# critic: 0.025830 - generator: -0.017836 - 0s
# Epoch 309/1001
# critic: 0.023571 - generator: -0.016797 - 1s
# Epoch 310/1001
# critic: 0.023277 - generator: -0.014376 - 1s
# Epoch 311/1001
# critic: 0.024104 - generator: -0.008599 - 1s
# Epoch 312/1001
# critic: 0.022440 - generator: -0.016543 - 0s
# Epoch 313/1001
# critic: 0.018523 - generator: -0.020347 - 0s
# Epoch 314/1001
# critic: 0.016365 - generator: -0.019973 - 0s
# Epoch 315/1001
# critic: 0.018350 - generator: -0.019613 - 0s
# Epoch 316/1001
# critic: 0.021153 - generator: -0.018125 - 0s
# Epoch 317/1001
# critic: 0.022473 - generator: -0.016669 - 0s
# Epoch 318/1001
# critic: 0.026223 - generator: -0.017188 - 0s
# Epoch 319/1001
# critic: 0.019421 - generator: -0.011652 - 0s
# Epoch 320/1001
# critic: 0.021459 - generator: -0.005320 - 1s
# Epoch 321/1001
# critic: 0.028042 - generator: -0.004516 - 0s
# Epoch 322/1001
# critic: 0.021401 - generator: -0.007485 - 0s
# Epoch 323/1001
# critic: 0.026363 - generator: -0.015525 - 0s
# Epoch 324/1001
# critic: 0.027925 - generator: -0.004068 - 0s
# Epoch 325/1001
# critic: 0.024695 - generator: -0.011654 - 0s
# Epoch 326/1001
# critic: 0.019642 - generator: -0.005900 - 0s
# Epoch 327/1001
# critic: 0.020930 - generator: -0.012401 - 1s
# Epoch 328/1001
# critic: 0.026444 - generator: -0.005953 - 0s
# Epoch 329/1001
# critic: 0.022961 - generator: 0.003482 - 0s
# Epoch 330/1001
# critic: 0.017375 - generator: 0.006969 - 0s
# Epoch 331/1001
# critic: 0.022605 - generator: 0.010450 - 0s
# Epoch 332/1001
# critic: 0.027479 - generator: -0.000333 - 0s
# Epoch 333/1001
# critic: 0.026579 - generator: 0.001004 - 1s
# Epoch 334/1001
# critic: 0.021168 - generator: 0.000869 - 0s
# Epoch 335/1001
# critic: 0.023388 - generator: 0.001885 - 0s
# Epoch 336/1001
# critic: 0.020822 - generator: 0.001052 - 0s
# Epoch 337/1001
# critic: 0.014729 - generator: 0.004905 - 0s
# Epoch 338/1001
# critic: 0.023617 - generator: 0.007240 - 0s
# Epoch 339/1001
# critic: 0.020832 - generator: 0.008014 - 0s
# Epoch 340/1001
# critic: 0.023144 - generator: 0.008202 - 1s
# Epoch 341/1001
# critic: 0.021644 - generator: 0.007607 - 1s
# Epoch 342/1001
# critic: 0.023374 - generator: 0.010563 - 0s
# Epoch 343/1001
# critic: 0.021246 - generator: 0.007521 - 1s
# Epoch 344/1001
# critic: 0.019636 - generator: 0.008922 - 1s
# Epoch 345/1001
# critic: 0.021520 - generator: 0.007811 - 1s
# Epoch 346/1001
# critic: 0.018424 - generator: 0.008671 - 1s
# Epoch 347/1001
# critic: 0.025098 - generator: 0.008753 - 1s
# Epoch 348/1001
# critic: 0.021203 - generator: 0.014155 - 1s
# Epoch 349/1001
# critic: 0.023080 - generator: 0.020460 - 1s
# Epoch 350/1001
# critic: 0.017980 - generator: 0.016870 - 1s
# Epoch 351/1001
# critic: 0.022126 - generator: 0.031841 - 1s
# Epoch 352/1001
# critic: 0.021251 - generator: 0.013050 - 1s
# Epoch 353/1001
# critic: 0.021204 - generator: 0.030292 - 0s
# Epoch 354/1001
# critic: 0.016082 - generator: 0.028507 - 0s
# Epoch 355/1001
# critic: 0.015450 - generator: 0.026796 - 0s
# Epoch 356/1001
# critic: 0.026941 - generator: 0.037216 - 1s
# Epoch 357/1001
# critic: 0.013514 - generator: 0.036046 - 0s
# Epoch 358/1001
# critic: 0.024285 - generator: 0.034616 - 1s
# Epoch 359/1001
# critic: 0.016945 - generator: 0.035224 - 1s
# Epoch 360/1001
# critic: 0.024811 - generator: 0.035756 - 1s
# Epoch 361/1001
# critic: 0.019893 - generator: 0.035039 - 0s
# Epoch 362/1001
# critic: 0.022195 - generator: 0.032293 - 0s
# Epoch 363/1001
# critic: 0.017308 - generator: 0.028559 - 0s
# Epoch 364/1001
# critic: 0.018856 - generator: 0.033142 - 0s
# Epoch 365/1001
# critic: 0.021346 - generator: 0.032208 - 0s
# Epoch 366/1001
# critic: 0.020603 - generator: 0.037471 - 0s
# Epoch 367/1001
# critic: 0.019146 - generator: 0.037636 - 1s
# Epoch 368/1001
# critic: 0.018277 - generator: 0.037557 - 1s
# Epoch 369/1001
# critic: 0.024160 - generator: 0.041606 - 0s
# Epoch 370/1001
# critic: 0.015972 - generator: 0.042894 - 0s
# Epoch 371/1001
# critic: 0.020173 - generator: 0.043543 - 0s
# Epoch 372/1001
# critic: 0.018765 - generator: 0.031093 - 0s
# Epoch 373/1001
# critic: 0.023047 - generator: 0.027574 - 0s
# Epoch 374/1001
# critic: 0.022740 - generator: 0.046639 - 0s
# Epoch 375/1001
# critic: 0.018097 - generator: 0.037178 - 0s
# Epoch 376/1001
# critic: 0.018325 - generator: 0.044286 - 0s
# Epoch 377/1001
# critic: 0.023743 - generator: 0.048418 - 0s
# Epoch 378/1001
# critic: 0.017917 - generator: 0.040250 - 1s
# Epoch 379/1001
# critic: 0.023942 - generator: 0.047284 - 0s
# Epoch 380/1001
# critic: 0.024198 - generator: 0.048425 - 0s
# Epoch 381/1001
# critic: 0.020294 - generator: 0.055478 - 1s
# Epoch 382/1001
# critic: 0.022700 - generator: 0.058013 - 1s
# Epoch 383/1001
# critic: 0.017752 - generator: 0.052285 - 1s
# Epoch 384/1001
# critic: 0.022295 - generator: 0.056921 - 1s
# Epoch 385/1001
# critic: 0.021300 - generator: 0.055745 - 1s
# Epoch 386/1001
# critic: 0.018499 - generator: 0.061372 - 1s
# Epoch 387/1001
# critic: 0.023766 - generator: 0.052921 - 1s
# Epoch 388/1001
# critic: 0.022873 - generator: 0.063644 - 0s
# Epoch 389/1001
# critic: 0.020878 - generator: 0.062741 - 1s
# Epoch 390/1001
# critic: 0.018472 - generator: 0.062710 - 1s
# Epoch 391/1001
# critic: 0.023521 - generator: 0.060922 - 1s
# Epoch 392/1001
# critic: 0.014121 - generator: 0.063059 - 1s
# Epoch 393/1001
# critic: 0.021390 - generator: 0.063681 - 1s
# Epoch 394/1001
# critic: 0.025441 - generator: 0.065798 - 1s
# Epoch 395/1001
# critic: 0.023647 - generator: 0.067337 - 1s
# Epoch 396/1001
# critic: 0.021329 - generator: 0.071234 - 1s
# Epoch 397/1001
# critic: 0.020135 - generator: 0.070106 - 1s
# Epoch 398/1001
# critic: 0.015144 - generator: 0.068717 - 1s
# Epoch 399/1001
# critic: 0.013974 - generator: 0.069984 - 1s
# Epoch 400/1001
# critic: 0.022799 - generator: 0.065931 - 1s
# Epoch 401/1001
# critic: 0.018720 - generator: 0.059279 - 1s
# Epoch 402/1001
# critic: 0.019805 - generator: 0.057326 - 1s
# Epoch 403/1001
# critic: 0.019004 - generator: 0.051989 - 1s
# Epoch 404/1001
# critic: 0.026864 - generator: 0.059215 - 1s
# Epoch 405/1001
# critic: 0.017539 - generator: 0.060585 - 1s
# Epoch 406/1001
# critic: 0.019334 - generator: 0.043884 - 1s
# Epoch 407/1001
# critic: 0.025195 - generator: 0.057122 - 1s
# Epoch 408/1001
# critic: 0.018597 - generator: 0.054952 - 1s
# Epoch 409/1001
# critic: 0.017117 - generator: 0.051218 - 0s
# Epoch 410/1001
# critic: 0.018998 - generator: 0.057270 - 1s
# Epoch 411/1001
# critic: 0.016848 - generator: 0.053223 - 0s
# Epoch 412/1001
# critic: 0.017862 - generator: 0.051310 - 1s
# Epoch 413/1001
# critic: 0.019877 - generator: 0.046041 - 1s
# Epoch 414/1001
# critic: 0.019948 - generator: 0.050625 - 1s
# Epoch 415/1001
# critic: 0.015979 - generator: 0.057211 - 1s
# Epoch 416/1001
# critic: 0.015582 - generator: 0.055578 - 1s
# Epoch 417/1001
# critic: 0.020252 - generator: 0.061314 - 0s
# Epoch 418/1001
# critic: 0.018704 - generator: 0.049923 - 0s
# Epoch 419/1001
# critic: 0.027638 - generator: 0.052952 - 1s
# Epoch 420/1001
# critic: 0.019001 - generator: 0.048710 - 1s
# Epoch 421/1001
# critic: 0.019029 - generator: 0.063479 - 1s
# Epoch 422/1001
# critic: 0.016799 - generator: 0.053817 - 1s
# Epoch 423/1001
# critic: 0.016175 - generator: 0.054539 - 1s
# Epoch 424/1001
# critic: 0.018092 - generator: 0.060410 - 1s
# Epoch 425/1001
# critic: 0.016528 - generator: 0.052880 - 0s
# Epoch 426/1001
# critic: 0.015149 - generator: 0.062387 - 1s
# Epoch 427/1001
# critic: 0.011896 - generator: 0.058365 - 1s
# Epoch 428/1001
# critic: 0.012150 - generator: 0.056316 - 1s
# Epoch 429/1001
# critic: 0.022862 - generator: 0.058887 - 0s
# Epoch 430/1001
# critic: 0.023032 - generator: 0.056278 - 1s
# Epoch 431/1001
# critic: 0.013904 - generator: 0.063669 - 0s
# Epoch 432/1001
# critic: 0.012143 - generator: 0.055438 - 0s
# Epoch 433/1001
# critic: 0.013915 - generator: 0.062495 - 1s
# Epoch 434/1001
# critic: 0.012150 - generator: 0.057646 - 1s
# Epoch 435/1001
# critic: 0.014654 - generator: 0.068937 - 1s
# Epoch 436/1001
# critic: 0.023395 - generator: 0.067924 - 1s
# Epoch 437/1001
# critic: 0.021209 - generator: 0.072990 - 1s
# Epoch 438/1001
# critic: 0.019981 - generator: 0.067416 - 1s
# Epoch 439/1001
# critic: 0.015179 - generator: 0.066240 - 1s
# Epoch 440/1001
# critic: 0.009545 - generator: 0.065660 - 1s
# Epoch 441/1001
# critic: 0.024375 - generator: 0.063165 - 1s
# Epoch 442/1001
# critic: 0.018340 - generator: 0.064539 - 1s
# Epoch 443/1001
# critic: 0.019661 - generator: 0.067156 - 1s
# Epoch 444/1001
# critic: 0.016781 - generator: 0.063523 - 1s
# Epoch 445/1001
# critic: 0.018575 - generator: 0.058425 - 1s
# Epoch 446/1001
# critic: 0.014571 - generator: 0.064273 - 1s
# Epoch 447/1001
# critic: 0.018151 - generator: 0.063640 - 1s
# Epoch 448/1001
# critic: 0.015248 - generator: 0.066667 - 1s
# Epoch 449/1001
# critic: 0.012866 - generator: 0.061009 - 1s
# Epoch 450/1001
# critic: 0.013106 - generator: 0.064619 - 1s
# Epoch 451/1001
# critic: 0.018798 - generator: 0.070921 - 1s
# Epoch 452/1001
# critic: 0.014938 - generator: 0.073562 - 1s
# Epoch 453/1001
# critic: 0.015351 - generator: 0.072421 - 1s
# Epoch 454/1001
# critic: 0.015159 - generator: 0.078527 - 1s
# Epoch 455/1001
# critic: 0.013102 - generator: 0.082525 - 1s
# Epoch 456/1001
# critic: 0.008823 - generator: 0.083587 - 1s
# Epoch 457/1001
# critic: 0.015044 - generator: 0.080616 - 1s
# Epoch 458/1001
# critic: 0.012309 - generator: 0.085400 - 1s
# Epoch 459/1001
# critic: 0.019070 - generator: 0.084032 - 1s
# Epoch 460/1001
# critic: 0.018200 - generator: 0.085450 - 1s
# Epoch 461/1001
# critic: 0.014742 - generator: 0.087585 - 1s
# Epoch 462/1001
# critic: 0.012018 - generator: 0.083304 - 1s
# Epoch 463/1001
# critic: 0.014037 - generator: 0.078757 - 1s
# Epoch 464/1001
# critic: 0.020983 - generator: 0.079776 - 1s
# Epoch 465/1001
# critic: 0.016441 - generator: 0.077157 - 1s
# Epoch 466/1001
# critic: 0.015056 - generator: 0.083744 - 1s
# Epoch 467/1001
# critic: 0.011970 - generator: 0.084419 - 1s
# Epoch 468/1001
# critic: 0.016183 - generator: 0.088720 - 1s
# Epoch 469/1001
# critic: 0.009711 - generator: 0.086906 - 1s
# Epoch 470/1001
# critic: 0.016809 - generator: 0.078633 - 1s
# Epoch 471/1001
# critic: 0.014628 - generator: 0.085564 - 1s
# Epoch 472/1001
# critic: 0.014585 - generator: 0.089765 - 1s
# Epoch 473/1001
# critic: 0.015844 - generator: 0.084807 - 1s
# Epoch 474/1001
# critic: 0.020224 - generator: 0.085485 - 1s
# Epoch 475/1001
# critic: 0.014964 - generator: 0.081154 - 1s
# Epoch 476/1001
# critic: 0.020087 - generator: 0.086178 - 1s
# Epoch 477/1001
# critic: 0.013451 - generator: 0.089378 - 1s
# Epoch 478/1001
# critic: 0.016446 - generator: 0.093781 - 1s
# Epoch 479/1001
# critic: 0.018225 - generator: 0.088661 - 1s
# Epoch 480/1001
# critic: 0.016643 - generator: 0.087728 - 1s
# Epoch 481/1001
# critic: 0.014413 - generator: 0.095538 - 1s
# Epoch 482/1001
# critic: 0.014020 - generator: 0.096378 - 1s
# Epoch 483/1001
# critic: 0.014113 - generator: 0.099731 - 1s
# Epoch 484/1001
# critic: 0.010245 - generator: 0.100063 - 1s
# Epoch 485/1001
# critic: 0.012017 - generator: 0.102102 - 1s
# Epoch 486/1001
# critic: 0.008378 - generator: 0.097197 - 1s
# Epoch 487/1001
# critic: 0.013190 - generator: 0.112197 - 1s
# Epoch 488/1001
# critic: 0.013788 - generator: 0.107295 - 1s
# Epoch 489/1001
# critic: 0.017364 - generator: 0.110071 - 1s
# Epoch 490/1001
# critic: 0.010181 - generator: 0.104020 - 1s
# Epoch 491/1001
# critic: 0.009723 - generator: 0.104834 - 1s
# Epoch 492/1001
# critic: 0.010840 - generator: 0.117304 - 1s
# Epoch 493/1001
# critic: 0.014518 - generator: 0.113142 - 1s
# Epoch 494/1001
# critic: 0.013523 - generator: 0.107237 - 1s
# Epoch 495/1001
# critic: 0.016185 - generator: 0.112879 - 1s
# Epoch 496/1001
# critic: 0.013594 - generator: 0.112975 - 1s
# Epoch 497/1001
# critic: 0.018965 - generator: 0.111233 - 1s
# Epoch 498/1001
# critic: 0.012118 - generator: 0.114425 - 1s
# Epoch 499/1001
# critic: 0.013799 - generator: 0.112430 - 1s
# Epoch 500/1001
# critic: 0.014155 - generator: 0.112204 - 1s
# Epoch 501/1001
# critic: 0.012762 - generator: 0.118247 - 1s
# Epoch 502/1001
# critic: 0.013598 - generator: 0.118654 - 1s
# Epoch 503/1001
# critic: 0.008860 - generator: 0.118988 - 1s
# Epoch 504/1001
# critic: 0.012847 - generator: 0.117411 - 1s
# Epoch 505/1001
# critic: 0.015526 - generator: 0.101661 - 0s
# Epoch 506/1001
# critic: 0.016414 - generator: 0.103595 - 0s
# Epoch 507/1001
# critic: 0.012182 - generator: 0.110136 - 0s
# Epoch 508/1001
# critic: 0.011695 - generator: 0.111035 - 0s
# Epoch 509/1001
# critic: 0.016822 - generator: 0.113900 - 0s
# Epoch 510/1001
# critic: 0.013740 - generator: 0.109911 - 0s
# Epoch 511/1001
# critic: 0.014825 - generator: 0.114181 - 1s
# Epoch 512/1001
# critic: 0.016665 - generator: 0.108816 - 1s
# Epoch 513/1001
# critic: 0.016441 - generator: 0.106730 - 0s
# Epoch 514/1001
# critic: 0.012984 - generator: 0.102235 - 0s
# Epoch 515/1001
# critic: 0.009950 - generator: 0.107036 - 0s
# Epoch 516/1001
# critic: 0.011485 - generator: 0.104368 - 0s
# Epoch 517/1001
# critic: 0.013347 - generator: 0.097043 - 1s
# Epoch 518/1001
# critic: 0.010623 - generator: 0.111032 - 1s
# Epoch 519/1001
# critic: 0.006240 - generator: 0.108554 - 1s
# Epoch 520/1001
# critic: 0.012527 - generator: 0.101665 - 1s
# Epoch 521/1001
# critic: 0.013014 - generator: 0.108679 - 1s
# Epoch 522/1001
# critic: 0.014003 - generator: 0.102772 - 1s
# Epoch 523/1001
# critic: 0.009970 - generator: 0.104875 - 1s
# Epoch 524/1001
# critic: 0.012539 - generator: 0.105360 - 0s
# Epoch 525/1001
# critic: 0.012841 - generator: 0.107782 - 1s
# Epoch 526/1001
# critic: 0.017745 - generator: 0.105575 - 1s
# Epoch 527/1001
# critic: 0.007942 - generator: 0.102386 - 0s
# Epoch 528/1001
# critic: 0.003110 - generator: 0.113258 - 1s
# Epoch 529/1001
# critic: 0.015515 - generator: 0.110427 - 1s
# Epoch 530/1001
# critic: 0.011546 - generator: 0.108844 - 1s
# Epoch 531/1001
# critic: 0.013255 - generator: 0.102518 - 1s
# Epoch 532/1001
# critic: 0.012260 - generator: 0.109803 - 0s
# Epoch 533/1001
# critic: 0.013375 - generator: 0.100760 - 1s
# Epoch 534/1001
# critic: 0.009562 - generator: 0.110484 - 1s
# Epoch 535/1001
# critic: 0.012262 - generator: 0.112565 - 1s
# Epoch 536/1001
# critic: 0.008893 - generator: 0.104433 - 1s
# Epoch 537/1001
# critic: 0.014158 - generator: 0.106108 - 1s
# Epoch 538/1001
# critic: 0.012309 - generator: 0.103945 - 1s
# Epoch 539/1001
# critic: 0.011766 - generator: 0.101291 - 1s
# Epoch 540/1001
# critic: 0.013882 - generator: 0.094117 - 1s
# Epoch 541/1001
# critic: 0.012166 - generator: 0.102188 - 1s
# Epoch 542/1001
# critic: 0.011747 - generator: 0.097023 - 1s
# Epoch 543/1001
# critic: 0.009083 - generator: 0.099685 - 1s
# Epoch 544/1001
# critic: 0.010328 - generator: 0.085697 - 1s
# Epoch 545/1001
# critic: 0.015329 - generator: 0.095823 - 1s
# Epoch 546/1001
# critic: 0.013375 - generator: 0.098277 - 1s
# Epoch 547/1001
# critic: 0.010843 - generator: 0.093059 - 1s
# Epoch 548/1001
# critic: 0.013858 - generator: 0.090063 - 1s
# Epoch 549/1001
# critic: 0.012047 - generator: 0.089311 - 1s
# Epoch 550/1001
# critic: 0.015299 - generator: 0.085667 - 1s
# Epoch 551/1001
# critic: 0.009288 - generator: 0.087285 - 1s
# Epoch 552/1001
# critic: 0.014889 - generator: 0.081800 - 1s
# Epoch 553/1001
# critic: 0.014326 - generator: 0.084031 - 1s
# Epoch 554/1001
# critic: 0.009323 - generator: 0.084970 - 1s
# Epoch 555/1001
# critic: 0.013358 - generator: 0.080552 - 1s
# Epoch 556/1001
# critic: 0.009561 - generator: 0.086515 - 1s
# Epoch 557/1001
# critic: 0.011470 - generator: 0.088026 - 1s
# Epoch 558/1001
# critic: 0.011657 - generator: 0.087589 - 1s
# Epoch 559/1001
# critic: 0.012049 - generator: 0.089479 - 1s
# Epoch 560/1001
# critic: 0.014640 - generator: 0.080186 - 1s
# Epoch 561/1001
# critic: 0.011776 - generator: 0.091634 - 0s
# Epoch 562/1001
# critic: 0.009778 - generator: 0.083278 - 1s
# Epoch 563/1001
# critic: 0.007542 - generator: 0.096522 - 1s
# Epoch 564/1001
# critic: 0.010356 - generator: 0.088350 - 1s
# Epoch 565/1001
# critic: 0.010154 - generator: 0.080405 - 1s
# Epoch 566/1001
# critic: 0.007790 - generator: 0.083067 - 0s
# Epoch 567/1001
# critic: 0.009942 - generator: 0.086172 - 1s
# Epoch 568/1001
# critic: 0.010192 - generator: 0.083413 - 0s
# Epoch 569/1001
# critic: 0.008072 - generator: 0.090279 - 1s
# Epoch 570/1001
# critic: 0.012501 - generator: 0.089572 - 0s
# Epoch 571/1001
# critic: 0.011313 - generator: 0.085236 - 0s
# Epoch 572/1001
# critic: 0.011133 - generator: 0.085940 - 0s
# Epoch 573/1001
# critic: 0.012100 - generator: 0.089290 - 1s
# Epoch 574/1001
# critic: 0.014658 - generator: 0.087049 - 0s
# Epoch 575/1001
# critic: 0.008598 - generator: 0.088479 - 1s
# Epoch 576/1001
# critic: 0.006578 - generator: 0.083615 - 1s
# Epoch 577/1001
# critic: 0.011307 - generator: 0.092945 - 1s
# Epoch 578/1001
# critic: 0.009454 - generator: 0.091609 - 1s
# Epoch 579/1001
# critic: 0.009997 - generator: 0.088539 - 1s
# Epoch 580/1001
# critic: 0.009513 - generator: 0.081392 - 1s
# Epoch 581/1001
# critic: 0.008140 - generator: 0.085603 - 1s
# Epoch 582/1001
# critic: 0.010439 - generator: 0.102246 - 1s
# Epoch 583/1001
# critic: 0.009751 - generator: 0.096845 - 1s
# Epoch 584/1001
# critic: 0.011855 - generator: 0.090381 - 1s
# Epoch 585/1001
# critic: 0.009786 - generator: 0.097102 - 1s
# Epoch 586/1001
# critic: 0.011159 - generator: 0.082320 - 1s
# Epoch 587/1001
# critic: 0.008888 - generator: 0.095908 - 1s
# Epoch 588/1001
# critic: 0.010310 - generator: 0.091874 - 1s
# Epoch 589/1001
# critic: 0.015960 - generator: 0.100604 - 1s
# Epoch 590/1001
# critic: 0.011122 - generator: 0.096166 - 1s
# Epoch 591/1001
# critic: 0.012978 - generator: 0.091902 - 1s
# Epoch 592/1001
# critic: 0.014352 - generator: 0.085369 - 1s
# Epoch 593/1001
# critic: 0.010452 - generator: 0.091009 - 1s
# Epoch 594/1001
# critic: 0.010739 - generator: 0.092193 - 1s
# Epoch 595/1001
# critic: 0.012472 - generator: 0.102668 - 1s
# Epoch 596/1001
# critic: 0.011265 - generator: 0.092623 - 1s
# Epoch 597/1001
# critic: 0.011299 - generator: 0.096331 - 1s
# Epoch 598/1001
# critic: 0.008271 - generator: 0.101966 - 1s
# Epoch 599/1001
# critic: 0.006081 - generator: 0.098551 - 1s
# Epoch 600/1001
# critic: 0.012184 - generator: 0.104091 - 1s
# Epoch 601/1001
# critic: 0.012717 - generator: 0.106284 - 1s
# Epoch 602/1001
# critic: 0.011729 - generator: 0.102705 - 1s
# Epoch 603/1001
# critic: 0.012598 - generator: 0.098790 - 1s
# Epoch 604/1001
# critic: 0.008566 - generator: 0.099906 - 1s
# Epoch 605/1001
# critic: 0.010176 - generator: 0.111349 - 1s
# Epoch 606/1001
# critic: 0.013553 - generator: 0.092819 - 1s
# Epoch 607/1001
# critic: 0.009778 - generator: 0.105830 - 1s
# Epoch 608/1001
# critic: 0.003501 - generator: 0.111826 - 1s
# Epoch 609/1001
# critic: 0.012431 - generator: 0.117075 - 1s
# Epoch 610/1001
# critic: 0.011631 - generator: 0.113726 - 1s
# Epoch 611/1001
# critic: 0.014521 - generator: 0.103869 - 0s
# Epoch 612/1001
# critic: 0.013030 - generator: 0.117668 - 1s
# Epoch 613/1001
# critic: 0.006868 - generator: 0.108829 - 0s
# Epoch 614/1001
# critic: 0.010048 - generator: 0.116980 - 0s
# Epoch 615/1001
# critic: 0.004088 - generator: 0.115200 - 0s
# Epoch 616/1001
# critic: 0.009187 - generator: 0.113533 - 0s
# Epoch 617/1001
# critic: 0.008232 - generator: 0.121335 - 1s
# Epoch 618/1001
# critic: 0.009159 - generator: 0.119996 - 0s
# Epoch 619/1001
# critic: 0.011115 - generator: 0.117752 - 0s
# Epoch 620/1001
# critic: 0.008994 - generator: 0.128698 - 0s
# Epoch 621/1001
# critic: 0.009811 - generator: 0.121886 - 0s
# Epoch 622/1001
# critic: 0.005005 - generator: 0.119813 - 1s
# Epoch 623/1001
# critic: 0.012165 - generator: 0.123268 - 0s
# Epoch 624/1001
# critic: 0.009598 - generator: 0.118146 - 0s
# Epoch 625/1001
# critic: 0.009200 - generator: 0.127027 - 0s
# Epoch 626/1001
# critic: 0.009220 - generator: 0.123829 - 0s
# Epoch 627/1001
# critic: 0.011819 - generator: 0.120649 - 1s
# Epoch 628/1001
# critic: 0.004677 - generator: 0.120999 - 1s
# Epoch 629/1001
# critic: 0.011335 - generator: 0.121004 - 1s
# Epoch 630/1001
# critic: 0.008473 - generator: 0.130022 - 1s
# Epoch 631/1001
# critic: 0.010121 - generator: 0.116423 - 0s
# Epoch 632/1001
# critic: 0.009320 - generator: 0.119569 - 0s
# Epoch 633/1001
# critic: 0.010581 - generator: 0.123914 - 0s
# Epoch 634/1001
# critic: 0.010284 - generator: 0.119513 - 0s
# Epoch 635/1001
# critic: 0.010309 - generator: 0.115958 - 0s
# Epoch 636/1001
# critic: 0.008340 - generator: 0.113690 - 0s
# Epoch 637/1001
# critic: 0.010406 - generator: 0.123281 - 1s
# Epoch 638/1001
# critic: 0.010401 - generator: 0.120391 - 1s
# Epoch 639/1001
# critic: 0.007941 - generator: 0.129703 - 0s
# Epoch 640/1001
# critic: 0.008012 - generator: 0.121607 - 0s
# Epoch 641/1001
# critic: 0.008033 - generator: 0.118798 - 0s
# Epoch 642/1001
# critic: 0.008929 - generator: 0.117576 - 0s
# Epoch 643/1001
# critic: 0.010400 - generator: 0.115219 - 0s
# Epoch 644/1001
# critic: 0.007714 - generator: 0.129265 - 0s
# Epoch 645/1001
# critic: 0.010513 - generator: 0.126783 - 1s
# Epoch 646/1001
# critic: 0.001493 - generator: 0.122926 - 0s
# Epoch 647/1001
# critic: 0.011647 - generator: 0.122296 - 1s
# Epoch 648/1001
# critic: 0.012237 - generator: 0.116816 - 1s
# Epoch 649/1001
# critic: 0.010330 - generator: 0.120639 - 0s
# Epoch 650/1001
# critic: 0.012265 - generator: 0.116781 - 1s
# Epoch 651/1001
# critic: 0.007249 - generator: 0.120032 - 1s
# Epoch 652/1001
# critic: 0.009732 - generator: 0.116923 - 0s
# Epoch 653/1001
# critic: 0.005145 - generator: 0.127325 - 0s
# Epoch 654/1001
# critic: 0.010571 - generator: 0.118255 - 0s
# Epoch 655/1001
# critic: 0.007693 - generator: 0.115647 - 0s
# Epoch 656/1001
# critic: 0.010574 - generator: 0.118022 - 0s
# Epoch 657/1001
# critic: 0.009128 - generator: 0.122030 - 0s
# Epoch 658/1001
# critic: 0.006920 - generator: 0.117091 - 0s
# Epoch 659/1001
# critic: 0.004284 - generator: 0.118128 - 0s
# Epoch 660/1001
# critic: 0.008603 - generator: 0.122993 - 0s
# Epoch 661/1001
# critic: 0.013546 - generator: 0.122103 - 0s
# Epoch 662/1001
# critic: 0.006741 - generator: 0.124844 - 0s
# Epoch 663/1001
# critic: 0.008460 - generator: 0.122891 - 0s
# Epoch 664/1001
# critic: 0.008025 - generator: 0.114720 - 0s
# Epoch 665/1001
# critic: 0.010995 - generator: 0.122126 - 0s
# Epoch 666/1001
# critic: 0.006162 - generator: 0.118148 - 0s
# Epoch 667/1001
# critic: 0.004362 - generator: 0.120633 - 0s
# Epoch 668/1001
# critic: 0.011139 - generator: 0.120855 - 0s
# Epoch 669/1001
# critic: 0.002924 - generator: 0.128335 - 0s
# Epoch 670/1001
# critic: 0.007831 - generator: 0.127897 - 0s
# Epoch 671/1001
# critic: 0.006239 - generator: 0.121673 - 0s
# Epoch 672/1001
# critic: 0.010445 - generator: 0.128261 - 0s
# Epoch 673/1001
# critic: 0.006634 - generator: 0.130706 - 0s
# Epoch 674/1001
# critic: 0.008633 - generator: 0.131113 - 0s
# Epoch 675/1001
# critic: 0.011500 - generator: 0.124890 - 0s
# Epoch 676/1001
# critic: 0.011348 - generator: 0.123125 - 0s
# Epoch 677/1001
# critic: 0.007563 - generator: 0.129024 - 0s
# Epoch 678/1001
# critic: 0.010375 - generator: 0.118859 - 0s
# Epoch 679/1001
# critic: 0.009609 - generator: 0.130770 - 0s
# Epoch 680/1001
# critic: 0.010766 - generator: 0.130147 - 1s
# Epoch 681/1001
# critic: 0.008176 - generator: 0.129739 - 1s
# Epoch 682/1001
# critic: 0.007190 - generator: 0.121865 - 1s
# Epoch 683/1001
# critic: 0.007114 - generator: 0.129042 - 0s
# Epoch 684/1001
# critic: 0.004275 - generator: 0.121605 - 1s
# Epoch 685/1001
# critic: 0.007984 - generator: 0.128713 - 0s
# Epoch 686/1001
# critic: 0.011026 - generator: 0.136332 - 0s
# Epoch 687/1001
# critic: 0.014469 - generator: 0.135965 - 1s
# Epoch 688/1001
# critic: 0.007651 - generator: 0.140587 - 1s
# Epoch 689/1001
# critic: 0.009078 - generator: 0.139502 - 1s
# Epoch 690/1001
# critic: 0.009993 - generator: 0.136639 - 1s
# Epoch 691/1001
# critic: 0.006644 - generator: 0.135177 - 0s
# Epoch 692/1001
# critic: 0.007055 - generator: 0.135711 - 0s
# Epoch 693/1001
# critic: 0.009349 - generator: 0.139389 - 0s
# Epoch 694/1001
# critic: 0.007671 - generator: 0.131927 - 0s
# Epoch 695/1001
# critic: 0.013142 - generator: 0.137534 - 0s
# Epoch 696/1001
# critic: 0.010864 - generator: 0.140054 - 0s
# Epoch 697/1001
# critic: 0.007034 - generator: 0.135560 - 0s
# Epoch 698/1001
# critic: 0.008347 - generator: 0.134309 - 0s
# Epoch 699/1001
# critic: 0.008876 - generator: 0.144309 - 0s
# Epoch 700/1001
# critic: 0.009519 - generator: 0.138379 - 0s
# Epoch 701/1001
# critic: 0.007596 - generator: 0.142165 - 0s
# Epoch 702/1001
# critic: 0.012347 - generator: 0.141410 - 0s
# Epoch 703/1001
# critic: 0.006549 - generator: 0.142538 - 0s
# Epoch 704/1001
# critic: 0.008029 - generator: 0.142910 - 0s
# Epoch 705/1001
# critic: 0.009691 - generator: 0.130809 - 0s
# Epoch 706/1001
# critic: 0.008339 - generator: 0.137025 - 0s
# Epoch 707/1001
# critic: 0.009174 - generator: 0.139928 - 0s
# Epoch 708/1001
# critic: 0.004613 - generator: 0.144274 - 0s
# Epoch 709/1001
# critic: 0.008218 - generator: 0.135314 - 0s
# Epoch 710/1001
# critic: 0.009911 - generator: 0.137642 - 0s
# Epoch 711/1001
# critic: 0.007880 - generator: 0.147356 - 0s
# Epoch 712/1001
# critic: 0.005894 - generator: 0.144762 - 0s
# Epoch 713/1001
# critic: 0.009959 - generator: 0.141415 - 0s
# Epoch 714/1001
# critic: 0.005443 - generator: 0.135739 - 0s
# Epoch 715/1001
# critic: 0.011600 - generator: 0.137553 - 0s
# Epoch 716/1001
# critic: 0.006222 - generator: 0.136517 - 0s
# Epoch 717/1001
# critic: 0.012081 - generator: 0.146019 - 0s
# Epoch 718/1001
# critic: 0.010737 - generator: 0.139050 - 0s
# Epoch 719/1001
# critic: 0.007438 - generator: 0.143646 - 0s
# Epoch 720/1001
# critic: 0.010639 - generator: 0.135575 - 0s
# Epoch 721/1001
# critic: 0.009362 - generator: 0.139135 - 0s
# Epoch 722/1001
# critic: 0.005181 - generator: 0.139331 - 0s
# Epoch 723/1001
# critic: 0.007375 - generator: 0.140248 - 0s
# Epoch 724/1001
# critic: 0.005827 - generator: 0.133664 - 0s
# Epoch 725/1001
# critic: 0.007765 - generator: 0.137181 - 0s
# Epoch 726/1001
# critic: 0.007812 - generator: 0.145696 - 0s
# Epoch 727/1001
# critic: 0.007657 - generator: 0.135030 - 0s
# Epoch 728/1001
# critic: 0.008284 - generator: 0.146764 - 1s
# Epoch 729/1001
# critic: 0.007682 - generator: 0.135811 - 0s
# Epoch 730/1001
# critic: 0.009888 - generator: 0.131906 - 1s
# Epoch 731/1001
# critic: 0.009949 - generator: 0.132690 - 1s
# Epoch 732/1001
# critic: 0.012565 - generator: 0.139952 - 1s
# Epoch 733/1001
# critic: 0.004121 - generator: 0.144395 - 0s
# Epoch 734/1001
# critic: 0.010193 - generator: 0.134761 - 0s
# Epoch 735/1001
# critic: 0.010694 - generator: 0.139577 - 0s
# Epoch 736/1001
# critic: 0.008616 - generator: 0.141029 - 1s
# Epoch 737/1001
# critic: 0.008788 - generator: 0.135255 - 1s
# Epoch 738/1001
# critic: 0.009596 - generator: 0.140442 - 0s
# Epoch 739/1001
# critic: 0.006197 - generator: 0.143315 - 0s
# Epoch 740/1001
# critic: 0.004372 - generator: 0.142557 - 0s
# Epoch 741/1001
# critic: 0.003928 - generator: 0.143394 - 1s
# Epoch 742/1001
# critic: 0.009821 - generator: 0.149428 - 0s
# Epoch 743/1001
# critic: 0.003092 - generator: 0.148239 - 0s
# Epoch 744/1001
# critic: 0.004783 - generator: 0.139234 - 0s
# Epoch 745/1001
# critic: 0.008840 - generator: 0.135645 - 0s
# Epoch 746/1001
# critic: 0.007815 - generator: 0.141516 - 0s
# Epoch 747/1001
# critic: 0.004472 - generator: 0.151966 - 1s
# Epoch 748/1001
# critic: 0.009198 - generator: 0.143644 - 1s
# Epoch 749/1001
# critic: 0.006893 - generator: 0.153858 - 0s
# Epoch 750/1001
# critic: 0.010676 - generator: 0.139834 - 0s
# Epoch 751/1001
# critic: 0.009091 - generator: 0.142981 - 0s
# Epoch 752/1001
# critic: 0.007266 - generator: 0.146523 - 0s
# Epoch 753/1001
# critic: 0.005920 - generator: 0.145350 - 0s
# Epoch 754/1001
# critic: 0.006356 - generator: 0.148681 - 0s
# Epoch 755/1001
# critic: 0.004879 - generator: 0.144720 - 0s
# Epoch 756/1001
# critic: 0.008645 - generator: 0.140027 - 0s
# Epoch 757/1001
# critic: 0.006548 - generator: 0.145878 - 0s
# Epoch 758/1001
# critic: 0.006443 - generator: 0.157385 - 1s
# Epoch 759/1001
# critic: 0.013586 - generator: 0.143560 - 0s
# Epoch 760/1001
# critic: 0.008284 - generator: 0.148104 - 0s
# Epoch 761/1001
# critic: 0.006296 - generator: 0.146387 - 0s
# Epoch 762/1001
# critic: 0.009567 - generator: 0.142465 - 0s
# Epoch 763/1001
# critic: 0.009220 - generator: 0.154590 - 0s
# Epoch 764/1001
# critic: 0.012905 - generator: 0.149682 - 0s
# Epoch 765/1001
# critic: 0.007616 - generator: 0.151292 - 0s
# Epoch 766/1001
# critic: 0.009140 - generator: 0.159504 - 0s
# Epoch 767/1001
# critic: 0.011476 - generator: 0.155337 - 0s
# Epoch 768/1001
# critic: 0.006352 - generator: 0.148010 - 0s
# Epoch 769/1001
# critic: 0.004832 - generator: 0.153139 - 0s
# Epoch 770/1001
# critic: 0.003264 - generator: 0.157433 - 1s
# Epoch 771/1001
# critic: 0.004025 - generator: 0.154086 - 0s
# Epoch 772/1001
# critic: 0.008521 - generator: 0.153524 - 0s
# Epoch 773/1001
# critic: 0.008030 - generator: 0.157671 - 0s
# Epoch 774/1001
# critic: 0.010063 - generator: 0.149670 - 0s
# Epoch 775/1001
# critic: 0.009938 - generator: 0.147383 - 0s
# Epoch 776/1001
# critic: 0.010358 - generator: 0.149125 - 0s
# Epoch 777/1001
# critic: 0.009599 - generator: 0.147075 - 0s
# Epoch 778/1001
# critic: 0.006672 - generator: 0.151823 - 0s
# Epoch 779/1001
# critic: 0.006191 - generator: 0.141632 - 0s
# Epoch 780/1001
# critic: 0.004932 - generator: 0.145843 - 0s
# Epoch 781/1001
# critic: 0.006712 - generator: 0.148245 - 0s
# Epoch 782/1001
# critic: 0.007193 - generator: 0.152363 - 0s
# Epoch 783/1001
# critic: 0.005303 - generator: 0.149072 - 0s
# Epoch 784/1001
# critic: 0.007438 - generator: 0.152857 - 0s
# Epoch 785/1001
# critic: 0.007828 - generator: 0.142632 - 0s
# Epoch 786/1001
# critic: 0.009737 - generator: 0.144338 - 0s
# Epoch 787/1001
# critic: 0.011011 - generator: 0.141910 - 0s
# Epoch 788/1001
# critic: 0.010505 - generator: 0.145222 - 0s
# Epoch 789/1001
# critic: 0.009945 - generator: 0.145975 - 0s
# Epoch 790/1001
# critic: 0.006261 - generator: 0.141967 - 0s
# Epoch 791/1001
# critic: 0.006515 - generator: 0.142927 - 0s
# Epoch 792/1001
# critic: 0.009310 - generator: 0.150225 - 0s
# Epoch 793/1001
# critic: 0.006479 - generator: 0.150384 - 0s
# Epoch 794/1001
# critic: 0.009737 - generator: 0.151576 - 0s
# Epoch 795/1001
# critic: 0.007133 - generator: 0.154473 - 0s
# Epoch 796/1001
# critic: 0.011964 - generator: 0.149428 - 0s
# Epoch 797/1001
# critic: 0.008238 - generator: 0.155855 - 0s
# Epoch 798/1001
# critic: 0.002798 - generator: 0.155280 - 0s
# Epoch 799/1001
# critic: 0.009642 - generator: 0.156413 - 0s
# Epoch 800/1001
# critic: 0.007780 - generator: 0.153006 - 0s
# Epoch 801/1001
# critic: 0.006203 - generator: 0.157155 - 0s
# Epoch 802/1001
# critic: 0.007175 - generator: 0.152119 - 0s
# Epoch 803/1001
# critic: 0.007393 - generator: 0.151936 - 0s
# Epoch 804/1001
# critic: 0.011372 - generator: 0.148260 - 0s
# Epoch 805/1001
# critic: 0.009356 - generator: 0.150813 - 0s
# Epoch 806/1001
# critic: 0.008950 - generator: 0.150309 - 0s
# Epoch 807/1001
# critic: 0.007434 - generator: 0.148578 - 0s
# Epoch 808/1001
# critic: 0.006813 - generator: 0.147684 - 0s
# Epoch 809/1001
# critic: 0.007313 - generator: 0.151059 - 0s
# Epoch 810/1001
# critic: 0.008357 - generator: 0.147315 - 0s
# Epoch 811/1001
# critic: 0.012929 - generator: 0.148138 - 0s
# Epoch 812/1001
# critic: 0.008790 - generator: 0.146641 - 0s
# Epoch 813/1001
# critic: 0.004843 - generator: 0.140427 - 0s
# Epoch 814/1001
# critic: 0.006530 - generator: 0.141637 - 0s
# Epoch 815/1001
# critic: 0.006413 - generator: 0.147510 - 0s
# Epoch 816/1001
# critic: 0.009943 - generator: 0.141299 - 0s
# Epoch 817/1001
# critic: 0.008586 - generator: 0.138963 - 0s
# Epoch 818/1001
# critic: 0.008479 - generator: 0.130604 - 0s
# Epoch 819/1001
# critic: 0.006468 - generator: 0.143498 - 0s
# Epoch 820/1001
# critic: 0.009303 - generator: 0.144734 - 0s
# Epoch 821/1001
# critic: 0.009786 - generator: 0.141195 - 0s
# Epoch 822/1001
# critic: 0.008673 - generator: 0.141429 - 0s
# Epoch 823/1001
# critic: 0.006954 - generator: 0.136370 - 0s
# Epoch 824/1001
# critic: 0.009895 - generator: 0.138729 - 0s
# Epoch 825/1001
# critic: 0.005328 - generator: 0.142552 - 0s
# Epoch 826/1001
# critic: 0.006209 - generator: 0.137901 - 0s
# Epoch 827/1001
# critic: 0.007225 - generator: 0.137824 - 0s
# Epoch 828/1001
# critic: 0.007534 - generator: 0.147437 - 0s
# Epoch 829/1001
# critic: 0.008854 - generator: 0.141601 - 0s
# Epoch 830/1001
# critic: 0.003408 - generator: 0.142616 - 0s
# Epoch 831/1001
# critic: 0.007549 - generator: 0.143431 - 0s
# Epoch 832/1001
# critic: 0.009222 - generator: 0.141098 - 0s
# Epoch 833/1001
# critic: 0.011832 - generator: 0.146100 - 0s
# Epoch 834/1001
# critic: 0.007020 - generator: 0.147376 - 0s
# Epoch 835/1001
# critic: 0.006310 - generator: 0.143625 - 0s
# Epoch 836/1001
# critic: 0.011375 - generator: 0.143370 - 0s
# Epoch 837/1001
# critic: 0.009387 - generator: 0.140128 - 0s
# Epoch 838/1001
# critic: 0.006448 - generator: 0.144499 - 0s
# Epoch 839/1001
# critic: 0.007193 - generator: 0.152050 - 0s
# Epoch 840/1001
# critic: 0.005643 - generator: 0.155890 - 0s
# Epoch 841/1001
# critic: 0.010001 - generator: 0.151050 - 0s
# Epoch 842/1001
# critic: 0.009351 - generator: 0.145581 - 0s
# Epoch 843/1001
# critic: 0.004529 - generator: 0.149776 - 0s
# Epoch 844/1001
# critic: 0.009269 - generator: 0.149762 - 0s
# Epoch 845/1001
# critic: 0.008831 - generator: 0.143002 - 1s
# Epoch 846/1001
# critic: 0.008802 - generator: 0.146333 - 1s
# Epoch 847/1001
# critic: 0.008119 - generator: 0.145485 - 0s
# Epoch 848/1001
# critic: 0.007764 - generator: 0.143413 - 0s
# Epoch 849/1001
# critic: 0.003861 - generator: 0.143345 - 0s
# Epoch 850/1001
# critic: 0.007976 - generator: 0.146419 - 0s
# Epoch 851/1001
# critic: 0.008646 - generator: 0.143859 - 1s
# Epoch 852/1001
# critic: 0.005152 - generator: 0.153024 - 0s
# Epoch 853/1001
# critic: 0.007799 - generator: 0.149821 - 1s
# Epoch 854/1001
# critic: 0.004290 - generator: 0.149509 - 1s
# Epoch 855/1001
# critic: 0.010222 - generator: 0.155723 - 1s
# Epoch 856/1001
# critic: 0.006132 - generator: 0.150256 - 1s
# Epoch 857/1001
# critic: 0.006257 - generator: 0.148817 - 0s
# Epoch 858/1001
# critic: 0.007269 - generator: 0.150645 - 0s
# Epoch 859/1001
# critic: 0.005101 - generator: 0.154356 - 0s
# Epoch 860/1001
# critic: 0.006023 - generator: 0.150632 - 0s
# Epoch 861/1001
# critic: 0.006829 - generator: 0.155381 - 0s
# Epoch 862/1001
# critic: 0.007677 - generator: 0.153215 - 0s
# Epoch 863/1001
# critic: 0.010529 - generator: 0.155344 - 0s
# Epoch 864/1001
# critic: 0.007110 - generator: 0.147707 - 1s
# Epoch 865/1001
# critic: 0.010899 - generator: 0.154288 - 1s
# Epoch 866/1001
# critic: 0.007730 - generator: 0.151106 - 1s
# Epoch 867/1001
# critic: 0.006719 - generator: 0.144306 - 1s
# Epoch 868/1001
# critic: 0.005547 - generator: 0.153903 - 1s
# Epoch 869/1001
# critic: 0.007715 - generator: 0.150182 - 0s
# Epoch 870/1001
# critic: 0.007831 - generator: 0.154872 - 1s
# Epoch 871/1001
# critic: 0.010646 - generator: 0.152592 - 1s
# Epoch 872/1001
# critic: 0.009555 - generator: 0.153500 - 1s
# Epoch 873/1001
# critic: 0.005425 - generator: 0.154099 - 0s
# Epoch 874/1001
# critic: 0.007523 - generator: 0.144905 - 1s
# Epoch 875/1001
# critic: 0.007231 - generator: 0.148353 - 1s
# Epoch 876/1001
# critic: 0.008617 - generator: 0.148009 - 1s
# Epoch 877/1001
# critic: 0.008161 - generator: 0.153729 - 0s
# Epoch 878/1001
# critic: 0.004155 - generator: 0.159815 - 1s
# Epoch 879/1001
# critic: 0.009215 - generator: 0.154728 - 1s
# Epoch 880/1001
# critic: 0.011690 - generator: 0.160194 - 1s
# Epoch 881/1001
# critic: 0.007884 - generator: 0.154536 - 1s
# Epoch 882/1001
# critic: 0.007324 - generator: 0.156042 - 1s
# Epoch 883/1001
# critic: 0.011794 - generator: 0.164308 - 1s
# Epoch 884/1001
# critic: 0.005987 - generator: 0.168890 - 1s
# Epoch 885/1001
# critic: 0.009233 - generator: 0.164730 - 1s
# Epoch 886/1001
# critic: 0.007634 - generator: 0.164921 - 1s
# Epoch 887/1001
# critic: 0.006880 - generator: 0.162820 - 1s
# Epoch 888/1001
# critic: 0.006133 - generator: 0.154524 - 1s
# Epoch 889/1001
# critic: 0.007582 - generator: 0.161493 - 1s
# Epoch 890/1001
# critic: 0.004989 - generator: 0.160491 - 1s
# Epoch 891/1001
# critic: 0.007227 - generator: 0.160118 - 1s
# Epoch 892/1001
# critic: 0.008365 - generator: 0.159633 - 1s
# Epoch 893/1001
# critic: 0.010169 - generator: 0.159719 - 0s
# Epoch 894/1001
# critic: 0.005967 - generator: 0.151062 - 0s
# Epoch 895/1001
# critic: 0.008153 - generator: 0.157367 - 0s
# Epoch 896/1001
# critic: 0.008464 - generator: 0.155500 - 0s
# Epoch 897/1001
# critic: 0.008534 - generator: 0.160674 - 1s
# Epoch 898/1001
# critic: 0.010657 - generator: 0.160350 - 1s
# Epoch 899/1001
# critic: 0.005081 - generator: 0.157308 - 1s
# Epoch 900/1001
# critic: 0.004569 - generator: 0.159268 - 1s
# Epoch 901/1001
# critic: 0.010361 - generator: 0.157026 - 0s
# Epoch 902/1001
# critic: 0.008851 - generator: 0.149087 - 0s
# Epoch 903/1001
# critic: 0.004059 - generator: 0.151823 - 1s
# Epoch 904/1001
# critic: 0.004183 - generator: 0.159199 - 1s
# Epoch 905/1001
# critic: 0.004449 - generator: 0.149991 - 1s
# Epoch 906/1001
# critic: 0.006004 - generator: 0.154162 - 1s
# Epoch 907/1001
# critic: 0.007146 - generator: 0.155490 - 1s
# Epoch 908/1001
# critic: 0.009344 - generator: 0.156845 - 0s
# Epoch 909/1001
# critic: 0.008169 - generator: 0.151323 - 0s
# Epoch 910/1001
# critic: 0.007035 - generator: 0.144769 - 0s
# Epoch 911/1001
# critic: 0.001922 - generator: 0.142448 - 0s
# Epoch 912/1001
# critic: 0.006372 - generator: 0.148464 - 1s
# Epoch 913/1001
# critic: 0.005154 - generator: 0.146019 - 1s
# Epoch 914/1001
# critic: 0.004707 - generator: 0.149994 - 1s
# Epoch 915/1001
# critic: 0.011708 - generator: 0.148659 - 0s
# Epoch 916/1001
# critic: 0.005263 - generator: 0.155075 - 0s
# Epoch 917/1001
# critic: 0.008925 - generator: 0.149210 - 0s
# Epoch 918/1001
# critic: 0.008194 - generator: 0.145363 - 0s
# Epoch 919/1001
# critic: 0.011030 - generator: 0.139837 - 0s
# Epoch 920/1001
# critic: 0.007814 - generator: 0.148768 - 0s
# Epoch 921/1001
# critic: 0.010781 - generator: 0.144384 - 0s
# Epoch 922/1001
# critic: 0.008890 - generator: 0.150165 - 0s
# Epoch 923/1001
# critic: 0.006333 - generator: 0.144253 - 0s
# Epoch 924/1001
# critic: 0.007218 - generator: 0.143344 - 0s
# Epoch 925/1001
# critic: 0.007444 - generator: 0.141375 - 0s
# Epoch 926/1001
# critic: 0.006921 - generator: 0.137472 - 0s
# Epoch 927/1001
# critic: 0.007622 - generator: 0.142535 - 0s
# Epoch 928/1001
# critic: 0.003186 - generator: 0.146827 - 0s
# Epoch 929/1001
# critic: 0.008171 - generator: 0.145342 - 0s
# Epoch 930/1001
# critic: 0.005756 - generator: 0.136601 - 0s
# Epoch 931/1001
# critic: 0.008250 - generator: 0.144956 - 0s
# Epoch 932/1001
# critic: 0.004730 - generator: 0.144492 - 0s
# Epoch 933/1001
# critic: 0.009185 - generator: 0.146265 - 0s
# Epoch 934/1001
# critic: 0.008863 - generator: 0.145687 - 0s
# Epoch 935/1001
# critic: 0.006051 - generator: 0.134828 - 0s
# Epoch 936/1001
# critic: 0.007519 - generator: 0.147500 - 0s
# Epoch 937/1001
# critic: 0.009938 - generator: 0.140511 - 0s
# Epoch 938/1001
# critic: 0.009488 - generator: 0.143550 - 0s
# Epoch 939/1001
# critic: 0.004872 - generator: 0.136739 - 0s
# Epoch 940/1001
# critic: 0.007285 - generator: 0.134441 - 0s
# Epoch 941/1001
# critic: 0.006981 - generator: 0.140778 - 0s
# Epoch 942/1001
# critic: 0.007015 - generator: 0.149854 - 0s
# Epoch 943/1001
# critic: 0.007677 - generator: 0.138683 - 0s
# Epoch 944/1001
# critic: 0.006654 - generator: 0.142988 - 0s
# Epoch 945/1001
# critic: 0.008037 - generator: 0.140276 - 0s
# Epoch 946/1001
# critic: 0.003247 - generator: 0.139515 - 0s
# Epoch 947/1001
# critic: 0.008417 - generator: 0.134179 - 0s
# Epoch 948/1001
# critic: 0.007402 - generator: 0.133795 - 0s
# Epoch 949/1001
# critic: 0.010338 - generator: 0.129303 - 0s
# Epoch 950/1001
# critic: 0.006804 - generator: 0.129576 - 0s
# Epoch 951/1001
# critic: 0.006172 - generator: 0.131095 - 0s
# Epoch 952/1001
# critic: 0.009119 - generator: 0.130459 - 0s
# Epoch 953/1001
# critic: 0.003315 - generator: 0.142662 - 0s
# Epoch 954/1001
# critic: 0.008021 - generator: 0.133931 - 0s
# Epoch 955/1001
# critic: 0.007250 - generator: 0.134793 - 0s
# Epoch 956/1001
# critic: 0.007498 - generator: 0.138668 - 0s
# Epoch 957/1001
# critic: 0.008600 - generator: 0.125813 - 0s
# Epoch 958/1001
# critic: 0.010321 - generator: 0.136982 - 0s
# Epoch 959/1001
# critic: 0.006552 - generator: 0.125709 - 0s
# Epoch 960/1001
# critic: 0.005107 - generator: 0.120263 - 1s
# Epoch 961/1001
# critic: 0.006639 - generator: 0.123801 - 1s
# Epoch 962/1001
# critic: 0.003977 - generator: 0.134461 - 1s
# Epoch 963/1001
# critic: 0.005315 - generator: 0.131641 - 1s
# Epoch 964/1001
# critic: 0.005437 - generator: 0.122457 - 1s
# Epoch 965/1001
# critic: 0.008297 - generator: 0.125797 - 0s
# Epoch 966/1001
# critic: 0.005926 - generator: 0.136932 - 0s
# Epoch 967/1001
# critic: 0.007717 - generator: 0.126534 - 0s
# Epoch 968/1001
# critic: 0.008320 - generator: 0.119063 - 0s
# Epoch 969/1001
# critic: 0.005505 - generator: 0.129550 - 0s
# Epoch 970/1001
# critic: 0.006798 - generator: 0.127504 - 0s
# Epoch 971/1001
# critic: 0.005486 - generator: 0.130058 - 0s
# Epoch 972/1001
# critic: 0.009617 - generator: 0.126497 - 1s
# Epoch 973/1001
# critic: 0.010123 - generator: 0.134574 - 1s
# Epoch 974/1001
# critic: 0.005918 - generator: 0.132426 - 1s
# Epoch 975/1001
# critic: 0.005960 - generator: 0.128755 - 1s
# Epoch 976/1001
# critic: 0.007633 - generator: 0.136117 - 1s
# Epoch 977/1001
# critic: 0.007876 - generator: 0.133159 - 1s
# Epoch 978/1001
# critic: 0.008040 - generator: 0.135835 - 1s
# Epoch 979/1001
# critic: 0.008248 - generator: 0.134124 - 1s
# Epoch 980/1001
# critic: 0.008402 - generator: 0.126238 - 1s
# Epoch 981/1001
# critic: 0.007330 - generator: 0.136017 - 1s
# Epoch 982/1001
# critic: 0.005445 - generator: 0.126860 - 1s
# Epoch 983/1001
# critic: 0.010216 - generator: 0.129355 - 1s
# Epoch 984/1001
# critic: 0.007845 - generator: 0.128961 - 1s
# Epoch 985/1001
# critic: 0.009457 - generator: 0.134869 - 1s
# Epoch 986/1001
# critic: 0.008654 - generator: 0.140812 - 0s
# Epoch 987/1001
# critic: 0.008516 - generator: 0.134337 - 0s
# Epoch 988/1001
# critic: 0.006381 - generator: 0.136971 - 0s
# Epoch 989/1001
# critic: 0.006935 - generator: 0.134698 - 0s
# Epoch 990/1001
# critic: 0.007136 - generator: 0.129554 - 0s
# Epoch 991/1001
# critic: 0.008971 - generator: 0.129834 - 0s
# Epoch 992/1001
# critic: 0.007878 - generator: 0.141035 - 0s
# Epoch 993/1001
# critic: 0.005802 - generator: 0.137927 - 0s
# Epoch 994/1001
# critic: 0.005367 - generator: 0.140689 - 0s
# Epoch 995/1001
# critic: 0.007229 - generator: 0.136018 - 0s
# Epoch 996/1001
# critic: 0.001086 - generator: 0.136786 - 0s
# Epoch 997/1001
# critic: 0.005810 - generator: 0.138960 - 0s
# Epoch 998/1001
# critic: 0.005755 - generator: 0.134594 - 0s
# Epoch 999/1001
# critic: 0.006424 - generator: 0.132464 - 0s
# Epoch 1000/1001
# critic: 0.010229 - generator: 0.144795 - 0s
# WARNING:tensorflow:From C:\Users\ellye\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: GANS/Models/GAN_0\assets
# Loss:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Prediction

# %%
latent_values = tf.random.normal([1000, latent_space], mean=0.0, stddev=0.1)
predicted_values = wgan.generator.predict(latent_values)
if scaled == '-1-1':
    predicted_values[:,:]=(predicted_values[:,:])
    predicted_values = scaler.inverse_transform(predicted_values)
elif scaled =='0-1':
    predicted_values = scaler.inverse_transform(predicted_values)
plt.plot(X_train,y_train,'o')
plt.plot(predicted_values[:,0],predicted_values[:,1],'o')
plt.show()

# %%
x_input = [-1, 0, 0.5, 1.5]
n_points = 20
y_min = -0.75
y_max = 1


# produces an input of fixed x coordinates with random y values
predict1 = np.full((n_points//4, 2), x_input[0])
predict2 = np.full((n_points//4, 2), x_input[1])
predict3 = np.full((n_points//4, 2), x_input[2])
predict4 = np.full((n_points//4, 2), x_input[3])
predictthis = np.concatenate((predict1, predict2, predict3, predict4))

for n in range(n_points):
    predictthis[n,1] = random.uniform(y_min, y_max)
    
# np.random.shuffle(predictthis)

# %%
X_generated = wgan.predict(predictthis, scaler, scaled)
# Out:
# Optimizing latent space for point  0  /  20
# Optimizing latent space for point  1  /  20
# Optimizing latent space for point  2  /  20
# Optimizing latent space for point  3  /  20
# Optimizing latent space for point  4  /  20
# Optimizing latent space for point  5  /  20
# Optimizing latent space for point  6  /  20
# Optimizing latent space for point  7  /  20
# Optimizing latent space for point  8  /  20
# Optimizing latent space for point  9  /  20
# Optimizing latent space for point  10  /  20
# Optimizing latent space for point  11  /  20
# Optimizing latent space for point  12  /  20
# Optimizing latent space for point  13  /  20
# Optimizing latent space for point  14  /  20
# Optimizing latent space for point  15  /  20
# Optimizing latent space for point  16  /  20
# Optimizing latent space for point  17  /  20
# Optimizing latent space for point  18  /  20
# Optimizing latent space for point  19  /  20

# %%
plt.title("Prediction at x = -1, 0, 1.5")
plt.scatter(X_train, y_train, label="Training data")
#plt.scatter(predictthis[:,0], predictthis[:,1], label="Sample data", c="pink")
plt.scatter(X_generated[:,0], X_generated[:,1], label="Fixed Input Prediction")
plt.legend(loc='upper right')
plt.tight_layout()
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(6.625, 0.5, 'y')

# %%
mse = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(1e-2)

def mse_loss(inp, outp):
    """
    Calculates the MSE loss between the x-coordinates
    """
    inp = tf.reshape(inp, [-1, n_features])
    outp = tf.reshape(outp, [-1, n_features])
    return mse(inp[:,0], outp[:,0])


def opt_step(latent_values, real_coding):
    """
    Minimizes the loss between generated point and inputted point
    """
    with tf.GradientTape() as tape:
        tape.watch(latent_values)
        gen_output = wgan.generator(latent_values, training=True)
        loss = mse_loss(real_coding, gen_output)

    gradient = tape.gradient(loss, latent_values)
    optimizer.apply_gradients(zip([gradient], [latent_values]))

    return loss

def optimize_coding(real_coding):
    """
    Optimizes the latent space values
    """
    latent_values = tf.random.normal([20, latent_space], mean=0.0, stddev=0.1)
    latent_values = tf.Variable(latent_values)

    loss = []
    for epoch in range(1000):
        loss.append(opt_step(latent_values, real_coding).numpy())

    return latent_values

def predict(input_data_unscaled, scaler, scaled):
    """
    Optimizes the latent space of the input then produces a prediction from
    the generator.
    """

    input_data = scaler.fit_transform(input_data_unscaled)

    predicted_vals = np.zeros((1, n_features))

    for n in range(len(input_data)):
        print("Optimizing latent space for point ", n, " / ", len(input_data))
        real_coding = input_data[n]
        real_coding = tf.constant(real_coding)
        real_coding = tf.cast(real_coding, dtype=tf.float32)

        latent_values = optimize_coding(real_coding)

        predicted_vals_1 = scaler.inverse_transform((wgan.generator.predict(tf.convert_to_tensor(latent_values)).reshape(-1, n_features)))

#         predicted_vals_1 = predicted_vals_1.reshape(1, n_features)
        predicted_vals = np.concatenate((predicted_vals, predicted_vals_1), axis=0)

    predicted_vals = predicted_vals[1:,:]
    return predicted_vals

# %%
X_generated = predict(predictthis, scaler, scaled)
# Out:
# Optimizing latent space for point  0  /  20
# Optimizing latent space for point  1  /  20
# Optimizing latent space for point  2  /  20
# Optimizing latent space for point  3  /  20
# Optimizing latent space for point  4  /  20
# Optimizing latent space for point  5  /  20
# Optimizing latent space for point  6  /  20
# Optimizing latent space for point  7  /  20
# Optimizing latent space for point  8  /  20
# Optimizing latent space for point  9  /  20
# Optimizing latent space for point  10  /  20
# Optimizing latent space for point  11  /  20
# Optimizing latent space for point  12  /  20
# Optimizing latent space for point  13  /  20
# Optimizing latent space for point  14  /  20
# Optimizing latent space for point  15  /  20
# Optimizing latent space for point  16  /  20
# Optimizing latent space for point  17  /  20
# Optimizing latent space for point  18  /  20
# Optimizing latent space for point  19  /  20

# %%
plt.title("Prediction at x = -1, 0, 1.5")
plt.scatter(X_train, y_train, label="Training data")
plt.scatter(predictthis[:,0], predictthis[:,1], label="Sample data", c="pink")
plt.scatter(X_generated[:,0], X_generated[:,1], label="Fixed Input Prediction")
plt.legend(loc='upper right')
plt.tight_layout()
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(6.625, 0.5, 'y')
