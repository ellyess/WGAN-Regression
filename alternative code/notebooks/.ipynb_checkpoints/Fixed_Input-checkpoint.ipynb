# %%
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import random

import sys
sys.path.append("..")

import dataset, network, GPR_Model, prob_dist
import WGAN_Model

# %% [markdown]
# # Load data

# %%
# 2 n_features sets "sinus", "circle", "multi", "moons", "heter"
# 3 n_features sets "helix", "3d"

scenario = "moons"
n_instance = 500 # number of generated points
n_features = 2

# %%
if scenario in ("3d", "helix") :
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.tight_layout()
    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='grey')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Preprocessing

# %%
wgan = WGAN_Model.WGAN(n_features)

# %%
train_dataset, scaler, X_train_scaled = wgan.preproc(X_train, y_train)
# Out:
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)
# every time the data shape (10, 2)

# %% [markdown]
# ### Training

# %%
hist = wgan.train(train_dataset, epochs=200)
# Out:
# Epoch 0/200
# discriminator: 0.016039 - generator: -0.112244 - 4s
# Epoch 1/200
# discriminator: 0.061794 - generator: -0.075969 - 1s
# Epoch 2/200
# discriminator: 0.008622 - generator: -0.048692 - 1s
# Epoch 3/200
# discriminator: 0.031534 - generator: -0.063278 - 1s
# Epoch 4/200
# discriminator: 0.043822 - generator: -0.059551 - 1s
# Epoch 5/200
# discriminator: 0.009095 - generator: 0.001998 - 1s
# Epoch 6/200
# discriminator: 0.048296 - generator: 0.016087 - 1s
# Epoch 7/200
# discriminator: 0.013462 - generator: 0.038741 - 1s
# Epoch 8/200
# discriminator: 0.015377 - generator: 0.076701 - 1s
# Epoch 9/200
# discriminator: 0.035376 - generator: 0.095991 - 1s
# Epoch 10/200
# discriminator: 0.002190 - generator: 0.114094 - 1s
# Epoch 11/200
# discriminator: -0.037609 - generator: 0.139402 - 1s
# Epoch 12/200
# discriminator: 0.026948 - generator: 0.167523 - 1s
# Epoch 13/200
# discriminator: 0.010481 - generator: 0.190698 - 1s
# Epoch 14/200
# discriminator: 0.005107 - generator: 0.219958 - 1s
# Epoch 15/200
# discriminator: -0.005453 - generator: 0.222421 - 1s
# Epoch 16/200
# discriminator: -0.006246 - generator: 0.220283 - 1s
# Epoch 17/200
# discriminator: 0.001185 - generator: 0.224264 - 1s
# Epoch 18/200
# discriminator: 0.028060 - generator: 0.267444 - 1s
# Epoch 19/200
# discriminator: -0.012536 - generator: 0.283321 - 1s
# Epoch 20/200
# discriminator: -0.003205 - generator: 0.273360 - 1s
# Epoch 21/200
# discriminator: -0.021989 - generator: 0.291599 - 1s
# Epoch 22/200
# discriminator: 0.007879 - generator: 0.292487 - 1s
# Epoch 23/200
# discriminator: 0.001408 - generator: 0.283710 - 1s
# Epoch 24/200
# discriminator: 0.001530 - generator: 0.299946 - 1s
# Epoch 25/200
# discriminator: 0.008287 - generator: 0.297701 - 1s
# Epoch 26/200
# discriminator: -0.001268 - generator: 0.309681 - 1s
# Epoch 27/200
# discriminator: 0.007227 - generator: 0.320114 - 1s
# Epoch 28/200
# discriminator: 0.012601 - generator: 0.330560 - 1s
# Epoch 29/200
# discriminator: -0.007167 - generator: 0.340767 - 1s
# Epoch 30/200
# discriminator: -0.005850 - generator: 0.343837 - 0s
# Epoch 31/200
# discriminator: -0.009586 - generator: 0.359574 - 0s
# Epoch 32/200
# discriminator: 0.010403 - generator: 0.374447 - 1s
# Epoch 33/200
# discriminator: 0.003709 - generator: 0.370869 - 1s
# Epoch 34/200
# discriminator: 0.016645 - generator: 0.386946 - 1s
# Epoch 35/200
# discriminator: 0.005446 - generator: 0.380929 - 1s
# Epoch 36/200
# discriminator: 0.015170 - generator: 0.395650 - 1s
# Epoch 37/200
# discriminator: 0.012759 - generator: 0.389257 - 1s
# Epoch 38/200
# discriminator: 0.011442 - generator: 0.400770 - 0s
# Epoch 39/200
# discriminator: -0.007655 - generator: 0.418733 - 1s
# Epoch 40/200
# discriminator: 0.027309 - generator: 0.428017 - 1s
# Epoch 41/200
# discriminator: 0.023842 - generator: 0.455708 - 1s
# Epoch 42/200
# discriminator: 0.050937 - generator: 0.468616 - 1s
# Epoch 43/200
# discriminator: 0.035219 - generator: 0.479811 - 1s
# Epoch 44/200
# discriminator: 0.058676 - generator: 0.535503 - 0s
# Epoch 45/200
# discriminator: 0.060791 - generator: 0.584156 - 1s
# Epoch 46/200
# discriminator: 0.107096 - generator: 0.601553 - 0s
# Epoch 47/200
# discriminator: 0.113283 - generator: 0.643805 - 0s
# Epoch 48/200
# discriminator: 0.118650 - generator: 0.699355 - 1s
# Epoch 49/200
# discriminator: 0.105267 - generator: 0.757088 - 1s
# Epoch 50/200
# discriminator: 0.182595 - generator: 0.791637 - 1s
# Epoch 51/200
# discriminator: 0.155611 - generator: 0.839215 - 0s
# Epoch 52/200
# discriminator: 0.178530 - generator: 0.908959 - 1s
# Epoch 53/200
# discriminator: 0.173947 - generator: 0.995022 - 1s
# Epoch 54/200
# discriminator: 0.220060 - generator: 1.025246 - 1s
# Epoch 55/200
# discriminator: 0.273778 - generator: 1.097564 - 1s
# Epoch 56/200
# discriminator: 0.279528 - generator: 1.141605 - 1s
# Epoch 57/200
# discriminator: 0.228673 - generator: 1.176940 - 0s
# Epoch 58/200
# discriminator: 0.313566 - generator: 1.269521 - 1s
# Epoch 59/200
# discriminator: 0.318846 - generator: 1.318020 - 1s
# Epoch 60/200
# discriminator: 0.296574 - generator: 1.344591 - 0s
# Epoch 61/200
# discriminator: 0.319003 - generator: 1.427293 - 1s
# Epoch 62/200
# discriminator: 0.317048 - generator: 1.391555 - 0s
# Epoch 63/200
# discriminator: 0.354654 - generator: 1.448030 - 0s
# Epoch 64/200
# discriminator: 0.287191 - generator: 1.424448 - 0s
# Epoch 65/200
# discriminator: 0.275241 - generator: 1.519646 - 0s
# Epoch 66/200
# discriminator: 0.325926 - generator: 1.512326 - 0s
# Epoch 67/200
# discriminator: 0.331250 - generator: 1.459235 - 0s
# Epoch 68/200
# discriminator: 0.361121 - generator: 1.501164 - 0s
# Epoch 69/200
# discriminator: 0.284895 - generator: 1.526971 - 0s
# Epoch 70/200
# discriminator: 0.357809 - generator: 1.555561 - 1s
# Epoch 71/200
# discriminator: 0.312894 - generator: 1.566631 - 1s
# Epoch 72/200
# discriminator: 0.396583 - generator: 1.563907 - 1s
# Epoch 73/200
# discriminator: 0.298311 - generator: 1.502970 - 1s
# Epoch 74/200
# discriminator: 0.360953 - generator: 1.623129 - 1s
# Epoch 75/200
# discriminator: 0.345852 - generator: 1.562488 - 1s
# Epoch 76/200
# discriminator: 0.413467 - generator: 1.586897 - 1s
# Epoch 77/200
# discriminator: 0.415133 - generator: 1.576628 - 1s
# Epoch 78/200
# discriminator: 0.329547 - generator: 1.562236 - 1s
# Epoch 79/200
# discriminator: 0.426477 - generator: 1.565420 - 1s
# Epoch 80/200
# discriminator: 0.369081 - generator: 1.579737 - 0s
# Epoch 81/200
# discriminator: 0.335448 - generator: 1.600555 - 1s
# Epoch 82/200
# discriminator: 0.312785 - generator: 1.562437 - 0s
# Epoch 83/200
# discriminator: 0.347371 - generator: 1.560068 - 0s
# Epoch 84/200
# discriminator: 0.389219 - generator: 1.489170 - 1s
# Epoch 85/200
# discriminator: 0.359203 - generator: 1.511801 - 1s
# Epoch 86/200
# discriminator: 0.292828 - generator: 1.483668 - 1s
# Epoch 87/200
# discriminator: 0.350479 - generator: 1.515583 - 1s
# Epoch 88/200
# discriminator: 0.293046 - generator: 1.565996 - 1s
# Epoch 89/200
# discriminator: 0.329376 - generator: 1.480617 - 1s
# Epoch 90/200
# discriminator: 0.351271 - generator: 1.485308 - 1s
# Epoch 91/200
# discriminator: 0.308663 - generator: 1.507904 - 1s
# Epoch 92/200
# discriminator: 0.279744 - generator: 1.456885 - 1s
# Epoch 93/200
# discriminator: 0.410987 - generator: 1.433925 - 1s
# Epoch 94/200
# discriminator: 0.307730 - generator: 1.449433 - 1s
# Epoch 95/200
# discriminator: 0.380522 - generator: 1.367315 - 1s
# Epoch 96/200
# discriminator: 0.337996 - generator: 1.349880 - 1s
# Epoch 97/200
# discriminator: 0.314179 - generator: 1.360709 - 1s
# Epoch 98/200
# discriminator: 0.355682 - generator: 1.282850 - 1s
# Epoch 99/200
# discriminator: 0.403340 - generator: 1.298218 - 1s
# Epoch 100/200
# discriminator: 0.398380 - generator: 1.252702 - 1s
# Epoch 101/200
# discriminator: 0.395034 - generator: 1.193886 - 1s
# Epoch 102/200
# discriminator: 0.408250 - generator: 1.202824 - 1s
# Epoch 103/200
# discriminator: 0.381091 - generator: 1.156533 - 0s
# Epoch 104/200
# discriminator: 0.457451 - generator: 1.159599 - 0s
# Epoch 105/200
# discriminator: 0.402596 - generator: 1.106942 - 1s
# Epoch 106/200
# discriminator: 0.442999 - generator: 1.081344 - 1s
# Epoch 107/200
# discriminator: 0.440298 - generator: 1.076362 - 1s
# Epoch 108/200
# discriminator: 0.388079 - generator: 1.041950 - 1s
# Epoch 109/200
# discriminator: 0.436967 - generator: 0.991695 - 1s
# Epoch 110/200
# discriminator: 0.387071 - generator: 1.046112 - 0s
# Epoch 111/200
# discriminator: 0.398199 - generator: 0.996395 - 0s
# Epoch 112/200
# discriminator: 0.416548 - generator: 0.943153 - 0s
# Epoch 113/200
# discriminator: 0.412831 - generator: 0.967784 - 0s
# Epoch 114/200
# discriminator: 0.466509 - generator: 0.915588 - 0s
# Epoch 115/200
# discriminator: 0.499968 - generator: 0.897280 - 1s
# Epoch 116/200
# discriminator: 0.486493 - generator: 0.827437 - 1s
# Epoch 117/200
# discriminator: 0.505559 - generator: 0.822418 - 1s
# Epoch 118/200
# discriminator: 0.582722 - generator: 0.792530 - 1s
# Epoch 119/200
# discriminator: 0.513788 - generator: 0.762395 - 1s
# Epoch 120/200
# discriminator: 0.518780 - generator: 0.733027 - 0s
# Epoch 121/200
# discriminator: 0.531775 - generator: 0.755217 - 1s
# Epoch 122/200
# discriminator: 0.589436 - generator: 0.665611 - 1s
# Epoch 123/200
# discriminator: 0.610410 - generator: 0.713651 - 1s
# Epoch 124/200
# discriminator: 0.638722 - generator: 0.665251 - 1s
# Epoch 125/200
# discriminator: 0.582228 - generator: 0.667186 - 0s
# Epoch 126/200
# discriminator: 0.606995 - generator: 0.642283 - 1s
# Epoch 127/200
# discriminator: 0.617104 - generator: 0.628919 - 0s
# Epoch 128/200
# discriminator: 0.625180 - generator: 0.654184 - 0s
# Epoch 129/200
# discriminator: 0.642176 - generator: 0.639200 - 1s
# Epoch 130/200
# discriminator: 0.651466 - generator: 0.689233 - 1s
# Epoch 131/200
# discriminator: 0.632580 - generator: 0.663302 - 1s
# Epoch 132/200
# discriminator: 0.619683 - generator: 0.675629 - 1s
# Epoch 133/200
# discriminator: 0.599368 - generator: 0.751593 - 1s
# Epoch 134/200
# discriminator: 0.552367 - generator: 0.766913 - 1s
# Epoch 135/200
# discriminator: 0.550961 - generator: 0.836786 - 1s
# Epoch 136/200
# discriminator: 0.552635 - generator: 0.867289 - 1s
# Epoch 137/200
# discriminator: 0.555574 - generator: 0.841392 - 1s
# Epoch 138/200
# discriminator: 0.470270 - generator: 0.912746 - 1s
# Epoch 139/200
# discriminator: 0.567741 - generator: 0.870641 - 1s
# Epoch 140/200
# discriminator: 0.520164 - generator: 0.822516 - 1s
# Epoch 141/200
# discriminator: 0.487644 - generator: 0.809450 - 1s
# Epoch 142/200
# discriminator: 0.540793 - generator: 0.847765 - 1s
# Epoch 143/200
# discriminator: 0.491030 - generator: 0.826263 - 1s
# Epoch 144/200
# discriminator: 0.568415 - generator: 0.826851 - 1s
# Epoch 145/200
# discriminator: 0.417321 - generator: 0.873144 - 0s
# Epoch 146/200
# discriminator: 0.492468 - generator: 0.880735 - 1s
# Epoch 147/200
# discriminator: 0.475649 - generator: 0.869527 - 1s
# Epoch 148/200
# discriminator: 0.452049 - generator: 0.844044 - 0s
# Epoch 149/200
# discriminator: 0.529927 - generator: 0.838473 - 1s
# Epoch 150/200
# discriminator: 0.461173 - generator: 0.860529 - 1s
# Epoch 151/200
# discriminator: 0.483180 - generator: 0.859878 - 0s
# Epoch 152/200
# discriminator: 0.506843 - generator: 0.845727 - 0s
# Epoch 153/200
# discriminator: 0.533981 - generator: 0.821820 - 0s
# Epoch 154/200
# discriminator: 0.349799 - generator: 0.842967 - 0s
# Epoch 155/200
# discriminator: 0.416446 - generator: 0.897309 - 1s
# Epoch 156/200
# discriminator: 0.458419 - generator: 0.812051 - 1s
# Epoch 157/200
# discriminator: 0.372996 - generator: 0.856249 - 1s
# Epoch 158/200
# discriminator: 0.320782 - generator: 0.859466 - 1s
# Epoch 159/200
# discriminator: 0.393282 - generator: 0.882055 - 1s
# Epoch 160/200
# discriminator: 0.431933 - generator: 0.893238 - 1s
# Epoch 161/200
# discriminator: 0.402948 - generator: 0.946414 - 1s
# Epoch 162/200
# discriminator: 0.249918 - generator: 0.968605 - 1s
# Epoch 163/200
# discriminator: 0.321858 - generator: 0.977717 - 1s
# Epoch 164/200
# discriminator: 0.260026 - generator: 1.001533 - 0s
# Epoch 165/200
# discriminator: 0.315659 - generator: 0.966164 - 0s
# Epoch 166/200
# discriminator: 0.247801 - generator: 0.995310 - 0s
# Epoch 167/200
# discriminator: 0.228771 - generator: 1.068205 - 0s
# Epoch 168/200
# discriminator: 0.151549 - generator: 1.138385 - 0s
# Epoch 169/200
# discriminator: 0.181705 - generator: 1.169456 - 0s
# Epoch 170/200
# discriminator: 0.114039 - generator: 1.248495 - 0s
# Epoch 171/200
# discriminator: 0.097212 - generator: 1.368487 - 0s
# Epoch 172/200
# discriminator: 0.085607 - generator: 1.337242 - 0s
# Epoch 173/200
# discriminator: 0.001177 - generator: 1.410970 - 0s
# Epoch 174/200
# discriminator: -0.053225 - generator: 1.326455 - 0s
# Epoch 175/200
# discriminator: 0.062203 - generator: 1.448986 - 0s
# Epoch 176/200
# discriminator: 0.005378 - generator: 1.527165 - 0s
# Epoch 177/200
# discriminator: -0.065320 - generator: 1.749592 - 0s
# Epoch 178/200
# discriminator: -0.125656 - generator: 1.760331 - 1s
# Epoch 179/200
# discriminator: -0.314786 - generator: 1.838987 - 1s
# Epoch 180/200
# discriminator: -0.352069 - generator: 1.907318 - 0s
# Epoch 181/200
# discriminator: -0.315256 - generator: 1.906560 - 1s
# Epoch 182/200
# discriminator: -0.430312 - generator: 2.050585 - 1s
# Epoch 183/200
# discriminator: -0.555681 - generator: 2.090997 - 1s
# Epoch 184/200
# discriminator: -0.482086 - generator: 2.077080 - 1s
# Epoch 185/200
# discriminator: -0.605508 - generator: 2.099289 - 1s
# Epoch 186/200
# discriminator: -0.605945 - generator: 2.235226 - 1s
# Epoch 187/200
# discriminator: -0.673473 - generator: 2.382714 - 1s
# Epoch 188/200
# discriminator: -0.706366 - generator: 2.380780 - 0s
# Epoch 189/200
# discriminator: -0.843970 - generator: 2.680224 - 1s
# Epoch 190/200
# discriminator: -0.963655 - generator: 2.693069 - 1s
# Epoch 191/200
# discriminator: -1.019742 - generator: 2.831802 - 1s
# Epoch 192/200
# discriminator: -0.959100 - generator: 2.897009 - 0s
# Epoch 193/200
# discriminator: -1.014174 - generator: 2.942261 - 1s
# Epoch 194/200
# discriminator: -1.054739 - generator: 2.984245 - 1s
# Epoch 195/200
# discriminator: -0.997341 - generator: 3.061116 - 1s
# Epoch 196/200
# discriminator: -1.007599 - generator: 2.978320 - 0s
# Epoch 197/200
# discriminator: -0.879136 - generator: 2.925835 - 1s
# Epoch 198/200
# discriminator: -0.808452 - generator: 2.887625 - 0s
# Epoch 199/200
# discriminator: -0.701958 - generator: 2.860868 - 0s

# %%
# plot loss
print('Loss: ')
fig, ax = plt.subplots(1,1, figsize=[10,5])
ax.plot(hist)
ax.legend(['loss_gen', 'loss_disc'])
#ax.set_yscale('log')
ax.grid()
plt.tight_layout()
# Out:
# Loss:

# %% [markdown]
# ### Prediction

# %%
# define these for desired prediction
x_input = 0
n_points = 10
y_min = -1
y_max = -1


# produces an input of fixed x coordinates with random y values
predictthis = np.full((n_points, 2), x_input)
for n in range(n_points):
    predictthis[n,1] = random.uniform(y_min, y_max)
    
predictthis_scaled = scaler.fit_transform(predictthis)*2 - 1

# %%
X_generated = wgan.predict(predictthis_scaled, scaler)
# Out:
# Optimizing latent space for point  0  /  10
# Optimizing latent space for point  1  /  10
# Optimizing latent space for point  2  /  10
# Optimizing latent space for point  3  /  10
# Optimizing latent space for point  4  /  10
# Optimizing latent space for point  5  /  10
# Optimizing latent space for point  6  /  10
# Optimizing latent space for point  7  /  10
# Optimizing latent space for point  8  /  10
# Optimizing latent space for point  9  /  10

# %%
if scenario in ("3d", "helix"):
    ax = plt.subplot(projection='3d')

    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], c='b', label='Generated Data')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
else:
    plt.title("Prediction at x = -1")
    plt.scatter(X_train, y_train, label="Training data")
    plt.scatter(X_generated[:,0], X_generated[:,1], label="Fixed Input Prediction")
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.xlabel("x")
    plt.ylabel("y")
