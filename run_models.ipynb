# %%
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras


import dataset, network, GPR_Model, prob_dist
import WGAN_Model

# %% [markdown]
# # Load data

# %%
# 2 n_features sets "sinus", "circle", "multi", "moons", "heter"
# 3 n_features sets "helix", "3d"

scenario = "circle"
n_instance = 100 # number of generated points
n_features = 2

# %%
if scenario in ("3d", "helix") :
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.tight_layout()
    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='grey')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Preprocessing

# %%
wgan = WGAN_Model.WGAN(n_features)

# %%
train_dataset, X_train_concat_flatten, scaler,  X_train_concat = wgan.preproc(X_train, y_train)
test_dataset, X_test_concat_flatten, scaler1,  X_test_concat = wgan.preproc(X_test, y_test)
# Out:
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (1, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (1, 20, 2, 1)

# %% [markdown]
# ### Training

# %%
wgan.generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 160)               20480
# _________________________________________________________________
# batch_normalization (BatchNo (None, 160)               640
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                12800
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                3200
# _________________________________________________________________
# reshape (Reshape)            (None, 20, 2, 1)          0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20, 2, 1)          1
# =================================================================
# Total params: 37,121
# Trainable params: 36,801
# Non-trainable params: 320
# _________________________________________________________________

# %%
hist = wgan.train(train_dataset, epochs=100)
# Out:
# Epoch 0/100
# discriminator: -0.324082 - generator: 0.272057 - 5s
# Epoch 1/100
# discriminator: -0.260371 - generator: 0.351608 - 0s
# Epoch 2/100
# discriminator: -0.111915 - generator: 0.180500 - 0s
# Epoch 3/100
# discriminator: -0.302587 - generator: 0.176941 - 0s
# Epoch 4/100
# discriminator: 0.019635 - generator: 0.174691 - 0s
# Epoch 5/100
# discriminator: -0.421688 - generator: 0.161853 - 0s
# Epoch 6/100
# discriminator: -0.387531 - generator: 0.253857 - 0s
# Epoch 7/100
# discriminator: -0.431614 - generator: 0.225206 - 0s
# Epoch 8/100
# discriminator: -0.386482 - generator: 0.298670 - 0s
# Epoch 9/100
# discriminator: -0.189380 - generator: 0.221318 - 0s
# Epoch 10/100
# discriminator: -0.140723 - generator: 0.187768 - 0s
# Epoch 11/100
# discriminator: -0.214552 - generator: 0.150113 - 0s
# Epoch 12/100
# discriminator: -0.013278 - generator: 0.117224 - 0s
# Epoch 13/100
# discriminator: -0.185063 - generator: 0.119370 - 0s
# Epoch 14/100
# discriminator: -0.057830 - generator: 0.141678 - 0s
# Epoch 15/100
# discriminator: -0.204293 - generator: 0.145707 - 0s
# Epoch 16/100
# discriminator: -0.208656 - generator: -0.033176 - 0s
# Epoch 17/100
# discriminator: -0.229095 - generator: 0.090480 - 0s
# Epoch 18/100
# discriminator: -0.183447 - generator: 0.108988 - 0s
# Epoch 19/100
# discriminator: -0.016044 - generator: 0.191049 - 0s
# Epoch 20/100
# discriminator: -0.320347 - generator: 0.176983 - 0s
# Epoch 21/100
# discriminator: -0.162118 - generator: 0.152549 - 0s
# Epoch 22/100
# discriminator: -0.064339 - generator: 0.108686 - 0s
# Epoch 23/100
# discriminator: -0.136326 - generator: 0.000458 - 0s
# Epoch 24/100
# discriminator: -0.069954 - generator: -0.032607 - 0s
# Epoch 25/100
# discriminator: -0.197498 - generator: -0.064301 - 0s
# Epoch 26/100
# discriminator: -0.192351 - generator: 0.035761 - 0s
# Epoch 27/100
# discriminator: -0.265865 - generator: -0.013753 - 0s
# Epoch 28/100
# discriminator: -0.098766 - generator: 0.063424 - 0s
# Epoch 29/100
# discriminator: -0.007526 - generator: -0.034259 - 0s
# Epoch 30/100
# discriminator: 0.042718 - generator: 0.026216 - 0s
# Epoch 31/100
# discriminator: -0.180850 - generator: 0.045356 - 0s
# Epoch 32/100
# discriminator: -0.138260 - generator: 0.149035 - 0s
# Epoch 33/100
# discriminator: -0.085384 - generator: 0.124860 - 0s
# Epoch 34/100
# discriminator: -0.138821 - generator: 0.126179 - 0s
# Epoch 35/100
# discriminator: -0.107864 - generator: 0.178146 - 0s
# Epoch 36/100
# discriminator: -0.250599 - generator: 0.068417 - 0s
# Epoch 37/100
# discriminator: -0.212210 - generator: 0.099949 - 0s
# Epoch 38/100
# discriminator: -0.052525 - generator: 0.069815 - 0s
# Epoch 39/100
# discriminator: -0.276627 - generator: 0.151841 - 0s
# Epoch 40/100
# discriminator: -0.203336 - generator: 0.253805 - 0s
# Epoch 41/100
# discriminator: -0.285339 - generator: 0.451986 - 0s
# Epoch 42/100
# discriminator: -0.262432 - generator: 0.483186 - 0s
# Epoch 43/100
# discriminator: -0.339034 - generator: 0.494109 - 0s
# Epoch 44/100
# discriminator: -0.346120 - generator: 0.403018 - 0s
# Epoch 45/100
# discriminator: -0.262160 - generator: 0.375822 - 0s
# Epoch 46/100
# discriminator: -0.364622 - generator: 0.433853 - 0s
# Epoch 47/100
# discriminator: -0.273636 - generator: 0.385351 - 0s
# Epoch 48/100
# discriminator: -0.227776 - generator: 0.259801 - 0s
# Epoch 49/100
# discriminator: -0.211298 - generator: 0.345277 - 0s
# Epoch 50/100
# discriminator: -0.200542 - generator: 0.240972 - 0s
# Epoch 51/100
# discriminator: -0.182009 - generator: 0.317867 - 0s
# Epoch 52/100
# discriminator: -0.245244 - generator: 0.277780 - 0s
# Epoch 53/100
# discriminator: -0.108688 - generator: 0.222864 - 0s
# Epoch 54/100
# discriminator: -0.250319 - generator: 0.322791 - 0s
# Epoch 55/100
# discriminator: -0.095151 - generator: 0.312652 - 0s
# Epoch 56/100
# discriminator: -0.212139 - generator: 0.378254 - 0s
# Epoch 57/100
# discriminator: -0.279276 - generator: 0.317526 - 0s
# Epoch 58/100
# discriminator: -0.215955 - generator: 0.435460 - 0s
# Epoch 59/100
# discriminator: -0.274829 - generator: 0.385701 - 0s
# Epoch 60/100
# discriminator: -0.352598 - generator: 0.448144 - 0s
# Epoch 61/100
# discriminator: -0.299264 - generator: 0.407253 - 0s
# Epoch 62/100
# discriminator: -0.393731 - generator: 0.438221 - 0s
# Epoch 63/100
# discriminator: -0.530763 - generator: 0.472452 - 0s
# Epoch 64/100
# discriminator: -0.359245 - generator: 0.444360 - 0s
# Epoch 65/100
# discriminator: -0.323571 - generator: 0.453944 - 0s
# Epoch 66/100
# discriminator: -0.398244 - generator: 0.530644 - 0s
# Epoch 67/100
# discriminator: -0.344282 - generator: 0.543694 - 0s
# Epoch 68/100
# discriminator: -0.437576 - generator: 0.528966 - 0s
# Epoch 69/100
# discriminator: -0.441257 - generator: 0.474860 - 0s
# Epoch 70/100
# discriminator: -0.286647 - generator: 0.497134 - 0s
# Epoch 71/100
# discriminator: -0.569213 - generator: 0.521913 - 0s
# Epoch 72/100
# discriminator: -0.215317 - generator: 0.453158 - 0s
# Epoch 73/100
# discriminator: -0.336257 - generator: 0.405442 - 0s
# Epoch 74/100
# discriminator: -0.292991 - generator: 0.557855 - 0s
# Epoch 75/100
# discriminator: -0.470849 - generator: 0.674196 - 0s
# Epoch 76/100
# discriminator: -0.368128 - generator: 0.660170 - 0s
# Epoch 77/100
# discriminator: -0.545836 - generator: 0.610091 - 0s
# Epoch 78/100
# discriminator: -0.448433 - generator: 0.644977 - 0s
# Epoch 79/100
# discriminator: -0.375260 - generator: 0.685093 - 0s
# Epoch 80/100
# discriminator: -0.434986 - generator: 0.612183 - 0s
# Epoch 81/100
# discriminator: -0.296514 - generator: 0.662727 - 0s
# Epoch 82/100
# discriminator: -0.464108 - generator: 0.668302 - 0s
# Epoch 83/100
# discriminator: -0.520982 - generator: 0.657611 - 0s
# Epoch 84/100
# discriminator: -0.504992 - generator: 0.625992 - 0s
# Epoch 85/100
# discriminator: -0.270589 - generator: 0.596851 - 0s
# Epoch 86/100
# discriminator: -0.448105 - generator: 0.493403 - 0s
# Epoch 87/100
# discriminator: -0.431983 - generator: 0.462291 - 0s
# Epoch 88/100
# discriminator: -0.422021 - generator: 0.529882 - 0s
# Epoch 89/100
# discriminator: -0.324079 - generator: 0.544318 - 0s
# Epoch 90/100
# discriminator: -0.383732 - generator: 0.537425 - 0s
# Epoch 91/100
# discriminator: -0.407580 - generator: 0.479902 - 0s
# Epoch 92/100
# discriminator: -0.374689 - generator: 0.520681 - 0s
# Epoch 93/100
# discriminator: -0.406455 - generator: 0.469543 - 0s
# Epoch 94/100
# discriminator: -0.337989 - generator: 0.465954 - 0s
# Epoch 95/100
# discriminator: -0.427076 - generator: 0.426126 - 0s
# Epoch 96/100
# discriminator: -0.435422 - generator: 0.527974 - 0s
# Epoch 97/100
# discriminator: -0.335280 - generator: 0.561106 - 0s
# Epoch 98/100
# discriminator: -0.312167 - generator: 0.418831 - 0s
# Epoch 99/100
# discriminator: -0.435513 - generator: 0.346918 - 0s

# %%
# plot loss
print('Loss: ')
fig, ax = plt.subplots(1,1, figsize=[10,5])
ax.plot(hist)
ax.legend(['loss_gen', 'loss_disc'])
#ax.set_yscale('log')
ax.grid()
plt.tight_layout()
# Out:
# Loss:

# %% [markdown]
# ### Prediction

# %%
X_generated = wgan.predict(X_test_concat_flatten, scaler1, X_test_concat)

# %%
if scenario in ("3d", "helix"):
    ax = plt.subplot(projection='3d')

    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], c='b', label='Generated Data')  # 绘制数据点,颜色是红色
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
else:
    plt.scatter(X_generated[:,0], X_generated[:,1], label="Generated Data by WGAN-GP")
    plt.scatter(X_train, y_train, label="Real data")
    plt.legend(loc='best')
    plt.tight_layout()

# %%
X_generated[:,1].shape
X_train.reshape(-1,1).shape
# Out:
# (100, 1)

# %% [markdown]
# # Gaussian Process Regression

# %%
ypred_GPR = GPR_Model.train(X_train, y_train, X_test, n_features)

# %%
if scenario in ("3d", "helix"):
    ax = plt.subplot(projection='3d')

    ax.scatter(X_test[:,0], X_test[:,1], ypred_GPR, c='b', label='Generated Data')  # 绘制数据点,颜色是红色
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z') 
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()

else:
    plt.scatter(X_test, ypred_GPR, label='Generated Data by GPR')
    plt.scatter(X_train, y_train, label='Real Data')
    plt.legend(loc='best')

# %% [markdown]
# # Comparison
#
# ### Prediction Plots

# %%
# generates the plots
if scenario in ("3d", "helix"):
    fig = plt.figure(figsize=(13, 4))

    #---- First subplot
    ax = fig.add_subplot(1, 3, 1, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], y_test, color='orange')
    ax.set_title("Sample Data")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)

    ax = fig.add_subplot(1, 3, 2, projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], color='green', label='Generated Data')
    ax.set_title("WGAN-GP Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)

    ax = fig.add_subplot(1, 3, 3, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], ypred_GPR, c='b', label='Generated Data')
    ax.set_title("GPR Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)
    
    plt.tight_layout(pad=-1, w_pad=0.8, h_pad=0)
    

else:
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)
    axes[0].scatter(X_test, y_test, label='Real Data', color='orange')
    axes[0].set_title("Sample Data")
    axes[0].set_xlabel("x")
    axes[0].set_ylabel("y")

    axes[1].scatter(X_generated[:,0], X_generated[:,1], label="Generated Data by WGAN-GP", color='green')
    axes[1].set_title("WGAN-GP Predictions")
    axes[1].set_xlabel("x")

    axes[2].scatter(X_test, ypred_GPR, label='Generated Data by GPR')
    axes[2].set_title("GPR Predictions")
    axes[2].set_xlabel("x")

# %% [markdown]
# ### Probability Density Plots

# %%
# whole distribution
sns.distplot(y_train, hist=False, label='True')
sns.distplot(ypred_GPR, hist=False, label='GPR')
sns.distplot(X_generated[:,1], hist=False, label='GAN Generated')
plt.xlabel("Y")
plt.ylabel("Probability Density")
plt.legend(loc='best');

# %% [markdown]
# ### Please change the variables for desired probability density plots.

# %%
# user inputs
values = [-0.75,0,0.75] # input values
bounds = 0.05 # determine interval size

# for graph axis
x_min = -
x_max = 20
# Out:
#   File "<ipython-input-16-4bf36e5bfdc8>", line 6
#     x_min = -
#              ^
# SyntaxError: invalid syntax

# %%
# generating the plots
if scenario in ("3d", "helix"):
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[0], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[0], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[0], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x & y = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Z")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[1], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[1], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[1], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x & y = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Z")
    ax2.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[2], bounds)
    wgan_y = prob_dist.y2_values(X_generated[:,0], X_generated[:,1], X_generated[:,2], values[2], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[2], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x & y = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Z")
    ax3.set_xlim(x_min, x_max)

else:
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[0], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[0], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[0], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Y")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[1], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[1], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[1], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Y")
    ax2.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(X_generated[:,0], X_generated[:,1], values[2], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[2], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[2], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Y")
    ax3.set_xlim(x_min, x_max)
