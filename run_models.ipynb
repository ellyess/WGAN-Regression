# %%
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras


import dataset, network, GPR_Model, prob_dist
import WGAN_Model

# %% [markdown]
# # Load data

# %%
# 2 n_features sets "sinus", "circle", "multi", "moons", "heter"
# 3 n_features sets "helix", "3d"

scenario = "sinus"
n_instance = 100 # number of generated points
n_features = 2

# %%
if scenario in ("3d", "helix") :
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.tight_layout()
    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='grey')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Preprocessing

# %%
wgan = WGAN_Model.WGAN(n_features)

# %%
train_dataset, X_train_concat_flatten, scaler,  X_train_concat = wgan.preproc(X_train, y_train)
test_dataset, X_test_concat_flatten, scaler1,  X_test_concat = wgan.preproc(X_test, y_test)
# Out:
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (1, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (10, 20, 2, 1)
# every time the data shape (1, 20, 2, 1)

# %% [markdown]
# ### Training

# %%
hist = wgan.train(train_dataset, epochs=100)
# Out:
# Epoch 0/100
# discriminator: -0.439576 - generator: 0.553821 - 5s
# Epoch 1/100
# discriminator: -0.408664 - generator: 0.388667 - 0s
# Epoch 2/100
# discriminator: -0.556473 - generator: 0.427870 - 0s
# Epoch 3/100
# discriminator: -0.450178 - generator: 0.231348 - 0s
# Epoch 4/100
# discriminator: -0.370253 - generator: 0.286318 - 0s
# Epoch 5/100
# discriminator: -0.388279 - generator: 0.353166 - 0s
# Epoch 6/100
# discriminator: -0.421159 - generator: 0.401023 - 0s
# Epoch 7/100
# discriminator: -0.684960 - generator: 0.388328 - 0s
# Epoch 8/100
# discriminator: -0.784525 - generator: 0.403132 - 0s
# Epoch 9/100
# discriminator: -0.712046 - generator: 0.289629 - 0s
# Epoch 10/100
# discriminator: -0.708844 - generator: 0.242304 - 0s
# Epoch 11/100
# discriminator: -0.695918 - generator: 0.252336 - 0s
# Epoch 12/100
# discriminator: -0.959561 - generator: 0.262705 - 0s
# Epoch 13/100
# discriminator: -0.753947 - generator: 0.188908 - 0s
# Epoch 14/100
# discriminator: -0.697339 - generator: 0.187880 - 0s
# Epoch 15/100
# discriminator: -0.713273 - generator: 0.111077 - 0s
# Epoch 16/100
# discriminator: -0.597088 - generator: 0.219684 - 0s
# Epoch 17/100
# discriminator: -0.687430 - generator: 0.111454 - 0s
# Epoch 18/100
# discriminator: -0.706419 - generator: 0.178344 - 0s
# Epoch 19/100
# discriminator: -0.546150 - generator: 0.084643 - 0s
# Epoch 20/100
# discriminator: -0.669813 - generator: 0.124236 - 0s
# Epoch 21/100
# discriminator: -0.739358 - generator: 0.082437 - 0s
# Epoch 22/100
# discriminator: -0.630630 - generator: 0.102312 - 0s
# Epoch 23/100
# discriminator: -0.753089 - generator: 0.127595 - 0s
# Epoch 24/100
# discriminator: -0.734396 - generator: 0.137767 - 0s
# Epoch 25/100
# discriminator: -0.685948 - generator: 0.085573 - 0s
# Epoch 26/100
# discriminator: -0.796872 - generator: 0.143121 - 0s
# Epoch 27/100
# discriminator: -0.596520 - generator: 0.164370 - 0s
# Epoch 28/100
# discriminator: -0.740381 - generator: 0.143574 - 0s
# Epoch 29/100
# discriminator: -0.569471 - generator: 0.103285 - 0s
# Epoch 30/100
# discriminator: -0.801393 - generator: 0.070957 - 0s
# Epoch 31/100
# discriminator: -0.560257 - generator: 0.052505 - 0s
# Epoch 32/100
# discriminator: -0.613144 - generator: 0.132206 - 0s
# Epoch 33/100
# discriminator: -0.811488 - generator: 0.146561 - 0s
# Epoch 34/100
# discriminator: -0.948541 - generator: 0.285539 - 0s
# Epoch 35/100
# discriminator: -0.988041 - generator: 0.303400 - 0s
# Epoch 36/100
# discriminator: -1.008166 - generator: 0.503836 - 0s
# Epoch 37/100
# discriminator: -0.807523 - generator: 0.347549 - 0s
# Epoch 38/100
# discriminator: -0.761244 - generator: 0.396221 - 0s
# Epoch 39/100
# discriminator: -0.908564 - generator: 0.453253 - 0s
# Epoch 40/100
# discriminator: -0.814504 - generator: 0.362652 - 0s
# Epoch 41/100
# discriminator: -0.835052 - generator: 0.265910 - 0s
# Epoch 42/100
# discriminator: -0.737831 - generator: 0.326646 - 0s
# Epoch 43/100
# discriminator: -0.874938 - generator: 0.298967 - 0s
# Epoch 44/100
# discriminator: -0.917730 - generator: 0.324660 - 0s
# Epoch 45/100
# discriminator: -0.933054 - generator: 0.268278 - 0s
# Epoch 46/100
# discriminator: -1.117835 - generator: 0.552603 - 0s
# Epoch 47/100
# discriminator: -1.160786 - generator: 0.576446 - 0s
# Epoch 48/100
# discriminator: -1.199909 - generator: 0.531929 - 0s
# Epoch 49/100
# discriminator: -1.226767 - generator: 0.765879 - 0s
# Epoch 50/100
# discriminator: -1.187577 - generator: 0.821907 - 0s
# Epoch 51/100
# discriminator: -1.149159 - generator: 0.824050 - 0s
# Epoch 52/100
# discriminator: -1.087531 - generator: 0.639926 - 0s
# Epoch 53/100
# discriminator: -1.146550 - generator: 0.778027 - 0s
# Epoch 54/100
# discriminator: -1.157032 - generator: 0.533062 - 0s
# Epoch 55/100
# discriminator: -1.015521 - generator: 0.720628 - 0s
# Epoch 56/100
# discriminator: -1.254553 - generator: 0.832312 - 0s
# Epoch 57/100
# discriminator: -1.223598 - generator: 0.868638 - 0s
# Epoch 58/100
# discriminator: -1.057960 - generator: 0.775462 - 0s
# Epoch 59/100
# discriminator: -1.322131 - generator: 0.759120 - 0s
# Epoch 60/100
# discriminator: -1.020782 - generator: 0.832366 - 0s
# Epoch 61/100
# discriminator: -1.131748 - generator: 0.807742 - 0s
# Epoch 62/100
# discriminator: -1.213324 - generator: 0.813780 - 0s
# Epoch 63/100
# discriminator: -1.289005 - generator: 0.879924 - 0s
# Epoch 64/100
# discriminator: -0.960692 - generator: 0.744849 - 0s
# Epoch 65/100
# discriminator: -1.021612 - generator: 0.580717 - 0s
# Epoch 66/100
# discriminator: -1.083890 - generator: 0.640684 - 0s
# Epoch 67/100
# discriminator: -1.056156 - generator: 0.757713 - 0s
# Epoch 68/100
# discriminator: -1.191292 - generator: 0.701827 - 0s
# Epoch 69/100
# discriminator: -0.954738 - generator: 0.481291 - 0s
# Epoch 70/100
# discriminator: -0.912659 - generator: 0.714817 - 0s
# Epoch 71/100
# discriminator: -1.039966 - generator: 0.818430 - 0s
# Epoch 72/100
# discriminator: -0.864605 - generator: 0.786707 - 0s
# Epoch 73/100
# discriminator: -0.916377 - generator: 0.898052 - 0s
# Epoch 74/100
# discriminator: -1.050088 - generator: 0.991955 - 0s
# Epoch 75/100
# discriminator: -0.890907 - generator: 0.917057 - 0s
# Epoch 76/100
# discriminator: -1.007785 - generator: 0.912457 - 0s
# Epoch 77/100
# discriminator: -1.046448 - generator: 0.990504 - 0s
# Epoch 78/100
# discriminator: -0.882907 - generator: 0.976569 - 0s
# Epoch 79/100
# discriminator: -0.900880 - generator: 0.980889 - 0s
# Epoch 80/100
# discriminator: -0.725917 - generator: 0.874854 - 0s
# Epoch 81/100
# discriminator: -0.861470 - generator: 1.007913 - 0s
# Epoch 82/100
# discriminator: -0.888578 - generator: 1.070217 - 0s
# Epoch 83/100
# discriminator: -1.003769 - generator: 0.971284 - 0s
# Epoch 84/100
# discriminator: -1.077140 - generator: 1.085540 - 0s
# Epoch 85/100
# discriminator: -0.836115 - generator: 1.248579 - 0s
# Epoch 86/100
# discriminator: -0.897577 - generator: 1.462975 - 0s
# Epoch 87/100
# discriminator: -1.075408 - generator: 1.355981 - 0s
# Epoch 88/100
# discriminator: -0.876347 - generator: 1.173273 - 0s
# Epoch 89/100
# discriminator: -1.015850 - generator: 1.196680 - 0s
# Epoch 90/100
# discriminator: -0.931237 - generator: 1.155122 - 0s
# Epoch 91/100
# discriminator: -0.926484 - generator: 1.172299 - 0s
# Epoch 92/100
# discriminator: -1.045400 - generator: 1.109088 - 0s
# Epoch 93/100
# discriminator: -1.069977 - generator: 1.092296 - 0s
# Epoch 94/100
# discriminator: -0.993561 - generator: 1.035684 - 0s
# Epoch 95/100
# discriminator: -0.928982 - generator: 1.285193 - 0s
# Epoch 96/100
# discriminator: -1.146158 - generator: 1.236239 - 0s
# Epoch 97/100
# discriminator: -1.144626 - generator: 1.202182 - 0s
# Epoch 98/100
# discriminator: -1.020715 - generator: 1.273902 - 0s
# Epoch 99/100
# discriminator: -1.014791 - generator: 1.293917 - 0s

# %%
# plot loss
print('Loss: ')
fig, ax = plt.subplots(1,1, figsize=[10,5])
ax.plot(hist)
ax.legend(['loss_gen', 'loss_disc'])
#ax.set_yscale('log')
ax.grid()
plt.tight_layout()
# Out:
# Loss:

# %% [markdown]
# ### Prediction

# %%
wgan_pred = wgan.predict(X_test_concat_flatten, scaler1, X_test_concat)

# %%
if scenario in ("3d", "helix"):
    ax = plt.subplot(projection='3d')

    ax.scatter(wgan_pred[:,0], wgan_pred[:,1], wgan_pred[:,2], c='b', label='Generated Data')  # 绘制数据点,颜色是红色
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
else:
    plt.scatter(wgan_pred[:,0], wgan_pred[:,1], label="Generated Data by WGAN-GP")
    plt.scatter(X_train, y_train, label="Real data")
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# # Gaussian Process Regression

# %%
ypred_GPR = GPR_Model.train(X_train, y_train, X_test, n_features)

# %%
if scenario in ("3d", "helix"):
    ax = plt.subplot(projection='3d')

    ax.scatter(X_test[:,0], X_test[:,1], ypred_GPR, c='b', label='Generated Data')  # 绘制数据点,颜色是红色
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r')

    ax.set_zlabel('Z') 
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()

else:
    plt.scatter(X_test, ypred_GPR, label='Generated Data by GPR')
    plt.scatter(X_train, y_train, label='Real Data')
    plt.legend(loc='best')

# %% [markdown]
# # Comparison
#
# ### Prediction Plots

# %%
# generates the plots
if scenario in ("3d", "helix"):
    fig = plt.figure(figsize=(13, 4))

    #---- First subplot
    ax = fig.add_subplot(1, 3, 1, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], y_test, color='orange')
    ax.set_title("Sample Data")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)

    ax = fig.add_subplot(1, 3, 2, projection='3d')
    ax.scatter(wgan_pred[:,0], wgan_pred[:,1], wgan_pred[:,2], color='green', label='Generated Data')
    ax.set_title("WGAN-GP Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)

    ax = fig.add_subplot(1, 3, 3, projection='3d')
    ax.scatter(X_test[:,0], X_test[:,1], ypred_GPR, c='b', label='Generated Data')
    ax.set_title("GPR Predictions")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_xlim(-1.5,1.5)
    ax.set_ylim(-1.5,1.5)
    ax.set_zlim(0,22)
    
    plt.tight_layout(pad=-1, w_pad=0.8, h_pad=0)
    

else:
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)
    axes[0].scatter(X_test, y_test, label='Real Data', color='orange')
    axes[0].set_title("Sample Data")
    axes[0].set_xlabel("x")
    axes[0].set_ylabel("y")

    axes[1].scatter(wgan_pred[:,0], wgan_pred[:,1], label="Generated Data by WGAN-GP", color='green')
    axes[1].set_title("WGAN-GP Predictions")
    axes[1].set_xlabel("x")

    axes[2].scatter(X_test, ypred_GPR, label='Generated Data by GPR')
    axes[2].set_title("GPR Predictions")
    axes[2].set_xlabel("x")

# %% [markdown]
# ### Probability Density Plots

# %%
# whole distribution
sns.distplot(y_train, hist=False, label='True')
sns.distplot(ypred_GPR, hist=False, label='GPR')
sns.distplot(wgan_pred[:,1], hist=False, label='GAN Generated')
plt.xlabel("Y")
plt.ylabel("Probability Density")
plt.legend(loc='best');

# %% [markdown]
# ### Please change the variables for desired probability density plots.

# %%
# user inputs
values = [-0.75,0,0.75] # input values
bounds = 0.5 # determine interval size

# for graph axis
x_min = -1.5
x_max = 1.5

# %%
# generating the plots
if scenario in ("3d", "helix"):
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[0], bounds)
    wgan_y = prob_dist.y2_values(wgan_pred[:,0], wgan_pred[:,1], wgan_pred[:,2], values[0], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[0], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x & y = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Z")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[1], bounds)
    wgan_y = prob_dist.y2_values(wgan_pred[:,0], wgan_pred[:,1], wgan_pred[:,2], values[1], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[1], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x & y = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Z")
    ax2.set_xlim(x_min, x_max)

    input_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], y_test, values[2], bounds)
    wgan_y = prob_dist.y2_values(wgan_pred[:,0], wgan_pred[:,1], wgan_pred[:,2], values[2], bounds)
    gpr_y = prob_dist.y2_values(X_test[:,0], X_test[:,1], ypred_GPR, values[2], bounds)

    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x & y = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Z")
    ax3.set_xlim(x_min, x_max)

else:
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True, sharex=True)

    wgan_y = prob_dist.y_values(wgan_pred[:,0], wgan_pred[:,1], values[0], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[0], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[0], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax1)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax1)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax1)
    ax1.set_title("Probability Density at x = %1.2f" %values[0] + "±%1.2f" %bounds)
    ax1.set_xlabel("Y")
    ax1.set_ylabel("Probability Density")
    ax1.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(wgan_pred[:,0], wgan_pred[:,1], values[1], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[1], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[1], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax2)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax2)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax2)
    ax2.set_title("Probability Density at x = %1.2f" %values[1] + "±%1.2f" %bounds)
    ax2.set_xlabel("Y")
    ax2.set_xlim(x_min, x_max)

    wgan_y = prob_dist.y_values(wgan_pred[:,0], wgan_pred[:,1], values[2], bounds)
    input_y = prob_dist.y_values(X_test, y_test, values[2], bounds)
    gpr_y = prob_dist.y_values(X_test, ypred_GPR, values[2], bounds
                                  )
    sns.kdeplot(input_y, bw=.2, label='True', color="orange", ax=ax3)
    sns.kdeplot(wgan_y, bw=.2, label='WGAN-GP', color="green", ax=ax3)
    sns.kdeplot(gpr_y, bw=.2, label='GPR', color="blue", ax=ax3)
    ax3.set_title("Probability Density at x = %1.2f" %values[2] + "±%1.2f" %bounds)
    ax3.set_xlabel("Y")
    ax3.set_xlim(x_min, x_max)
